# %% [markdown]
# 使用文档 https://wthahaha.github.io/requests-html-doc-cn/#/?id=%e4%bd%bf%e7%94%a8%e6%96%b9%e6%b3%95

# %%
from bs4 import BeautifulSoup, Tag
import json
import re
import os

# %%
htmlstring = """<ul class="embed-menu">
<li class="group"><a data-nid="11746747" href="/zh_hans/climbing/china" class=""><i class="icon-double-angle-up"></i> <span class="primary-node-name">China</span></a>
</li><li class=" dropdown-submenu"><a data-nid="1810619040" href="/zh_hans/climbing/china/area/1810619040" class=""><span class="primary-node-name">安徽 Anhui</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/1810631571" data-nid="1810631571" data-subtype="crag">萧县天门寺</a></li><li><a href="/zh_hans/climbing/china/area/8253120453" data-nid="8253120453" data-subtype="region">蚌埠梅花山</a></li><li><a href="/zh_hans/climbing/china/area/6760976112" data-nid="6760976112" data-subtype="cliff">合肥茶壶山</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/12391149546" data-nid="12391149546" data-subtype="area">芜湖</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/1810678986" data-nid="1810678986" data-subtype="crag">芜湖繁昌戴店</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2318865684" data-nid="2318865684" data-subtype="cliff">南岩壁</a></li><li><a href="/zh_hans/climbing/china/area/2318811066" data-nid="2318811066" data-subtype="sector">大岩壁</a></li><li><a href="/zh_hans/climbing/china/area/2318808636" data-nid="2318808636" data-subtype="sector">攀石区</a></li><li><a href="/zh_hans/climbing/china/area/2318808696" data-nid="2318808696" data-subtype="sector">高台</a></li><li><a href="/zh_hans/climbing/china/area/2318808576" data-nid="2318808576" data-subtype="sector">推广区</a></li><li><a href="/zh_hans/climbing/china/area/2318808516" data-nid="2318808516" data-subtype="sector">中岩壁</a></li><li><a href="/zh_hans/climbing/china/area/2318808453" data-nid="2318808453" data-subtype="sector">小岩壁</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/1885192074" data-nid="1885192074" data-subtype="crag">南陵笔架山</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/12391150233" data-nid="12391150233" data-subtype="area">宣城市</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/1810650705" data-nid="1810650705" data-subtype="crag">宣城泾县狮子山</a></li><li><a href="/zh_hans/climbing/china/area/10483930617" data-nid="10483930617" data-subtype="area">宣城市溪口镇金狮洞</a></li><li><a href="/zh_hans/climbing/china/area/2318783841" data-nid="2318783841" data-subtype="crag">板桥大石壁</a></li><li><a href="/zh_hans/climbing/china/area/11490975423" data-nid="11490975423" data-subtype="crag">绩溪饭甑尖</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3911604870" data-nid="3911604870" data-subtype="area">障山大峡谷</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/3914325123" data-nid="3914325123" data-subtype="crag">百丈岩</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/4903571136" data-nid="4903571136" data-subtype="field">绩溪龙须山</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/2503501959" data-nid="2503501959" data-subtype="crag">安庆坦埠</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="11877193" href="/zh_hans/climbing/china/beijing" class=""><span class="primary-node-name">北京 Beijing</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/12486523" data-nid="12486523" data-subtype="crag">白河 Baihe</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3353513262" data-nid="3353513262" data-subtype="crag">天门山 Tianmen Mountain</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3356800659" data-nid="3356800659" data-subtype="cliff">西台子</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4705173177" data-nid="4705173177" data-subtype="cliff">一线天</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4705201419" data-nid="4705201419" data-subtype="crag">小北沟</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/4705213413" data-nid="4705213413" data-subtype="crag">石头场</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/4708456428" data-nid="4708456428" data-subtype="cliff">A区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4708457310" data-nid="4708457310" data-subtype="cliff">B区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4705220010" data-nid="4705220010" data-subtype="field">抱石区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6058556412" data-nid="6058556412" data-subtype="field">抱石B区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/8689229739" data-nid="8689229739" data-subtype="area">晚秋</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/7500366117" data-nid="7500366117" data-subtype="crag">肖像崖</a></li><li><a href="/zh_hans/climbing/china/beijing/area/7514356107" data-nid="7514356107" data-subtype="crag">双塔峰</a></li><li><a href="/zh_hans/climbing/china/beijing/area/7598899443" data-nid="7598899443" data-subtype="cliff">老城墙</a></li><li><a href="/zh_hans/climbing/china/beijing/area/9923842389" data-nid="9923842389" data-subtype="area">春晓、辣条 抱石</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4886274612" data-nid="4886274612" data-subtype="crag">林荫长廊</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3356802468" data-nid="3356802468" data-subtype="cliff">快活林</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4706165511" data-nid="4706165511" data-subtype="crag">天门洞</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3962435076" data-nid="3962435076" data-subtype="crag">京都第一瀑冰瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6154403022" data-nid="6154403022" data-subtype="field">背阳（林荫长廊抱石区）</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6152027748" data-nid="6152027748" data-subtype="field">向阳而生</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6071197323" data-nid="6071197323" data-subtype="field">上山沟（停车场旁）</a></li><li><a href="/zh_hans/climbing/china/beijing/area/7188205623" data-nid="7188205623" data-subtype="area">天门洞大石</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/2340553527" data-nid="2340553527" data-subtype="crag">精灵谷 Jinglinggu</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/12652060350" data-nid="12652060350" data-subtype="crag">班车岩场</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/2769771561" data-nid="2769771561" data-subtype="crag">养生堂</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/5926864824" data-nid="5926864824" data-subtype="crag">养生堂抱石区</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/12635812284" data-nid="12635812284" data-subtype="crag">露天浴场</a></li><li><a href="/zh_hans/climbing/china/beijing/area/7767671844" data-nid="7767671844" data-subtype="area">空中花园</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/7500206751" data-nid="7500206751" data-subtype="crag">三楼</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/7563314904" data-nid="7563314904" data-subtype="cliff">客厅</a></li><li><a href="/zh_hans/climbing/china/beijing/area/7590512130" data-nid="7590512130" data-subtype="cliff">阁楼</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/2451144054" data-nid="2451144054" data-subtype="cliff">精灵谷二楼</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3759424509" data-nid="3759424509" data-subtype="cliff">凉亭</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2593367079" data-nid="2593367079" data-subtype="cliff">大洞区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3443203395" data-nid="3443203395" data-subtype="cliff">小洞天</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3903118545" data-nid="3903118545" data-subtype="crag">鹰嘴岩</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4733827599" data-nid="4733827599" data-subtype="cliff">精灵影院</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2471846343" data-nid="2471846343" data-subtype="cliff">露天剧场</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3762413964" data-nid="3762413964" data-subtype="cliff">青石区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2714053422" data-nid="2714053422" data-subtype="cliff">灵泉区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2743551501" data-nid="2743551501" data-subtype="field">露天圆桌抱石</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2676199041" data-nid="2676199041" data-subtype="cliff">世外桃源</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5978268591" data-nid="5978268591" data-subtype="area">落日下</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4558257717" data-nid="4558257717" data-subtype="field">桃源抱石区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5891369166" data-nid="5891369166" data-subtype="cliff">精灵瀑</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/811932012" data-nid="811932012" data-subtype="crag">秘密花园 Secret Garden</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6885112782" data-nid="6885112782" data-subtype="crag">前哨 Frontier outpost</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/155656944" data-nid="155656944" data-subtype="crag">鸽壁 Pigeon Crag</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3885933192" data-nid="3885933192" data-subtype="field">水晶石区域 Crystal</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2747476740" data-nid="2747476740" data-subtype="cliff">雀巢</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3305688627" data-nid="3305688627" data-subtype="cliff">新鸽壁</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2747474952" data-nid="2747474952" data-subtype="cliff">老鸽壁</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4037237922" data-nid="4037237922" data-subtype="field">洞区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5951431539" data-nid="5951431539" data-subtype="area">洞区往上</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2747486400" data-nid="2747486400" data-subtype="cliff">跑签证</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/7598894262" data-nid="7598894262" data-subtype="crag">老村北</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/7599388800" data-nid="7599388800" data-subtype="crag">镜像岩</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/155656920" data-nid="155656920" data-subtype="crag">老怪 Demon Crag</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/812096289" data-nid="812096289" data-subtype="crag">小怪 Monster</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/812100768" data-nid="812100768" data-subtype="cliff">小怪后院</a></li><li><a href="/zh_hans/climbing/china/beijing/area/155656896" data-nid="155656896" data-subtype="crag">小怪正面 Main Wall</a></li><li><a href="/zh_hans/climbing/china/beijing/area/812119560" data-nid="812119560" data-subtype="cliff">二怪</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/650316279" data-nid="650316279" data-subtype="crag">十万岩友 A Hundred Thousand Climbers</a></li><li><a href="/zh_hans/climbing/china/beijing/area/155660892" data-nid="155660892" data-subtype="crag">私房菜 Private Cuisine</a></li><li><a href="/zh_hans/climbing/china/beijing/area/155656968" data-nid="155656968" data-subtype="crag">Cool Day</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2426411784" data-nid="2426411784" data-subtype="crag">春天里 Springtime</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/155656992" data-nid="155656992" data-subtype="crag">NB峡谷 New B Gorge</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/5357400078" data-nid="5357400078" data-subtype="cliff">三枪岩壁</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3940133640" data-nid="3940133640" data-subtype="cliff">NB峡谷冰瀑</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/2432759445" data-nid="2432759445" data-subtype="crag">老岩场 Old School</a></li><li><a href="/zh_hans/climbing/china/beijing/area/155793759" data-nid="155793759" data-subtype="crag">小华山</a></li><li><a href="/zh_hans/climbing/china/beijing/area/155661678" data-nid="155661678" data-subtype="crag">纪念碑 Monument</a></li><li><a href="/zh_hans/climbing/china/beijing/area/811932921" data-nid="811932921" data-subtype="crag">70年代 70‘s decade</a></li><li><a href="/zh_hans/climbing/china/beijing/area/156058986" data-nid="156058986" data-subtype="crag">东岸 East Bank</a></li><li><a href="/zh_hans/climbing/china/beijing/area/811935351" data-nid="811935351" data-subtype="crag">清凉洞 Qing Liang Cave</a></li><li><a href="/zh_hans/climbing/china/beijing/area/155793093" data-nid="155793093" data-subtype="field">乱石岗 Rocky Mound</a></li><li><a href="/zh_hans/climbing/china/beijing/huang-tu-liang" data-nid="155759769" data-subtype="crag">黄土梁 Huang Tu Liang</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3828829545" data-nid="3828829545" data-subtype="crag">天仙瀑峡谷 Tianxian Falls Gorge</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3828956772" data-nid="3828956772" data-subtype="crag">天仙瀑冰瀑</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/5720901915" data-nid="5720901915" data-subtype="crag">望川瀑</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/811940598" data-nid="811940598" data-subtype="area">龙云山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/6804555168" data-nid="6804555168" data-subtype="crag">小柏树\青龙\白虎 等结组线路</a></li><li><a href="/zh_hans/climbing/china/beijing/area/813047592" data-nid="813047592" data-subtype="cliff">大屁股 Big Butt</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3725371380" data-nid="3725371380" data-subtype="cliff">小树林</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3944659977" data-nid="3944659977" data-subtype="crag">红岸基地</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5891336847" data-nid="5891336847" data-subtype="cliff">龙云山景区一号人工冰壁</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5891339034" data-nid="5891339034" data-subtype="cliff">龙云山景区二号人工冰壁</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5891355654" data-nid="5891355654" data-subtype="cliff">白河天梯</a></li><li><a href="/zh_hans/climbing/china/beijing/area/10447476786" data-nid="10447476786" data-subtype="area">生肖石抱石</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/11769463674" data-nid="11769463674" data-subtype="field">黑石岩场</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/6193991856" data-nid="6193991856" data-subtype="area">完美世界</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/6281148390" data-nid="6281148390" data-subtype="crag">完美世界岩场</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/6214490079" data-nid="6214490079" data-subtype="cliff">东侧</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6209547570" data-nid="6209547570" data-subtype="cliff">西侧</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/6265930854" data-nid="6265930854" data-subtype="crag">彩虹崖</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6748658634" data-nid="6748658634" data-subtype="crag">金顶</a></li><li><a href="/zh_hans/climbing/china/beijing/area/7399087443" data-nid="7399087443" data-subtype="crag">星辰大海</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/3817907034" data-nid="3817907034" data-subtype="crag">迪士尼 Disney</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5756460441" data-nid="5756460441" data-subtype="cliff">立春瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/155659377" data-nid="155659377" data-subtype="crag">完美心情 Perfect Feeling</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5891349219" data-nid="5891349219" data-subtype="cliff">雨水瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/811941171" data-nid="811941171" data-subtype="crag">风之谷 The Valley of Freewind</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/9811009341" data-nid="9811009341" data-subtype="crag">世界尽头</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/9811013145" data-nid="9811013145" data-subtype="cliff">东侧岩壁</a></li><li><a href="/zh_hans/climbing/china/beijing/area/9811015608" data-nid="9811015608" data-subtype="cliff">西侧岩壁</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/4443230112" data-nid="4443230112" data-subtype="cliff">珍珠瀑</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/155758893" data-nid="155758893" data-subtype="crag">云蒙峡 Yun Meng Gorge</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/12435209544" data-nid="12435209544" data-subtype="cliff">云蒙峡入口（干攀）</a></li><li><a href="/zh_hans/climbing/china/beijing/area/12435119010" data-nid="12435119010" data-subtype="cliff">小镜湖（干攀）</a></li><li><a href="/zh_hans/climbing/china/beijing/area/11607406029" data-nid="11607406029" data-subtype="cliff">天画</a></li><li><a href="/zh_hans/climbing/china/beijing/area/11711693058" data-nid="11711693058" data-subtype="area">A区天画对面</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3803808741" data-nid="3803808741" data-subtype="cliff">B区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3803809911" data-nid="3803809911" data-subtype="cliff">马尔代夫</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3803810580" data-nid="3803810580" data-subtype="cliff">传统区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3803811537" data-nid="3803811537" data-subtype="cliff">焦区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3803812155" data-nid="3803812155" data-subtype="cliff">焱区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3803813091" data-nid="3803813091" data-subtype="cliff">小石潭</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3803813745" data-nid="3803813745" data-subtype="cliff">C区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3803814618" data-nid="3803814618" data-subtype="cliff">M4塔</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3830724387" data-nid="3830724387" data-subtype="cliff">云蒙峡一号人工冰瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5891165460" data-nid="5891165460" data-subtype="cliff">云蒙峡二号人工冰瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3830726910" data-nid="3830726910" data-subtype="cliff">云蒙峡百米瀑冰瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4317836937" data-nid="4317836937" data-subtype="cliff">三音瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4442390370" data-nid="4442390370" data-subtype="boulder">未命名抱石</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/155656824" data-nid="155656824" data-subtype="crag">桃谷 Peach Gorge</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6071446560" data-nid="6071446560" data-subtype="field">管控仅三天</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3963001659" data-nid="3963001659" data-subtype="crag">桃源仙谷</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3848892312" data-nid="3848892312" data-subtype="cliff">桃源瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3848892384" data-nid="3848892384" data-subtype="cliff">迎浪石</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3962866377" data-nid="3962866377" data-subtype="crag">黑龙潭</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3962286945" data-nid="3962286945" data-subtype="crag">黑龙潭通天瀑冰瀑</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/155793411" data-nid="155793411" data-subtype="crag">捧河湾 Peng He Wan</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/811960395" data-nid="811960395" data-subtype="crag">半岛</a></li><li><a href="/zh_hans/climbing/china/beijing/area/811960461" data-nid="811960461" data-subtype="cliff">捧河景区</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/811960527" data-nid="811960527" data-subtype="region">沙坨子</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/9119916732" data-nid="9119916732" data-subtype="cliff">泰坦尼克号石头Titanic Rock</a></li><li><a href="/zh_hans/climbing/china/beijing/area/9133673607" data-nid="9133673607" data-subtype="cliff">一线洞The Seam'n Cave</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/5891375961" data-nid="5891375961" data-subtype="cliff">白河之柱</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/956889135" data-nid="956889135" data-subtype="crag">五道岭 Wu Dao Ling</a></li><li><a href="/zh_hans/climbing/china/beijing/area/155656848" data-nid="155656848" data-subtype="crag">二道河 Er Dao He Crag</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/155656800" data-nid="155656800" data-subtype="crag">蜜蜂峡谷 Honeybee Gorge</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/811643133" data-nid="811643133" data-subtype="cliff">南侧 South Side</a></li><li><a href="/zh_hans/climbing/china/beijing/area/283400889" data-nid="283400889" data-subtype="cliff">北侧 North Side</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/4843223826" data-nid="4843223826" data-subtype="crag">流白水</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/6101122968" data-nid="6101122968" data-subtype="sector">水关</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/4843226937" data-nid="4843226937" data-subtype="boulder">水关</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/4966766190" data-nid="4966766190" data-subtype="sector">咖啡庄园</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/6101204964" data-nid="6101204964" data-subtype="boulder">one team &amp; 580 &amp; 老白干</a></li></ul></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/5542756365" data-nid="5542756365" data-subtype="field">云龙涧</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5891390934" data-nid="5891390934" data-subtype="crag">四潭雾泉冰瀑群</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3963222984" data-nid="3963222984" data-subtype="area">昌平 Changping District</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/2350910496" data-nid="2350910496" data-subtype="crag">后花园 Backyard Garden</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/2149251333" data-nid="2149251333" data-subtype="cliff">火焰山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/2149252974" data-nid="2149252974" data-subtype="sector">一楼</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2149253034" data-nid="2149253034" data-subtype="sector">二楼</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/2350918146" data-nid="2350918146" data-subtype="cliff">桃花岛</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2350918206" data-nid="2350918206" data-subtype="cliff">卧牛岭 Crouching Ox</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3142276239" data-nid="3142276239" data-subtype="crag">小北壁</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3984807360" data-nid="3984807360" data-subtype="field">琉球区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3984810726" data-nid="3984810726" data-subtype="field">河道区</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3984812412" data-nid="3984812412" data-subtype="field">垃圾箱</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3984849408" data-nid="3984849408" data-subtype="field">瀑布谷</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3918263892" data-nid="3918263892" data-subtype="crag">赤壁 Red Wall</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3918268398" data-nid="3918268398" data-subtype="cliff">东墙 East Wall</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3918269709" data-nid="3918269709" data-subtype="cliff">西墙 West Wall</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3962849784" data-nid="3962849784" data-subtype="crag">虎峪</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3962669175" data-nid="3962669175" data-subtype="crag">虎峪人工冰瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5756545572" data-nid="5756545572" data-subtype="cliff">虎峪2号人工冰瀑</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/6104537595" data-nid="6104537595" data-subtype="field">金山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/6115813539" data-nid="6115813539" data-subtype="boulder">金角大王</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6115844826" data-nid="6115844826" data-subtype="boulder">大金豆</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6115858569" data-nid="6115858569" data-subtype="boulder">山后小檐</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/6104540097" data-nid="6104540097" data-subtype="area">银山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/6123529629" data-nid="6123529629" data-subtype="boulder">马步</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6123494229" data-nid="6123494229" data-subtype="boulder">墨痕</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6123584721" data-nid="6123584721" data-subtype="boulder">六米</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6126763299" data-nid="6126763299" data-subtype="boulder">银角大王</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6148065033" data-nid="6148065033" data-subtype="boulder">小仰</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6151820979" data-nid="6151820979" data-subtype="boulder">奥利奥</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6194546475" data-nid="6194546475" data-subtype="boulder">小蓝鲸</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6154348083" data-nid="6154348083" data-subtype="boulder">大豆腐块儿</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6217821093" data-nid="6217821093" data-subtype="boulder">拐角</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6218749485" data-nid="6218749485" data-subtype="boulder">老树卧石</a></li><li><a href="/zh_hans/climbing/china/beijing/area/6232274148" data-nid="6232274148" data-subtype="boulder">白莲花</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/5997588351" data-nid="5997588351" data-subtype="area">海淀 Haidian District</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/phoenix-hill" data-nid="12486499" data-subtype="crag">凤凰岭 Phoenix Hill</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/phoenix-hill/area/3233521599" data-nid="3233521599" data-subtype="crag">南线</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/phoenix-hill/area/3254275068" data-nid="3254275068" data-subtype="cliff">任天堂</a></li><li><a href="/zh_hans/climbing/china/beijing/phoenix-hill/area/3254285007" data-nid="3254285007" data-subtype="cliff">百鸟朝凤</a></li><li><a href="/zh_hans/climbing/china/beijing/phoenix-hill/area/3254289993" data-nid="3254289993" data-subtype="cliff">变形金刚</a></li><li><a href="/zh_hans/climbing/china/beijing/phoenix-hill/area/6082746777" data-nid="6082746777" data-subtype="crag">喳喳花园</a></li><li><a href="/zh_hans/climbing/china/beijing/phoenix-hill/area/5533358913" data-nid="5533358913" data-subtype="cliff">元宇宙</a></li><li><a href="/zh_hans/climbing/china/beijing/phoenix-hill/area/5865350457" data-nid="5865350457" data-subtype="cliff">道德峰</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/phoenix-hill/area/5858091801" data-nid="5858091801" data-subtype="crag">中线</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/phoenix-hill/area/5858100900" data-nid="5858100900" data-subtype="cliff">雄狮峰</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/6084894738" data-nid="6084894738" data-subtype="crag">阳台山</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/6086562081" data-nid="6086562081" data-subtype="field">黑石林</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/6127238469" data-nid="6127238469" data-subtype="boulder">黑大兽</a></li></ul></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/sidu" data-nid="3963235614" data-subtype="area">房山 Fangshan District</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/long-an" data-nid="155760351" data-subtype="crag">龙安 Long An</a></li><li><a href="/zh_hans/climbing/china/beijing/sidu/area/817707108" data-nid="817707108" data-subtype="crag">三渡 San Du</a></li><li><a href="/zh_hans/climbing/china/beijing/sidu/area/272972097" data-nid="272972097" data-subtype="crag">四渡 Si Du</a></li><li><a href="/zh_hans/climbing/china/beijing/sidu/area/2714072064" data-nid="2714072064" data-subtype="crag">孤独星球 Lonely Planet</a></li><li><a href="/zh_hans/climbing/china/beijing/sidu/area/3972098502" data-nid="3972098502" data-subtype="crag">金水湖</a></li><li><a href="/zh_hans/climbing/china/beijing/sidu/area/5891591259" data-nid="5891591259" data-subtype="cliff">古柳冰瀑</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3963241254" data-nid="3963241254" data-subtype="area">门头沟 Mentougou District</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3844500177" data-nid="3844500177" data-subtype="crag">安家庄</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3844501995" data-nid="3844501995" data-subtype="cliff">安家庄1号瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3844502565" data-nid="3844502565" data-subtype="cliff">安家庄2号瀑</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3962689011" data-nid="3962689011" data-subtype="crag">双龙峡</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3962690532" data-nid="3962690532" data-subtype="crag">第一瀑布</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3962690598" data-nid="3962690598" data-subtype="crag">第二瀑布</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/3966041769" data-nid="3966041769" data-subtype="crag">龙门沟</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4516884945" data-nid="4516884945" data-subtype="crag">斋堂镇小冰瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5891419935" data-nid="5891419935" data-subtype="cliff">王平镇瓜草地冰瀑</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3963255876" data-nid="3963255876" data-subtype="area">延庆 Yanqing District</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3844458867" data-nid="3844458867" data-subtype="crag">玉渡山 Yudu Mountain</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3965797923" data-nid="3965797923" data-subtype="crag">青龙潭</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4516880484" data-nid="4516880484" data-subtype="crag">滴水壶</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5891411697" data-nid="5891411697" data-subtype="cliff">后沟村冰瀑</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3963266661" data-nid="3963266661" data-subtype="area">怀柔 Huairou District</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3944593458" data-nid="3944593458" data-subtype="crag">黄土梁 Huang Tu Liang</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3957141582" data-nid="3957141582" data-subtype="crag">天池峡谷</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/3962716737" data-nid="3962716737" data-subtype="cliff">天池冰瀑</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/4057357884" data-nid="4057357884" data-subtype="crag">七道沟</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/4516710480" data-nid="4516710480" data-subtype="area">峪道河</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/4516770168" data-nid="4516770168" data-subtype="cliff">一号冰瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/4516868670" data-nid="4516868670" data-subtype="cliff">二号冰瀑</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/5891395020" data-nid="5891395020" data-subtype="cliff">鬼谷洞</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5891401569" data-nid="5891401569" data-subtype="cliff">飞云瀑</a></li><li><a href="/zh_hans/climbing/china/beijing/area/5891406789" data-nid="5891406789" data-subtype="cliff">石门山</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/9634199058" data-nid="9634199058" data-subtype="crag">杏花台</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/9755120430" data-nid="9755120430" data-subtype="area">梦中情石</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/9756150867" data-nid="9756150867" data-subtype="boulder">下游巨石</a></li></ul></li><li><a href="/zh_hans/climbing/china/beijing/area/9755116719" data-nid="9755116719" data-subtype="field">京北第一泉</a></li><li><a href="/zh_hans/climbing/china/beijing/area/9830878317" data-nid="9830878317" data-subtype="field">low抱乐园</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/beijing/area/3963369384" data-nid="3963369384" data-subtype="area">岩馆 Climbing Gyms</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/beijing/area/2565197880" data-nid="2565197880" data-subtype="gym">岩时攀岩馆 Rock Hour</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2569226856" data-nid="2569226856" data-subtype="gym">O’le 798 Climbing Gym</a></li><li><a href="/zh_hans/climbing/china/beijing/area/2735156892" data-nid="2735156892" data-subtype="gym">人人攀岩</a></li><li><a href="/zh_hans/climbing/china/beijing/area/7085439966" data-nid="7085439966" data-subtype="gym">人人攀岩(丽泽店)</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3767236725" data-nid="3767236725" data-subtype="gym">问山攀岩馆</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3767235219" data-nid="3767235219" data-subtype="gym">Climb On Gym</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3286639866" data-nid="3286639866" data-subtype="gym">浩石运动攀岩空间（798店）</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3286639746" data-nid="3286639746" data-subtype="gym">香蕉攀岩768店</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3286639806" data-nid="3286639806" data-subtype="gym">香蕉攀岩上地店</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3963556593" data-nid="3963556593" data-subtype="gym">奥攀攀岩（玉泉营店）</a></li><li><a href="/zh_hans/climbing/china/beijing/area/3963561405" data-nid="3963561405" data-subtype="gym">攀岩最爱常营店</a></li><li><a href="/zh_hans/climbing/china/beijing/area/7083977949" data-nid="7083977949" data-subtype="gym">ET攀岩俱乐部</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="2633944944" href="/zh_hans/climbing/china/area/2633944944" class=""><span class="primary-node-name">重庆 Chongqing</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/12708252639" data-nid="12708252639" data-subtype="crag">石林寺</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2349767403" data-nid="2349767403" data-subtype="crag">南川石板沟</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2424457431" data-nid="2424457431" data-subtype="cliff">A</a></li><li><a href="/zh_hans/climbing/china/area/2424457491" data-nid="2424457491" data-subtype="cliff">B</a></li><li><a href="/zh_hans/climbing/china/area/2424457551" data-nid="2424457551" data-subtype="cliff">C</a></li><li><a href="/zh_hans/climbing/china/area/2424457611" data-nid="2424457611" data-subtype="cliff">D</a></li><li><a href="/zh_hans/climbing/china/area/2424457671" data-nid="2424457671" data-subtype="cliff">E</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/1141139391" data-nid="1141139391" data-subtype="crag">⽔江反壁岩</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2628183147" data-nid="2628183147" data-subtype="area">大保健岩区</a></li><li><a href="/zh_hans/climbing/china/area/2628183207" data-nid="2628183207" data-subtype="area">土匪洞岩区</a></li><li><a href="/zh_hans/climbing/china/area/2628183267" data-nid="2628183267" data-subtype="area">冰火岩区</a></li><li><a href="/zh_hans/climbing/china/area/2628183327" data-nid="2628183327" data-subtype="area">飞拉达岩区</a></li><li><a href="/zh_hans/climbing/china/area/2628183387" data-nid="2628183387" data-subtype="area">儿童乐园</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/3221541222" data-nid="3221541222" data-subtype="crag">水江天成岩</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/yu-lin-he" data-nid="156144861" data-subtype="crag">御临河</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/yu-lin-he/area/4948297098" data-nid="4948297098" data-subtype="region">老公路岩区</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/yu-lin-he/area/4948433928" data-nid="4948433928" data-subtype="cliff">排花洞岩区</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/4941332352" data-nid="4941332352" data-subtype="crag">猫儿峡</a></li><li><a href="/zh_hans/climbing/china/area/5520003504" data-nid="5520003504" data-subtype="crag">奉节县白帝城</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/7243375752" data-nid="7243375752" data-subtype="crag">涪陵鹦哥洞</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/12626754885" data-nid="12626754885" data-subtype="area">洞口内右侧</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/6141257139" data-nid="6141257139" data-subtype="field">窑湾森林公园</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/9039345786" data-nid="9039345786" data-subtype="boulder">2号</a></li><li><a href="/zh_hans/climbing/china/area/9039347355" data-nid="9039347355" data-subtype="boulder">5号</a></li><li><a href="/zh_hans/climbing/china/area/9039347415" data-nid="9039347415" data-subtype="boulder">9号</a></li><li><a href="/zh_hans/climbing/china/area/9039347475" data-nid="9039347475" data-subtype="boulder">13号</a></li><li><a href="/zh_hans/climbing/china/area/9039347535" data-nid="9039347535" data-subtype="boulder">16号</a></li><li><a href="/zh_hans/climbing/china/area/9039347595" data-nid="9039347595" data-subtype="boulder">17号</a></li></ul></li></ul></li><li class=" selected open-submenu"><a data-nid="154039944" href="/zh_hans/climbing/china/fujian" class=""><span class="primary-node-name">福建 Fujian</span></a><ul>
<li class=" dropdown-submenu"><a data-nid="3014166480" href="/zh_hans/climbing/china/fujian/area/3014166480" class=""><span class="primary-node-name">福州 Fuzhou</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/12699861633" data-nid="12699861633" data-subtype="area">连江县古石村</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/12699899811" data-nid="12699899811" data-subtype="area">古石村岩场</a></li><li><a href="/zh_hans/climbing/china/fujian/area/12699901509" data-nid="12699901509" data-subtype="area">岩场</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/9136364955" data-nid="9136364955" data-subtype="area">罗源 Luo Yuan</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/8369895024" data-nid="8369895024" data-subtype="area">罗源县起步镇鹰嘴岩</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/9047628489" data-nid="9047628489" data-subtype="crag">鹰嘴岩难度区</a></li><li><a href="/zh_hans/climbing/china/fujian/area/9047673933" data-nid="9047673933" data-subtype="crag">鹰嘴岩抱石区</a></li></ul></li><li><a href="/zh_hans/climbing/china/fujian/area/9052985607" data-nid="9052985607" data-subtype="crag">罗源县八井村</a></li><li><a href="/zh_hans/climbing/china/fujian/area/9052963989" data-nid="9052963989" data-subtype="crag">罗源县茅山村</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/9601319607" data-nid="9601319607" data-subtype="area">罗源县管柄村圆通寺</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/10979837712" data-nid="10979837712" data-subtype="boulder">圆通石</a></li><li><a href="/zh_hans/climbing/china/fujian/area/10963631049" data-nid="10963631049" data-subtype="boulder">胖头鱼</a></li><li><a href="/zh_hans/climbing/china/fujian/area/10986967455" data-nid="10986967455" data-subtype="boulder">流心</a></li><li><a href="/zh_hans/climbing/china/fujian/area/11030388246" data-nid="11030388246" data-subtype="boulder">火龙果</a></li><li><a href="/zh_hans/climbing/china/fujian/area/11030411073" data-nid="11030411073" data-subtype="boulder">掌上明猪</a></li><li><a href="/zh_hans/climbing/china/fujian/area/11038185921" data-nid="11038185921" data-subtype="boulder">金蟾</a></li><li><a href="/zh_hans/climbing/china/fujian/area/11447360061" data-nid="11447360061" data-subtype="boulder">自在</a></li></ul></li><li><a href="/zh_hans/climbing/china/fujian/area/9596719842" data-nid="9596719842" data-subtype="field">罗源县下楼海边岩场</a></li><li><a href="/zh_hans/climbing/china/fujian/area/7211439513" data-nid="7211439513" data-subtype="crag">罗源县圣塘村</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/luo-yuan-lin-tou-cliff" data-nid="156263445" data-subtype="area">罗源县廪头岩场 Luo Yuan Lin Tou Cliff</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/luo-yuan-lin-tou-cliff/area/9138181905" data-nid="9138181905" data-subtype="crag">1号岩场</a></li><li><a href="/zh_hans/climbing/china/fujian/luo-yuan-lin-tou-cliff/area/7593606570" data-nid="7593606570" data-subtype="crag">2号岩场</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/mo-xi-climbing-park" data-nid="156263421" data-subtype="crag">磨溪攀岩公园 Mo Xi Climbing Park</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/mo-xi-climbing-park/area/1689537816" data-nid="1689537816" data-subtype="cliff">磨溪1号岩壁 Cliff 1</a></li><li><a href="/zh_hans/climbing/china/fujian/mo-xi-climbing-park/area/1689537876" data-nid="1689537876" data-subtype="cliff">磨溪2号岩壁 Cliff 2</a></li><li><a href="/zh_hans/climbing/china/fujian/mo-xi-climbing-park/area/1689537936" data-nid="1689537936" data-subtype="cliff">磨溪3号岩壁 Cliff 3</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/mo-xi-climbing-park/area/3504536754" data-nid="3504536754" data-subtype="area">磨溪抱石</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/mo-xi-climbing-park/area/5521639299" data-nid="5521639299" data-subtype="boulder">南宫抱石</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/2685289203" data-nid="2685289203" data-subtype="crag">粗芦岛龙沙</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/12305916909" data-nid="12305916909" data-subtype="area">不明记录</a></li></ul></li><li><a href="/zh_hans/climbing/china/fujian/area/2685289755" data-nid="2685289755" data-subtype="crag">琅岐岛龙王洞</a></li><li><a href="/zh_hans/climbing/china/fujian/ma-wei-shang-qi" data-nid="3197720409" data-subtype="crag">马尾区牛栏坑岩场</a></li><li><a href="/zh_hans/climbing/china/fujian/area/8388692349" data-nid="8388692349" data-subtype="cliff">连江县北茭村</a></li><li><a href="/zh_hans/climbing/china/fujian/red-flag-canal-cliff-of-xiashi-in-fuqing-jingyang" data-nid="156263517" data-subtype="crag">福清镜洋下施红旗渠 Red Flag Canal Cliff</a></li><li><a href="/zh_hans/climbing/china/fujian/chang-le-zhang-gang-cliff" data-nid="156263469" data-subtype="crag">长乐漳港海边岩场 Chang Le Zhang Gang Cliff</a></li><li><a href="/zh_hans/climbing/china/fujian/area/11465313669" data-nid="11465313669" data-subtype="area">长乐象鼻澳海滩</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="2282955060" href="/zh_hans/climbing/china/fujian/area/2282955060" class=""><span class="primary-node-name">泉州 Quanzhou</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/3818743119" data-nid="3818743119" data-subtype="field">崇武簸箕湾</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/3820173558" data-nid="3820173558" data-subtype="boulder">#1</a></li><li><a href="/zh_hans/climbing/china/fujian/area/3820202955" data-nid="3820202955" data-subtype="boulder">#2</a></li><li><a href="/zh_hans/climbing/china/fujian/area/3820203852" data-nid="3820203852" data-subtype="boulder">#3</a></li><li><a href="/zh_hans/climbing/china/fujian/area/3820205925" data-nid="3820205925" data-subtype="boulder">#4</a></li><li><a href="/zh_hans/climbing/china/fujian/area/3820205991" data-nid="3820205991" data-subtype="boulder">#5</a></li><li><a href="/zh_hans/climbing/china/fujian/area/3820206057" data-nid="3820206057" data-subtype="boulder">#6</a></li><li><a href="/zh_hans/climbing/china/fujian/area/3820206123" data-nid="3820206123" data-subtype="boulder">#7</a></li><li><a href="/zh_hans/climbing/china/fujian/area/3820206210" data-nid="3820206210" data-subtype="boulder">#8</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/3818944755" data-nid="3818944755" data-subtype="crag">泉州桃源</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/3184690236" data-nid="3184690236" data-subtype="field">第一区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/5543610423" data-nid="5543610423" data-subtype="boulder">1号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543627601" data-nid="5543627601" data-subtype="boulder">2号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543636016" data-nid="5543636016" data-subtype="boulder">3号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543650158" data-nid="5543650158" data-subtype="boulder">4号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543650230" data-nid="5543650230" data-subtype="boulder">5号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543641185" data-nid="5543641185" data-subtype="boulder">6号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543650311" data-nid="5543650311" data-subtype="boulder">7号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543650407" data-nid="5543650407" data-subtype="boulder">8号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543644986" data-nid="5543644986" data-subtype="boulder">9号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543669481" data-nid="5543669481" data-subtype="boulder">10号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543669553" data-nid="5543669553" data-subtype="boulder">11号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543669625" data-nid="5543669625" data-subtype="boulder">12号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543669697" data-nid="5543669697" data-subtype="boulder">13号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543669769" data-nid="5543669769" data-subtype="boulder">14号石头</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/3186658311" data-nid="3186658311" data-subtype="field">第二区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/5543684280" data-nid="5543684280" data-subtype="boulder">1号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543684352" data-nid="5543684352" data-subtype="boulder">2号石头</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/3186658851" data-nid="3186658851" data-subtype="field">第三区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/5543690895" data-nid="5543690895" data-subtype="boulder">1号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543697963" data-nid="5543697963" data-subtype="boulder">2号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543698035" data-nid="5543698035" data-subtype="boulder">3号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543698122" data-nid="5543698122" data-subtype="boulder">4号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543698215" data-nid="5543698215" data-subtype="boulder">5号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543698311" data-nid="5543698311" data-subtype="boulder">6号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543698413" data-nid="5543698413" data-subtype="boulder">7号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543698509" data-nid="5543698509" data-subtype="boulder">8号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543698602" data-nid="5543698602" data-subtype="boulder">9号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543698695" data-nid="5543698695" data-subtype="boulder">10号石头</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/3186658911" data-nid="3186658911" data-subtype="field">第四区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/5543718399" data-nid="5543718399" data-subtype="boulder">1号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543718471" data-nid="5543718471" data-subtype="boulder">2号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543718543" data-nid="5543718543" data-subtype="boulder">3号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543718615" data-nid="5543718615" data-subtype="boulder">4号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543718687" data-nid="5543718687" data-subtype="boulder">5号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543718759" data-nid="5543718759" data-subtype="boulder">6号石头</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/3186658971" data-nid="3186658971" data-subtype="field">第五区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/5543735283" data-nid="5543735283" data-subtype="boulder">1号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543743722" data-nid="5543743722" data-subtype="boulder">2号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543743794" data-nid="5543743794" data-subtype="boulder">3号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543743866" data-nid="5543743866" data-subtype="boulder">4号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543743938" data-nid="5543743938" data-subtype="boulder">5号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543744010" data-nid="5543744010" data-subtype="boulder">6号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543744082" data-nid="5543744082" data-subtype="boulder">7号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543744154" data-nid="5543744154" data-subtype="boulder">8号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543744226" data-nid="5543744226" data-subtype="boulder">9号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543744298" data-nid="5543744298" data-subtype="boulder">10号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543744370" data-nid="5543744370" data-subtype="boulder">11号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543744442" data-nid="5543744442" data-subtype="boulder">12号石头</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/4887950247" data-nid="4887950247" data-subtype="field">鸡母石</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/5543448183" data-nid="5543448183" data-subtype="boulder">1号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543448249" data-nid="5543448249" data-subtype="boulder">2号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543448315" data-nid="5543448315" data-subtype="boulder">3号石头</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/5543556018" data-nid="5543556018" data-subtype="field">清源山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/5543578941" data-nid="5543578941" data-subtype="boulder">1号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579007" data-nid="5543579007" data-subtype="boulder">2号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579073" data-nid="5543579073" data-subtype="boulder">3号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579139" data-nid="5543579139" data-subtype="boulder">4号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579205" data-nid="5543579205" data-subtype="boulder">5号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579271" data-nid="5543579271" data-subtype="boulder">6号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579337" data-nid="5543579337" data-subtype="boulder">7号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579403" data-nid="5543579403" data-subtype="boulder">8号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579469" data-nid="5543579469" data-subtype="boulder">9号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579535" data-nid="5543579535" data-subtype="boulder">10号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579601" data-nid="5543579601" data-subtype="boulder">11号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579667" data-nid="5543579667" data-subtype="boulder">12号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579733" data-nid="5543579733" data-subtype="boulder">13号石头</a></li><li><a href="/zh_hans/climbing/china/fujian/area/5543579799" data-nid="5543579799" data-subtype="boulder">14号石头</a></li></ul></li><li><a href="/zh_hans/climbing/china/fujian/area/12757032366" data-nid="12757032366" data-subtype="boulder">紫帽山</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="2113419345" href="/zh_hans/climbing/china/fujian/area/2113419345" class=""><span class="primary-node-name">漳州</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/10927318563" data-nid="10927318563" data-subtype="crag">南太武 Nantaiwu</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/2113421331" data-nid="2113421331" data-subtype="sector">龟甲 Turtle Shell</a></li><li><a href="/zh_hans/climbing/china/fujian/area/2113421391" data-nid="2113421391" data-subtype="sector">猴岩 Monkey Rock</a></li><li><a href="/zh_hans/climbing/china/fujian/area/2113421451" data-nid="2113421451" data-subtype="sector">游乐场 Playground</a></li><li><a href="/zh_hans/climbing/china/fujian/area/2113421511" data-nid="2113421511" data-subtype="sector">巨石 Giant Stone</a></li><li><a href="/zh_hans/climbing/china/fujian/area/2292879237" data-nid="2292879237" data-subtype="sector">酒厂 Brewery</a></li></ul></li><li><a href="/zh_hans/climbing/china/fujian/area/10927320075" data-nid="10927320075" data-subtype="crag">尖山</a></li><li><a href="/zh_hans/climbing/china/fujian/area/10930793121" data-nid="10930793121" data-subtype="area">鼎仔内</a></li><li><a href="/zh_hans/climbing/china/fujian/area/12687847506" data-nid="12687847506" data-subtype="area">乌鼻头角</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="4364044584" href="/zh_hans/climbing/china/fujian/area/4364044584" class=""><span class="primary-node-name">厦门云顶山</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/4364044767" data-nid="4364044767" data-subtype="cliff">后花园</a></li><li><a href="/zh_hans/climbing/china/fujian/area/4364047605" data-nid="4364047605" data-subtype="cliff">秘密花园</a></li><li><a href="/zh_hans/climbing/china/fujian/area/4364050023" data-nid="4364050023" data-subtype="cliff">儿童乐园</a></li><li><a href="/zh_hans/climbing/china/fujian/area/3502715169" data-nid="3502715169" data-subtype="cliff">鹰谷</a></li><li><a href="/zh_hans/climbing/china/fujian/area/4397412474" data-nid="4397412474" data-subtype="cliff">光明墙</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="5655325776" href="/zh_hans/climbing/china/fujian/area/5655325776" class=""><span class="primary-node-name">厦门岛内</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/9260769921" data-nid="9260769921" data-subtype="area">云顶6号</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/9260771052" data-nid="9260771052" data-subtype="area">碧玉寺</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/10452195675" data-nid="10452195675" data-subtype="boulder">石头1</a></li><li><a href="/zh_hans/climbing/china/fujian/area/10452432153" data-nid="10452432153" data-subtype="boulder">石头2</a></li></ul></li><li><a href="/zh_hans/climbing/china/fujian/area/9316894623" data-nid="9316894623" data-subtype="area">曾山</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/fujian/area/9648358830" data-nid="9648358830" data-subtype="area">金榜公园</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/fujian/area/10931127744" data-nid="10931127744" data-subtype="area">金鸡亭</a></li><li><a href="/zh_hans/climbing/china/fujian/area/10931318379" data-nid="10931318379" data-subtype="area">紫竹林区</a></li><li><a href="/zh_hans/climbing/china/fujian/area/10931320140" data-nid="10931320140" data-subtype="area">文屏区</a></li><li><a href="/zh_hans/climbing/china/fujian/area/10931548041" data-nid="10931548041" data-subtype="area">细缝区</a></li><li><a href="/zh_hans/climbing/china/fujian/area/10931615697" data-nid="10931615697" data-subtype="area">涌石亭</a></li></ul></li><li><a href="/zh_hans/climbing/china/fujian/area/12861392685" data-nid="12861392685" data-subtype="area">忠仑公园</a></li></ul></li><li class=""><a data-nid="10941029322" href="/zh_hans/climbing/china/fujian/area/10941029322" class=""><span class="primary-node-name">岩舞空间攀岩厦门馆</span></a></li></ul>
</li><li class=" dropdown-submenu"><a data-nid="1990308066" href="/zh_hans/climbing/china/area/1990308066" class=""><span class="primary-node-name">甘肃 Gansu</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/3841593591" data-nid="3841593591" data-subtype="crag">平凉华亭王峡口一线天岩场</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/4731813462" data-nid="4731813462" data-subtype="crag">迭部</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/1990309749" data-nid="1990309749" data-subtype="crag">扎尕那 Zhagana</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="154039920" href="/zh_hans/climbing/china/guangdong" class=""><span class="primary-node-name">广东 Guangdong</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/ying-xi" data-nid="26032032" data-subtype="area">清远英西 YingXi</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/3504843123" data-nid="3504843123" data-subtype="area">观音谷</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/749424939" data-nid="749424939" data-subtype="crag">观音山 Guanyin Peak</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/792642918" data-nid="792642918" data-subtype="sector">正面 Front</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/749425482" data-nid="749425482" data-subtype="sector">背面 Back</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/829086723" data-nid="829086723" data-subtype="crag">佛仔岩 Fo Zai Crag</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/829088337" data-nid="829088337" data-subtype="crag">云石寺 Yun Shi Temple</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/163440195" data-nid="163440195" data-subtype="crag">Pocket Crag</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/26033220" data-nid="26033220" data-subtype="crag">Camel Mountain</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/2147654061" data-nid="2147654061" data-subtype="crag">和顺</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/3504843183" data-nid="3504843183" data-subtype="area">公正村 大庙周边</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/26032788" data-nid="26032788" data-subtype="crag">白璧 White crag</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/26032860" data-nid="26032860" data-subtype="crag">大庙 Big Temple Crag</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/163440087" data-nid="163440087" data-subtype="crag">金壁 The Golden Wall</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/26032932" data-nid="26032932" data-subtype="crag">No Name Mountain</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/26033076" data-nid="26033076" data-subtype="crag">兴华祖庙 The Jungle Book</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/2087173278" data-nid="2087173278" data-subtype="crag">Bullshit Crag</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/2147691075" data-nid="2147691075" data-subtype="cliff">朝天烛</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/2147671920" data-nid="2147671920" data-subtype="cliff">城下村</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/3504843243" data-nid="3504843243" data-subtype="area">石角村</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/26032500" data-nid="26032500" data-subtype="crag">竹林A Bamboo Groove</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/163439925" data-nid="163439925" data-subtype="sector">竹林B Fantasyland</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/26032644" data-nid="26032644" data-subtype="area">Suicide Slabs</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/26032716" data-nid="26032716" data-subtype="crag">The Afternoon Crag</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/26032428" data-nid="26032428" data-subtype="crag">小庙 Little Temple Crag</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/2384072367" data-nid="2384072367" data-subtype="crag">燕子岩</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/26032356" data-nid="26032356" data-subtype="crag">九龙山 Kowloon Peak</a></li><li><a href="/zh_hans/climbing/china/guangdong/ying-xi/area/3505020846" data-nid="3505020846" data-subtype="crag">彭家祠</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/bai-yun-hill" data-nid="156260268" data-subtype="crag">白云山 Bai Yun Hill</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/milky-cloud-hill" data-nid="156260565" data-subtype="crag">Milky Cloud Hill</a></li><li><a href="/zh_hans/climbing/china/guangdong/trash-crag" data-nid="156260589" data-subtype="crag">Trash Crag</a></li><li><a href="/zh_hans/climbing/china/guangdong/tigers-mouth" data-nid="156260613" data-subtype="crag">Tiger's Mouth</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/area/9196989465" data-nid="9196989465" data-subtype="crag">广州龙洞 Guangzhou Dragon Cave</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/area/9196992600" data-nid="9196992600" data-subtype="area">Zone A</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/area/9196996359" data-nid="9196996359" data-subtype="area">Bloc A1 - Welcome Bloc</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9196999419" data-nid="9196999419" data-subtype="area">Bloc A2 - Tian’s Bloc</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9197000850" data-nid="9197000850" data-subtype="area">Bloc A3 - Roof Bloc</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9197001636" data-nid="9197001636" data-subtype="area">Bloc A7 - Chen’s Bloc</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9219709227" data-nid="9219709227" data-subtype="area">Bloc A9 – Secret Bloc</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/area/9196994565" data-nid="9196994565" data-subtype="area">Zone B</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/area/9197002917" data-nid="9197002917" data-subtype="area">Bloc B1 - Chung’s Bloc</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9197004117" data-nid="9197004117" data-subtype="area">Bloc B2 - Puppy Bloc</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9197006037" data-nid="9197006037" data-subtype="area">Bloc B3 – Ting’s Bloc</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9219776115" data-nid="9219776115" data-subtype="area">Bloc B4 – Kid’s Bloc</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9219784917" data-nid="9219784917" data-subtype="area">Bloc B5 – Discovery Blocs</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/area/9197007333" data-nid="9197007333" data-subtype="area">Zone C</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/area/9316048275" data-nid="9316048275" data-subtype="area">Bloc C1 - Round Bloc</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9316059387" data-nid="9316059387" data-subtype="area">Bloc C2 - Egg Bloc</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9257912286" data-nid="9257912286" data-subtype="area">Bloc C4 – S Bloc</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/area/9934577151" data-nid="9934577151" data-subtype="crag">广州龙头山Guangzhou Dragon Head Mt.</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/area/9934585161" data-nid="9934585161" data-subtype="boulder">Bloc 1.2 贝</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934655589" data-nid="9934655589" data-subtype="boulder">Bloc 1.4 凰</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934662618" data-nid="9934662618" data-subtype="boulder">Bloc 1.6 打</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934662684" data-nid="9934662684" data-subtype="boulder">Bloc 1.7 脑</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934662750" data-nid="9934662750" data-subtype="boulder">Bloc 1.9牛</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934662816" data-nid="9934662816" data-subtype="boulder">Bloc 1.10 画</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934662882" data-nid="9934662882" data-subtype="boulder">Bloc 1.11 杜</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934662948" data-nid="9934662948" data-subtype="boulder">Bloc 1.13 猬</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934663014" data-nid="9934663014" data-subtype="boulder">Bloc 1.14 晋</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934663080" data-nid="9934663080" data-subtype="boulder">Bloc 1.15 衍</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934663146" data-nid="9934663146" data-subtype="boulder">Bloc 1.16 下</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934663212" data-nid="9934663212" data-subtype="boulder">Bloc 2.0 童</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934672677" data-nid="9934672677" data-subtype="boulder">Bloc 2.3 丝</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934672743" data-nid="9934672743" data-subtype="boulder">Bloc 2.11 鲨</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934672809" data-nid="9934672809" data-subtype="boulder">Bloc 2.21 城</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934672875" data-nid="9934672875" data-subtype="boulder">Bloc 2.23 履</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934672941" data-nid="9934672941" data-subtype="boulder">Bloc 2.24 浪</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934673007" data-nid="9934673007" data-subtype="boulder">Bloc 2.25 立</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934673073" data-nid="9934673073" data-subtype="boulder">Bloc 2.27 蚌</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934673139" data-nid="9934673139" data-subtype="boulder">Bloc 4.1 缝</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9934673205" data-nid="9934673205" data-subtype="boulder">Bloc 4.12 龍</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/area/829093608" data-nid="829093608" data-subtype="area">深圳 Shenzhen</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/area/829098198" data-nid="829098198" data-subtype="crag">马峦山 Maluanshan</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/chun-wan" data-nid="156261381" data-subtype="crag">春湾 Chun Wan</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/candle-tower" data-nid="156262089" data-subtype="crag">Candle Tower</a></li><li><a href="/zh_hans/climbing/china/guangdong/qing-yun-temple" data-nid="156262113" data-subtype="crag">Qing Yun Temple</a></li><li><a href="/zh_hans/climbing/china/guangdong/twins-peak" data-nid="156262137" data-subtype="crag">Twins Peak</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/area/828998256" data-nid="828998256" data-subtype="area">珠海 Zhuhai</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/area/829002543" data-nid="829002543" data-subtype="area">九州岛 Jiuzhou Island</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/area/5566585875" data-nid="5566585875" data-subtype="field">码头角</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/5566585947" data-nid="5566585947" data-subtype="field">东北角</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/5566586013" data-nid="5566586013" data-subtype="field">观音殿</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/5566586079" data-nid="5566586079" data-subtype="field">东南区</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangdong/area/831300507" data-nid="831300507" data-subtype="crag">Diploe Mountain</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/2282991180" data-nid="2282991180" data-subtype="crag">博物馆 Museum</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/2423237115" data-nid="2423237115" data-subtype="crag">庙湾</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/area/2423239593" data-nid="2423239593" data-subtype="crag">大万山岛风暴角</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/area/3645748020" data-nid="3645748020" data-subtype="unknown">东湾</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/3645750687" data-nid="3645750687" data-subtype="unknown">北壁</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/3645753384" data-nid="3645753384" data-subtype="unknown">孤岛西南壁</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/3645758343" data-nid="3645758343" data-subtype="unknown">孤岛赤壁</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/area/9657538164" data-nid="9657538164" data-subtype="crag">珠海荒土乐园野抱Zhuhai Wasteland Paradise</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/area/9657540792" data-nid="9657540792" data-subtype="boulder">Bloc A 启</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9657543339" data-nid="9657543339" data-subtype="boulder">Bloc B 盖</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9657543411" data-nid="9657543411" data-subtype="boulder">Bloc C 躺</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9657543483" data-nid="9657543483" data-subtype="boulder">Bloc D 怠</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9657543555" data-nid="9657543555" data-subtype="boulder">Bloc E 平</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9657543627" data-nid="9657543627" data-subtype="boulder">Bloc H 顺</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/9657545943" data-nid="9657545943" data-subtype="boulder">Bloc J 巨</a></li></ul></li></ul></li><li><a href="/zh_hans/climbing/china/guangdong/area/3681523950" data-nid="3681523950" data-subtype="field">汕头杭美岩场</a></li><li><a href="/zh_hans/climbing/china/guangdong/area/4907483772" data-nid="4907483772" data-subtype="crag">中山北台</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangdong/area/10342227987" data-nid="10342227987" data-subtype="area">肇庆怀集</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangdong/area/10342288866" data-nid="10342288866" data-subtype="area">燕岩</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="154039872" href="/zh_hans/climbing/china/guangxi" class=""><span class="primary-node-name">广西 Guangxi</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/leye" data-nid="156253425" data-subtype="crag">乐业 Leye</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/three-way-cave" data-nid="156257883" data-subtype="crag">Three Way Cave</a></li><li><a href="/zh_hans/climbing/china/guangxi/sun-salutation-crag" data-nid="156257907" data-subtype="crag">Sun Salutation Crag</a></li><li><a href="/zh_hans/climbing/china/guangxi/lily-crag" data-nid="156257931" data-subtype="crag">Lily Crag</a></li><li><a href="/zh_hans/climbing/china/guangxi/horse-cave" data-nid="156257955" data-subtype="crag">Horse Cave</a></li><li><a href="/zh_hans/climbing/china/guangxi/lower-mound-crag-1-1" data-nid="156257979" data-subtype="crag">Lower Mound Crag 1</a></li><li><a href="/zh_hans/climbing/china/guangxi/lower-mound-crag-2-2" data-nid="156258003" data-subtype="crag">Lower Mound Crag 2</a></li><li><a href="/zh_hans/climbing/china/guangxi/xia-liu-crag" data-nid="156258027" data-subtype="crag">Xia Liu Crag</a></li><li><a href="/zh_hans/climbing/china/guangxi/huo-mai-exploration-base" data-nid="156258051" data-subtype="crag">Huo Mai Exploration Base</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/leye/area/2338815987" data-nid="2338815987" data-subtype="crag">牛坪洞</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/leye/area/2441196591" data-nid="2441196591" data-subtype="sector">A</a></li><li><a href="/zh_hans/climbing/china/guangxi/leye/area/2441198517" data-nid="2441198517" data-subtype="sector">B</a></li><li><a href="/zh_hans/climbing/china/guangxi/leye/area/2441200629" data-nid="2441200629" data-subtype="sector">C</a></li><li><a href="/zh_hans/climbing/china/guangxi/leye/area/2441203497" data-nid="2441203497" data-subtype="sector">D</a></li><li><a href="/zh_hans/climbing/china/guangxi/leye/area/2441204889" data-nid="2441204889" data-subtype="sector">E</a></li><li><a href="/zh_hans/climbing/china/guangxi/leye/area/2441206038" data-nid="2441206038" data-subtype="sector">F</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangxi/leye/area/6905681673" data-nid="6905681673" data-subtype="crag">大石围天坑</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/3341738325" data-nid="3341738325" data-subtype="area">桂林 GuiLin</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/area/3027007035" data-nid="3027007035" data-subtype="crag">Pagoda Hill</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/5099334537" data-nid="5099334537" data-subtype="crag">马家坊</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/6721788591" data-nid="6721788591" data-subtype="area">翠竹路明渝丰田马路对面</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo" data-nid="11877169" data-subtype="area">阳朔 Yangshuo</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/3215903541" data-nid="3215903541" data-subtype="area">遇龙河地区 YuLong River</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/area/1946894193" data-nid="1946894193" data-subtype="crag">邻居山 The Neighborhood</a></li><li><a href="/zh_hans/climbing/china/yangshuo/lao-tie-shan" data-nid="12486187" data-subtype="crag">老铁山 Lao Tie Mountain</a></li><li><a href="/zh_hans/climbing/china/yangshuo/dag-crag" data-nid="12486115" data-subtype="crag">大屋檐 Dag Crag</a></li><li><a href="/zh_hans/climbing/china/yangshuo/baby-frog-buttress" data-nid="12486091" data-subtype="crag">蝌蚪山 Baby Frog Buttress</a></li><li><a href="/zh_hans/climbing/china/yangshuo/the-white-cliff" data-nid="12486379" data-subtype="crag">白岩 The White Cliff</a></li><li><a href="/zh_hans/climbing/china/yangshuo/dragons-tooth" data-nid="12486163" data-subtype="crag">龙牙山 Dragon's Tooth</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/10467621327" data-nid="10467621327" data-subtype="crag">私房菜 Private Reserve</a></li><li><a href="/zh_hans/climbing/china/yangshuo/dingoes-dell-maen-tao" data-nid="12486139" data-subtype="crag">流浪谷 Dingo's Dell</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/9030642591" data-nid="9030642591" data-subtype="area">白沙地区 BaiSha</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/area/9030643335" data-nid="9030643335" data-subtype="crag">白沙堡 Baishabao</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/3215911299" data-nid="3215911299" data-subtype="area">瑞士墙-酒瓶山地区 Corridor Entrance</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/area/1905629493" data-nid="1905629493" data-subtype="crag">三只小猪 Three Little Pigs</a></li><li><a href="/zh_hans/climbing/china/yangshuo/jeremys-jiji" data-nid="167366559" data-subtype="crag">Jeremy's Jiji</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/swiss-cheese-wall" data-nid="11358471" data-subtype="crag">瑞士墙 Swiss Wall</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/swiss-cheese-wall/area/157414479" data-nid="157414479" data-subtype="sector">巧克力墙 Chocolate Side</a></li><li><a href="/zh_hans/climbing/china/yangshuo/swiss-cheese-wall/area/157414143" data-nid="157414143" data-subtype="sector">奶酪墙 Cheese Side</a></li></ul></li><li><a href="/zh_hans/climbing/china/yangshuo/area/8690534532" data-nid="8690534532" data-subtype="area">状元岩场 Exemplar’s Crag</a></li><li><a href="/zh_hans/climbing/china/yangshuo/wine-bottle" data-nid="12485803" data-subtype="crag">酒瓶山 Wine Bottle</a></li><li><a href="/zh_hans/climbing/china/yangshuo/thumb-peak" data-nid="12485851" data-subtype="crag">拇指峰 Thumb Peak</a></li><li><a href="/zh_hans/climbing/china/yangshuo/the-middle-finger" data-nid="12485875" data-subtype="crag">中指峰 Middle Finger</a></li><li><a href="/zh_hans/climbing/china/yangshuo/the-butterfly-spring" data-nid="12485995" data-subtype="crag">蝴蝶泉 The Butterfly Spring</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/24676308" data-nid="24676308" data-subtype="crag">尖叫峰 Screaming Mountain Turtle</a></li><li><a href="/zh_hans/climbing/china/yangshuo/golden-cat-cave" data-nid="12485971" data-subtype="crag">金猫洞 Golden Cat Cave</a></li><li><a href="/zh_hans/climbing/china/yangshuo/the-promised-land" data-nid="12486403" data-subtype="crag">The Promised Land</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/3215938428" data-nid="3215938428" data-subtype="area">大榕树-同门山地区 JinBao Confluence</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/area/24698961" data-nid="24698961" data-subtype="crag">遇龙河边 Dragon River Crag</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/239047389" data-nid="239047389" data-subtype="crag">金水岸 Golden River Side</a></li><li><a href="/zh_hans/climbing/china/yangshuo/banyan-tree" data-nid="12485923" data-subtype="crag">大榕树 Banyan Tree</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/twin-gates" data-nid="12485827" data-subtype="crag">同门山 Twin Gates</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/twin-gates/area/110766204" data-nid="110766204" data-subtype="cliff">Western Tower</a></li><li><a href="/zh_hans/climbing/china/yangshuo/twin-gates/area/2604920463" data-nid="2604920463" data-subtype="sector">South Face</a></li><li><a href="/zh_hans/climbing/china/yangshuo/twin-gates/area/2605087938" data-nid="2605087938" data-subtype="sector">East Wall</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/treasure-cave" data-nid="228693636" data-subtype="crag">四方山 Square Mountain</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/treasure-cave/area/1903943544" data-nid="1903943544" data-subtype="sector">Staircase Wall</a></li><li><a href="/zh_hans/climbing/china/yangshuo/treasure-cave/area/1903950588" data-nid="1903950588" data-subtype="sector">Treasure Cave</a></li><li><a href="/zh_hans/climbing/china/yangshuo/treasure-cave/area/1903953885" data-nid="1903953885" data-subtype="sector">Brother's Cave</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/bamboo-grove" data-nid="12486355" data-subtype="crag">竹林岩 Bamboo Grove</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/bamboo-grove/area/141790026" data-nid="141790026" data-subtype="sector">Main Wall</a></li><li><a href="/zh_hans/climbing/china/yangshuo/bamboo-grove/area/141790374" data-nid="141790374" data-subtype="sector">North Buttress</a></li></ul></li><li><a href="/zh_hans/climbing/china/yangshuo/area/8943810267" data-nid="8943810267" data-subtype="crag">黑洞 Black Cave</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/226859751" data-nid="226859751" data-subtype="crag">小马岩 Horse Crag</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/3215943306" data-nid="3215943306" data-subtype="area">高田镇 GaoTian</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/area/2500257144" data-nid="2500257144" data-subtype="crag">双面 Double Face</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/155668254" data-nid="155668254" data-subtype="crag">奥丁洞 Odin's Den</a></li><li><a href="/zh_hans/climbing/china/yangshuo/moon-hill" data-nid="12486043" data-subtype="crag">月亮山 Moon Hill</a></li><li><a href="/zh_hans/climbing/china/yangshuo/entreprises-crag" data-nid="155668278" data-subtype="crag">小雷劈 Entreprise's Crag</a></li><li><a href="/zh_hans/climbing/china/yangshuo/lei-pi-shan" data-nid="12486475" data-subtype="crag">雷劈山 Lei Pi Shan</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/12017352957" data-nid="12017352957" data-subtype="crag">The Political Wall</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/12871467699" data-nid="12871467699" data-subtype="crag">小月亮山 Little Moon Hill</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/8225248041" data-nid="8225248041" data-subtype="crag">空中拳击台 Boxing Ring in the Sky</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/5995572897" data-nid="5995572897" data-subtype="crag">洞田洞 Dongtian Cave (Thunder Cave)</a></li><li><a href="/zh_hans/climbing/china/yangshuo/silver-cave" data-nid="12486067" data-subtype="crag">银子岩 Silver Cave</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/8528465106" data-nid="8528465106" data-subtype="crag">龙村 Dragon Village</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/3215950074" data-nid="3215950074" data-subtype="area">太空站地区 Space Buttress Crags</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/chicken-cave" data-nid="12486283" data-subtype="crag">鸡窝渡 Chicken Cave</a></li><li><a href="/zh_hans/climbing/china/yangshuo/space-buttress" data-nid="12486427" data-subtype="crag">太空站 Space Buttress</a></li><li><a href="/zh_hans/climbing/china/yangshuo/low-mountain-area" data-nid="12485899" data-subtype="crag">矮山 Low Mountain</a></li><li><a href="/zh_hans/climbing/china/yangshuo/the-totem-pole" data-nid="167372361" data-subtype="crag">图腾柱 Totem Pole</a></li><li><a href="/zh_hans/climbing/china/yangshuo/dragon-city" data-nid="168240369" data-subtype="crag">龙城 Dragon City</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/24701133" data-nid="24701133" data-subtype="crag">驼头山 The Camel's Head</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/3215956269" data-nid="3215956269" data-subtype="area">田家河 TianJia River</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/area/24652710" data-nid="24652710" data-subtype="crag">新世界 Brave New World</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/227983992" data-nid="227983992" data-subtype="crag">竹帘洞 Bamboo Cave</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/12101808" data-nid="12101808" data-subtype="crag">大枪山 Big Gun Wall</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/3215962353" data-nid="3215962353" data-subtype="area">白山地区 White Mountain Crags</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/area/1950049383" data-nid="1950049383" data-subtype="crag">驼背山 Humpback Mountain</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/the-egg" data-nid="12486259" data-subtype="crag">鸡蛋山 The Egg</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/the-egg/area/13977805" data-nid="13977805" data-subtype="sector">East Face</a></li><li><a href="/zh_hans/climbing/china/yangshuo/the-egg/area/13977877" data-nid="13977877" data-subtype="sector">Fantasy Area</a></li><li><a href="/zh_hans/climbing/china/yangshuo/the-egg/area/13977829" data-nid="13977829" data-subtype="sector">The Northeast Face</a></li><li><a href="/zh_hans/climbing/china/yangshuo/the-egg/area/13977853" data-nid="13977853" data-subtype="sector">West Face</a></li></ul></li><li><a href="/zh_hans/climbing/china/yangshuo/area/24649662" data-nid="24649662" data-subtype="crag">禽人 Bird Man</a></li><li><a href="/zh_hans/climbing/china/yangshuo/wall-of-the-damned" data-nid="167392794" data-subtype="crag">起死回生墙 Wall of the Damned</a></li><li><a href="/zh_hans/climbing/china/yangshuo/white-mountain" data-nid="12486235" data-subtype="crag">白山 White Mountain</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/2500271802" data-nid="2500271802" data-subtype="crag">高龙洞 Area 51</a></li><li><a href="/zh_hans/climbing/china/yangshuo/kiddie-crag" data-nid="12486451" data-subtype="crag">Kiddie Crag</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/3215967837" data-nid="3215967837" data-subtype="area">思龙地区 SiLong Crags</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/riverside" data-nid="12486307" data-subtype="crag">思龙山 Riverside</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/577609713" data-nid="577609713" data-subtype="crag">老羊山 The Goat</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/1950040788" data-nid="1950040788" data-subtype="crag">飞镖山 Spearhead</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/1950040848" data-nid="1950040848" data-subtype="crag">糖厂 Sugar Factory</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/2204354874" data-nid="2204354874" data-subtype="cliff">The Tunnel</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/9185313522" data-nid="9185313522" data-subtype="crag">豚跃峰 Leaping Dolphin</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/607082343" data-nid="607082343" data-subtype="area">福利镇 FuLi</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/area/394118709" data-nid="394118709" data-subtype="crag">Orange Panties Wall</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/394118649" data-nid="394118649" data-subtype="crag">穿岩 Insight Cave</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/1925346510" data-nid="1925346510" data-subtype="crag">Festival Area</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/area/1925353440" data-nid="1925353440" data-subtype="sector">Sector 1</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/1925353512" data-nid="1925353512" data-subtype="sector">Sector 2</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/1925353584" data-nid="1925353584" data-subtype="sector">Sector 3</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/1925353656" data-nid="1925353656" data-subtype="sector">Sector 4</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/1925353728" data-nid="1925353728" data-subtype="sector">Sector 5</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/1925353800" data-nid="1925353800" data-subtype="sector">Sector 6</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/3215973288" data-nid="3215973288" data-subtype="area">葡萄镇 PuTao</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/area/228505788" data-nid="228505788" data-subtype="crag">白面山 Mini Krabi</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/11541177" data-nid="11541177" data-subtype="crag">长城 The Great Wall</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/2500265490" data-nid="2500265490" data-subtype="crag">瞭望塔 The Watchtower</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yangshuo/area/2203163067" data-nid="2203163067" data-subtype="area">兴坪镇 XingPing</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yangshuo/area/2203151337" data-nid="2203151337" data-subtype="crag">红岩门 Red Wall</a></li><li><a href="/zh_hans/climbing/china/yangshuo/area/2203159416" data-nid="2203159416" data-subtype="crag">九马画山 Nine Horse Mural Hill</a></li><li><a href="/zh_hans/climbing/china/yangshuo/xing-ping-the-camel" data-nid="12486211" data-subtype="crag">The Camel</a></li></ul></li></ul></li><li><a href="/zh_hans/climbing/china/guangxi/area/1971890997" data-nid="1971890997" data-subtype="crag">平乐青龙月亮山 Qinglong Arch</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/9194468745" data-nid="9194468745" data-subtype="area">恭城 Gongcheng</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/9202721829" data-nid="9202721829" data-subtype="area">火石谷 Fire stone valley</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/9202771992" data-nid="9202771992" data-subtype="crag">山地巨魔的鼓 Drums of the mountain troll</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/area/9202780068" data-nid="9202780068" data-subtype="cliff">小鼓 Little Drum</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/9202783170" data-nid="9202783170" data-subtype="cliff">大鼓 Big Drum</a></li></ul></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/liuzhou" data-nid="156253401" data-subtype="crag">柳州 Liuzhou</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/low-hill" data-nid="156255651" data-subtype="crag">矮山 Low Hill</a></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2423110200" data-nid="2423110200" data-subtype="crag">横山</a></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2423110074" data-nid="2423110074" data-subtype="crag">三门江</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2423066403" data-nid="2423066403" data-subtype="crag">独凳山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/lone-stool-hill-east" data-nid="156255723" data-subtype="sector">东面 East</a></li><li><a href="/zh_hans/climbing/china/guangxi/lone-stool-hill-north" data-nid="156255747" data-subtype="sector">北面 North</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/drum-hill" data-nid="156255699" data-subtype="crag">鼓山 Drum Hill</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/drum-hill/area/2427076785" data-nid="2427076785" data-subtype="sector">西南 SW</a></li><li><a href="/zh_hans/climbing/china/guangxi/drum-hill/area/2427076851" data-nid="2427076851" data-subtype="sector">北 N</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2423107116" data-nid="2423107116" data-subtype="crag">扛山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2427097035" data-nid="2427097035" data-subtype="sector">北 N</a></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2427097101" data-nid="2427097101" data-subtype="sector">南 S</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2423110140" data-nid="2423110140" data-subtype="crag">银山</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2423104329" data-nid="2423104329" data-subtype="crag">茶壶山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2427176412" data-nid="2427176412" data-subtype="sector">东南洞口</a></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2427176280" data-nid="2427176280" data-subtype="sector">东 E</a></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/5330080767" data-nid="5330080767" data-subtype="area">北 N</a></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2427176346" data-nid="2427176346" data-subtype="sector">半山穿洞</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2423105331" data-nid="2423105331" data-subtype="crag">犀牛山</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/white-lotus-spring" data-nid="156255675" data-subtype="crag">白莲泉 White Lotus Spring</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/white-lotus-spring/area/5575898715" data-nid="5575898715" data-subtype="crag">东南面岩场</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/2349741273" data-nid="2349741273" data-subtype="crag">镜子山 The Mirror Mountain</a></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/3841621800" data-nid="3841621800" data-subtype="crag">箭盘山</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/8414835795" data-nid="8414835795" data-subtype="crag">敏洞山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/8414843712" data-nid="8414843712" data-subtype="cliff">蜂巢区</a></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/8414843790" data-nid="8414843790" data-subtype="cliff">风帆区</a></li><li><a href="/zh_hans/climbing/china/guangxi/liuzhou/area/8414843856" data-nid="8414843856" data-subtype="cliff">宝藏区</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/2143379343" data-nid="2143379343" data-subtype="area">马山 MaShan</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/2143383429" data-nid="2143383429" data-subtype="crag">金刚山 / King Kong Mountain</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/area/2143507167" data-nid="2143507167" data-subtype="sector">B</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2143507101" data-nid="2143507101" data-subtype="sector">A</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177421888" data-nid="2177421888" data-subtype="sector">A区右侧二楼</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177422503" data-nid="2177422503" data-subtype="sector">Right End</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/2143383489" data-nid="2143383489" data-subtype="crag">干娘山 / Foster Mother Mountain</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/area/2143452780" data-nid="2143452780" data-subtype="sector">A</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2143452846" data-nid="2143452846" data-subtype="sector">大洞 Cave</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2143452912" data-nid="2143452912" data-subtype="sector">B</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2143452978" data-nid="2143452978" data-subtype="sector">C</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2143453044" data-nid="2143453044" data-subtype="sector">D</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangxi/area/2143383549" data-nid="2143383549" data-subtype="crag">干爹山 / Foster Father Mountain</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2143383609" data-nid="2143383609" data-subtype="crag">螃蟹山 / Crab Mountain</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/2143383669" data-nid="2143383669" data-subtype="crag">万铁山 / Iron Mountain</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/area/2143406448" data-nid="2143406448" data-subtype="cliff">A B</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2143406520" data-nid="2143406520" data-subtype="cliff">C</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangxi/area/2143383729" data-nid="2143383729" data-subtype="crag">攀成山 / PanCheng Mountain</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177445438" data-nid="2177445438" data-subtype="crag">内环 / nèi huán</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177445498" data-nid="2177445498" data-subtype="crag">他卜 / Tā bo</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177445378" data-nid="2177445378" data-subtype="crag">金童山 / Golden Boy Mountain</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2143383789" data-nid="2143383789" data-subtype="crag">玉女山 / Jade Girl Mountain</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177443212" data-nid="2177443212" data-subtype="crag">板必半山 / Half Hill</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177445318" data-nid="2177445318" data-subtype="crag">板必香槟山 / Champagne Hill</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177445558" data-nid="2177445558" data-subtype="crag">羊山村A / Goat Hill Village A</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177447511" data-nid="2177447511" data-subtype="crag">羊山村陇供屯 / Goat Hill Village</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177447571" data-nid="2177447571" data-subtype="crag">外英灵阳寺/ Wai Ying Lingyang Temple</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/2152445259" data-nid="2152445259" data-subtype="crag">狮子洞 / Lion Cave</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/area/2152445976" data-nid="2152445976" data-subtype="sector">左区 / Left area</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2152446042" data-nid="2152446042" data-subtype="sector">底部 / Bottom</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2152446108" data-nid="2152446108" data-subtype="sector">右区 / Right area</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangxi/area/2306497215" data-nid="2306497215" data-subtype="crag">乐平村 / Leping Village</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/2177443092" data-nid="2177443092" data-subtype="crag">才支 / Talent</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/area/2177443152" data-nid="2177443152" data-subtype="crag">小金猫洞 / Little Golden Cat Cave</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2306420355" data-nid="2306420355" data-subtype="crag">1</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2306420421" data-nid="2306420421" data-subtype="crag">2</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2306420487" data-nid="2306420487" data-subtype="crag">3</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177443032" data-nid="2177443032" data-subtype="crag">凤凰山 / Phoenix Mountain</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/2177442972" data-nid="2177442972" data-subtype="crag">八椅山 / Eight Chair Mountain</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/nanning" data-nid="2145370758" data-subtype="area">南宁 Nanning</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/nanning/area/9353715234" data-nid="9353715234" data-subtype="crag">武鸣旧岑村</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/red-crag" data-nid="156254571" data-subtype="crag">红岩周边 Red Crag</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/red-crag/area/2145315573" data-nid="2145315573" data-subtype="cliff">红岩</a></li><li><a href="/zh_hans/climbing/china/guangxi/red-crag/area/5952740064" data-nid="5952740064" data-subtype="area">炸弹坑</a></li><li><a href="/zh_hans/climbing/china/guangxi/red-crag/area/2145315645" data-nid="2145315645" data-subtype="cliff">独石</a></li><li><a href="/zh_hans/climbing/china/guangxi/red-crag/area/2145315717" data-nid="2145315717" data-subtype="cliff">天门</a></li><li><a href="/zh_hans/climbing/china/guangxi/red-crag/area/2145315783" data-nid="2145315783" data-subtype="cliff">油站</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/rear-hill" data-nid="156254595" data-subtype="crag">后山周边 Rear Hill</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/rear-hill/area/2145329655" data-nid="2145329655" data-subtype="cliff">大岩壁</a></li><li><a href="/zh_hans/climbing/china/guangxi/rear-hill/area/4708921380" data-nid="4708921380" data-subtype="cliff">大洞 Cave</a></li><li><a href="/zh_hans/climbing/china/guangxi/rear-hill/area/2145329727" data-nid="2145329727" data-subtype="cliff">后山</a></li><li><a href="/zh_hans/climbing/china/guangxi/rear-hill/area/2145329799" data-nid="2145329799" data-subtype="cliff">热身墙</a></li><li><a href="/zh_hans/climbing/china/guangxi/rear-hill/area/5901550803" data-nid="5901550803" data-subtype="area">停车场对面</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangxi/front-hill" data-nid="156254619" data-subtype="crag">前山 Front Hill</a></li><li><a href="/zh_hans/climbing/china/guangxi/honeybee-cave" data-nid="156254643" data-subtype="crag">蜜蜂洞 Honeybee Cave</a></li><li><a href="/zh_hans/climbing/china/guangxi/nanning/area/4888045776" data-nid="4888045776" data-subtype="crag">P5</a></li><li><a href="/zh_hans/climbing/china/guangxi/nanning/area/5970345765" data-nid="5970345765" data-subtype="area">敢庚</a></li><li><a href="/zh_hans/climbing/china/guangxi/nanning/area/5970348792" data-nid="5970348792" data-subtype="area">那广</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/beiliu" data-nid="156253449" data-subtype="crag">北流 BeiLiu</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/zoo-crag" data-nid="156259941" data-subtype="crag">动物园岩场 Zoo Crag</a></li><li><a href="/zh_hans/climbing/china/guangxi/beiliu/area/2349684612" data-nid="2349684612" data-subtype="crag">铜石岭</a></li><li><a href="/zh_hans/climbing/china/guangxi/beiliu/area/2349694662" data-nid="2349694662" data-subtype="crag">勾漏洞大屋檐</a></li><li><a href="/zh_hans/climbing/china/guangxi/beiliu/area/5575748184" data-nid="5575748184" data-subtype="crag">风神庙</a></li><li><a href="/zh_hans/climbing/china/guangxi/beiliu/area/5575752396" data-nid="5575752396" data-subtype="crag">莲花山</a></li><li><a href="/zh_hans/climbing/china/guangxi/beiliu/area/5575758441" data-nid="5575758441" data-subtype="crag">独竹</a></li><li><a href="/zh_hans/climbing/china/guangxi/beiliu/area/5575762212" data-nid="5575762212" data-subtype="crag">蜂窝</a></li></ul></li><li><a href="/zh_hans/climbing/china/guangxi/area/3216513684" data-nid="3216513684" data-subtype="crag">灵山燕子洞</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/9063051402" data-nid="9063051402" data-subtype="area">凤山 Fengshan</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/area/9073350015" data-nid="9073350015" data-subtype="crag">穿龙岩 Chuan Dragon Cave</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/10098621027" data-nid="10098621027" data-subtype="cliff">魔猴山 Magic Monkey Wall</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guangxi/area/9723383133" data-nid="9723383133" data-subtype="crag">社更穿洞 Shegeng Cave</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guangxi/area/9969887574" data-nid="9969887574" data-subtype="cliff">西侧墙</a></li><li><a href="/zh_hans/climbing/china/guangxi/area/9969889839" data-nid="9969889839" data-subtype="cliff">东侧墙</a></li></ul></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="154039992" href="/zh_hans/climbing/china/guizhou" class=""><span class="primary-node-name">贵州 Guizhou</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guizhou/area/1812608817" data-nid="1812608817" data-subtype="area">六盘水 Liupanshui</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guizhou/area/1812611553" data-nid="1812611553" data-subtype="crag">牛鼻洞</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guizhou/area/8080415733" data-nid="8080415733" data-subtype="sector">洞口</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/8080417317" data-nid="8080417317" data-subtype="sector">洞中</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/8080417383" data-nid="8080417383" data-subtype="sector">洞外</a></li></ul></li><li><a href="/zh_hans/climbing/china/guizhou/area/1812609852" data-nid="1812609852" data-subtype="crag">核桃树</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/1812609912" data-nid="1812609912" data-subtype="crag">独山</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/1812609972" data-nid="1812609972" data-subtype="crag">C</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/1812610032" data-nid="1812610032" data-subtype="crag">D</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/5014203972" data-nid="5014203972" data-subtype="crag">望雕崖</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/5014204032" data-nid="5014204032" data-subtype="crag">马蹄谷</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/5141145009" data-nid="5141145009" data-subtype="crag">步步高升</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/8381018520" data-nid="8381018520" data-subtype="area">双洞村</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/9354447750" data-nid="9354447750" data-subtype="crag">郭家洞</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guizhou/area/7847536854" data-nid="7847536854" data-subtype="area">安顺市</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/getu" data-nid="154038642" data-subtype="area">格凸 Getu</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/getu/fish-crag" data-nid="155642268" data-subtype="crag">Fish Crag</a></li><li><a href="/zh_hans/climbing/china/getu/left-of-red" data-nid="155642292" data-subtype="crag">Left of Red</a></li><li><a href="/zh_hans/climbing/china/getu/wawans-cave" data-nid="155642316" data-subtype="crag">Wawan's Cave</a></li><li><a href="/zh_hans/climbing/china/getu/olivers-crag" data-nid="155642340" data-subtype="cliff">Oliver's Crag</a></li><li><a href="/zh_hans/climbing/china/getu/rastaman-crag" data-nid="155642364" data-subtype="crag">Rastaman Crag</a></li><li><a href="/zh_hans/climbing/china/getu/pussa-yan" data-nid="155643591" data-subtype="crag">Pussa Yan</a></li><li><a href="/zh_hans/climbing/china/getu/white-crag" data-nid="155643615" data-subtype="crag">White Crag</a></li><li><a href="/zh_hans/climbing/china/getu/cmdi-crags-cmdi" data-nid="155643639" data-subtype="crag">CMDI Crags</a></li><li><a href="/zh_hans/climbing/china/getu/banyangs-cave" data-nid="155752041" data-subtype="crag">Banyang's Cave</a></li><li><a href="/zh_hans/climbing/china/getu/lazy-dragon-cave" data-nid="155643687" data-subtype="crag">Lazy Dragon Cave</a></li><li><a href="/zh_hans/climbing/china/getu/flag-cliff" data-nid="155644914" data-subtype="crag">Flag Cliff</a></li><li><a href="/zh_hans/climbing/china/getu/buddha-cave" data-nid="155644938" data-subtype="crag">Buddha Cave</a></li><li><a href="/zh_hans/climbing/china/getu/school-time" data-nid="155644962" data-subtype="crag">School Time</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/getu/great-arch" data-nid="2267986266" data-subtype="crag">Great Arch</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/getu/great-arch-left-side" data-nid="155644986" data-subtype="sector">Left Side</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/getu/great-arch-left-side/area/2268010653" data-nid="2268010653" data-subtype="sector">Valhalla</a></li></ul></li><li><a href="/zh_hans/climbing/china/getu/great-arch-right-side" data-nid="155645010" data-subtype="sector">Right Side</a></li></ul></li><li><a href="/zh_hans/climbing/china/getu/lower-arch" data-nid="156172089" data-subtype="crag">The Lower Arch</a></li><li><a href="/zh_hans/climbing/china/getu/miao-sword" data-nid="155645034" data-subtype="crag">Miao Sword</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guizhou/area/3681574311" data-nid="3681574311" data-subtype="area">安顺抱石</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guizhou/area/5543079855" data-nid="5543079855" data-subtype="field">A区</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/5543081187" data-nid="5543081187" data-subtype="area">B区</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/5543081247" data-nid="5543081247" data-subtype="area">C区</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/5543081307" data-nid="5543081307" data-subtype="area">D区</a></li></ul></li><li><a href="/zh_hans/climbing/china/guizhou/area/5759746212" data-nid="5759746212" data-subtype="crag">龙宫龙字田岩场</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guizhou/area/7847536800" data-nid="7847536800" data-subtype="area">贵阳市</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guizhou/area/2349761241" data-nid="2349761241" data-subtype="crag">贵惠穿洞关</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guizhou/area/6900701778" data-nid="6900701778" data-subtype="area">贵阳花溪高坡</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guizhou/area/6900723315" data-nid="6900723315" data-subtype="cliff">运动攀区域</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/6900728325" data-nid="6900728325" data-subtype="field">抱石区域</a></li></ul></li><li><a href="/zh_hans/climbing/china/guizhou/area/3156233301" data-nid="3156233301" data-subtype="crag">百花湖下麦城村岩场</a></li><li><a href="/zh_hans/climbing/china/guizhou/guiyang-government" data-nid="156266637" data-subtype="crag">贵阳市省政府 Guiyang Government</a></li><li><a href="/zh_hans/climbing/china/guizhou/area/7945272870" data-nid="7945272870" data-subtype="area">情人谷岩场</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guizhou/area/7847579640" data-nid="7847579640" data-subtype="area">黔南州</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guizhou/yang-jia-zhai" data-nid="156266661" data-subtype="crag">贵定县杨家寨 Yang Jia Zhai</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guizhou/fish-pond-crag" data-nid="156267870" data-subtype="crag">鱼塘岩壁 Fish Pond Crag</a></li><li><a href="/zh_hans/climbing/china/guizhou/white-dragon-cave" data-nid="156267894" data-subtype="crag">白龙洞 White Dragon Cave</a></li></ul></li><li><a href="/zh_hans/climbing/china/guizhou/ya-di-village" data-nid="156266685" data-subtype="crag">贵定县崖底村 Ya Di Village</a></li><li><a href="/zh_hans/climbing/china/guizhou/bo-ji-zhai" data-nid="156266709" data-subtype="crag">都匀市簸箕寨 Bo Ji Zhai</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guizhou/area/11713847736" data-nid="11713847736" data-subtype="area">遵义Zunyi</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guizhou/storm-hill" data-nid="156266733" data-subtype="crag">风暴山 Storm Hill</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="3210699621" href="/zh_hans/climbing/china/area/3210699621" class=""><span class="primary-node-name">海南 Hainan</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/3449930418" data-nid="3449930418" data-subtype="crag">三亚落笔洞</a></li><li><a href="/zh_hans/climbing/china/area/6088596423" data-nid="6088596423" data-subtype="field">石头公园</a></li><li><a href="/zh_hans/climbing/china/area/6025620423" data-nid="6025620423" data-subtype="field">琼海白石岭</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/12371906487" data-nid="12371906487" data-subtype="area">万宁地区 Wanning area</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/9081617514" data-nid="9081617514" data-subtype="field">日月湾海边岩场</a></li><li><a href="/zh_hans/climbing/china/area/6036079830" data-nid="6036079830" data-subtype="crag">南燕湾</a></li><li><a href="/zh_hans/climbing/china/area/9134377149" data-nid="9134377149" data-subtype="field">南燕海边岩场</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/6039004968" data-nid="6039004968" data-subtype="area">神州半岛</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/6039010641" data-nid="6039010641" data-subtype="crag">第一湾</a></li><li><a href="/zh_hans/climbing/china/area/6071252046" data-nid="6071252046" data-subtype="area">四湾</a></li><li><a href="/zh_hans/climbing/china/area/6220817073" data-nid="6220817073" data-subtype="area">二湾三湾</a></li></ul></li></ul></li><li><a href="/zh_hans/climbing/china/area/5803751907" data-nid="5803751907" data-subtype="gym">道博攀岩馆</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/12626628129" data-nid="12626628129" data-subtype="field">陵水 香水湾10号沙滩</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/12626637570" data-nid="12626637570" data-subtype="field">香水湾10号沙滩</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="1887976938" href="/zh_hans/climbing/china/area/1887976938" class=""><span class="primary-node-name">河北 Hebei</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/8599764009" data-nid="8599764009" data-subtype="crag">邢台魔石岩场</a></li><li><a href="/zh_hans/climbing/china/area/2596275975" data-nid="2596275975" data-subtype="crag">唐山半壁山</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3226818069" data-nid="3226818069" data-subtype="area">秦皇岛</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3226854429" data-nid="3226854429" data-subtype="area">祖山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/3226825143" data-nid="3226825143" data-subtype="crag">花场峪岩场</a></li><li><a href="/zh_hans/climbing/china/area/3226825209" data-nid="3226825209" data-subtype="crag">观瀑台岩场</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/3226825275" data-nid="3226825275" data-subtype="field">北戴河海滨鸽子窝</a></li><li><a href="/zh_hans/climbing/china/area/3964150578" data-nid="3964150578" data-subtype="crag">花果山龙吐天浆冰瀑</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3737361855" data-nid="3737361855" data-subtype="crag">冰山梁 Bing Shan Liang</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/7839037209" data-nid="7839037209" data-subtype="crag">冰山梁景区</a></li><li><a href="/zh_hans/climbing/china/area/7839008373" data-nid="7839008373" data-subtype="crag">北京Alpine</a></li><li><a href="/zh_hans/climbing/china/area/7839045756" data-nid="7839045756" data-subtype="crag">主峰</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3844490946" data-nid="3844490946" data-subtype="area">小五台 Xiaowutai Mountain</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/3844492947" data-nid="3844492947" data-subtype="crag">未命名冰壁1</a></li><li><a href="/zh_hans/climbing/china/area/3844493649" data-nid="3844493649" data-subtype="crag">未命名冰壁2</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/4507911231" data-nid="4507911231" data-subtype="area">邯郸鼓山</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/4906488339" data-nid="4906488339" data-subtype="area">张家口</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/4906418613" data-nid="4906418613" data-subtype="crag">崇礼马丈子</a></li><li><a href="/zh_hans/climbing/china/area/4906508997" data-nid="4906508997" data-subtype="crag">桥西区马家梁</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/4987179390" data-nid="4987179390" data-subtype="crag">兴隆雾灵山仙人塔</a></li><li><a href="/zh_hans/climbing/china/area/1887982308" data-nid="1887982308" data-subtype="crag">冻凌背</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="154040040" href="/zh_hans/climbing/china/others" class=""><span class="primary-node-name">黑龙江 Heilongjiang</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/others/area/3450067578" data-nid="3450067578" data-subtype="area">哈尔滨 Harbin</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/others/area/3450140112" data-nid="3450140112" data-subtype="crag">平山岩场</a></li><li><a href="/zh_hans/climbing/china/others/area/3450397185" data-nid="3450397185" data-subtype="area">红石岩场</a></li><li><a href="/zh_hans/climbing/china/others/area/4906855347" data-nid="4906855347" data-subtype="crag">帽儿山</a></li><li><a href="/zh_hans/climbing/china/others/area/4906871373" data-nid="4906871373" data-subtype="crag">松峰山一线天</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="829117677" href="/zh_hans/climbing/china/area/829117677" class=""><span class="primary-node-name">河南 Henan</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guoliang-nanping" data-nid="829118673" data-subtype="area">万仙山 Wanxian Mountains</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guoliang-nanping/area/2527831224" data-nid="2527831224" data-subtype="area">红岩峡谷 Red Rock Canyon</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/2528211816" data-nid="2528211816" data-subtype="sector">通天塔 Tower of Babel</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guoliang-nanping/area/2529807309" data-nid="2529807309" data-subtype="area">郭亮隧道 Guoliang Tunnel</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guoliang-nanping/east-of-guo-liang-cave" data-nid="156071697" data-subtype="crag">郭亮洞以西 Left of Guo Liang Cave</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/guo-liang-cave" data-nid="156071721" data-subtype="crag">郭亮洞 Guo Liang Cave</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/across-from-guo-liang-cave" data-nid="156071745" data-subtype="crag">郭亮洞以东 Right of Guo Liang Cave</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/1689512598" data-nid="1689512598" data-subtype="sector">隧道墙 Tunnel Wall</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guoliang-nanping/area/1689477279" data-nid="1689477279" data-subtype="crag">通天河 Tong Tian He</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/2528063517" data-nid="2528063517" data-subtype="sector">O区</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/2528074428" data-nid="2528074428" data-subtype="sector">N区(河沟二层)</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/thick-slab" data-nid="2528099934" data-subtype="sector">M区(河沟里)</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/2528100630" data-nid="2528100630" data-subtype="sector">L区(停车场对面大岩壁)</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/2528100702" data-nid="2528100702" data-subtype="sector">K区(停车场对面大岩壁)</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/3901692264" data-nid="3901692264" data-subtype="cliff">停车场区</a></li></ul></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/generals-tower" data-nid="156071769" data-subtype="crag">将军峰 The Generals Peak</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guoliang-nanping/area/2528231655" data-nid="2528231655" data-subtype="crag">黑龙潭</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guoliang-nanping/zhuang-ao" data-nid="2528232285" data-subtype="sector">R区</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/crevice-corner" data-nid="2528232351" data-subtype="sector">Q区</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/2528232417" data-nid="2528232417" data-subtype="sector">P区</a></li></ul></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/2529029265" data-nid="2529029265" data-subtype="cliff">友谊峰 Friendship Peak</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/bottle-cliff" data-nid="156071817" data-subtype="crag">瓶子墙 Bottle Cliff</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/gate-cliff" data-nid="156071889" data-subtype="crag">大门墙 Gate Cliff</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/2529972708" data-nid="2529972708" data-subtype="cliff">丹分沟 Red Ravine</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/guoliang-nanping/area/3481330467" data-nid="3481330467" data-subtype="field">龙潭沟</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/3482776365" data-nid="3482776365" data-subtype="sector">A</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/3482776431" data-nid="3482776431" data-subtype="sector">B</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/3482776497" data-nid="3482776497" data-subtype="sector">C</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/3482776563" data-nid="3482776563" data-subtype="sector">D</a></li><li><a href="/zh_hans/climbing/china/guoliang-nanping/area/3482776629" data-nid="3482776629" data-subtype="sector">E</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2626953804" data-nid="2626953804" data-subtype="area">登封</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2326714638" data-nid="2326714638" data-subtype="crag">龙景</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2626868811" data-nid="2626868811" data-subtype="cliff">大岩壁</a></li><li><a href="/zh_hans/climbing/china/area/2626868871" data-nid="2626868871" data-subtype="cliff">一区</a></li><li><a href="/zh_hans/climbing/china/area/2626868931" data-nid="2626868931" data-subtype="cliff">二区</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2626865250" data-nid="2626865250" data-subtype="crag">老张沟一线天</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2626871679" data-nid="2626871679" data-subtype="sector">A</a></li><li><a href="/zh_hans/climbing/china/area/2626871739" data-nid="2626871739" data-subtype="sector">B</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/4273282494" data-nid="4273282494" data-subtype="crag">待仙沟(大仙沟庙)</a></li><li><a href="/zh_hans/climbing/china/area/10598215323" data-nid="10598215323" data-subtype="area">悠然农场（挡阳山）</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/3140846121" data-nid="3140846121" data-subtype="crag">安阳林州黑龙潭冰瀑</a></li><li><a href="/zh_hans/climbing/china/area/6897375144" data-nid="6897375144" data-subtype="crag">洛阳下岸岩场</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="1834779138" href="/zh_hans/climbing/china/area/1834779138" class=""><span class="primary-node-name">湖北 Hubei</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2751704211" data-nid="2751704211" data-subtype="area">黄石</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2783729763" data-nid="2783729763" data-subtype="crag">草甸</a></li><li><a href="/zh_hans/climbing/china/area/2783735352" data-nid="2783735352" data-subtype="crag">李家坊</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/1834908783" data-nid="1834908783" data-subtype="crag">西洞</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2762110719" data-nid="2762110719" data-subtype="unknown">右墙</a></li><li><a href="/zh_hans/climbing/china/area/2762113689" data-nid="2762113689" data-subtype="unknown">左墙</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/2309050644" data-nid="2309050644" data-subtype="crag">黄钻</a></li><li><a href="/zh_hans/climbing/china/area/2366887404" data-nid="2366887404" data-subtype="crag">蓝钻</a></li><li><a href="/zh_hans/climbing/china/area/1834908729" data-nid="1834908729" data-subtype="crag">白塔岩</a></li><li><a href="/zh_hans/climbing/china/area/2349817497" data-nid="2349817497" data-subtype="crag">小雷山</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2751704265" data-nid="2751704265" data-subtype="area">咸宁</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2349826668" data-nid="2349826668" data-subtype="crag">挂榜山</a></li><li><a href="/zh_hans/climbing/china/area/1834850115" data-nid="1834850115" data-subtype="crag">鸣水泉</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/8762462322" data-nid="8762462322" data-subtype="crag">吕仙洞</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/12008524074" data-nid="12008524074" data-subtype="area">抱石线路</a></li><li><a href="/zh_hans/climbing/china/area/12008583561" data-nid="12008583561" data-subtype="area">运动攀线路</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/8762494224" data-nid="8762494224" data-subtype="crag">星星竹海</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/12437628714" data-nid="12437628714" data-subtype="field">奇石林</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/12437943828" data-nid="12437943828" data-subtype="field">入口区域</a></li><li><a href="/zh_hans/climbing/china/area/12437842500" data-nid="12437842500" data-subtype="field">火焰山</a></li><li><a href="/zh_hans/climbing/china/area/12437950710" data-nid="12437950710" data-subtype="field">山顶区域</a></li></ul></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3194704767" data-nid="3194704767" data-subtype="area">恩施 Enshi</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/4606962960" data-nid="4606962960" data-subtype="area">咸丰 Xianfeng</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/4606913166" data-nid="4606913166" data-subtype="crag">瓦窑沟</a></li><li><a href="/zh_hans/climbing/china/area/4606916373" data-nid="4606916373" data-subtype="crag">湾田八角庙</a></li><li><a href="/zh_hans/climbing/china/area/4606917858" data-nid="4606917858" data-subtype="crag">丁寨魏家堡 夏之谷</a></li><li><a href="/zh_hans/climbing/china/area/4788009762" data-nid="4788009762" data-subtype="crag">丁寨 春之⾕</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/8762651286" data-nid="8762651286" data-subtype="area">利川</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/8762657238" data-nid="8762657238" data-subtype="crag">小溪河牡丹岩场</a></li><li><a href="/zh_hans/climbing/china/area/8762657310" data-nid="8762657310" data-subtype="crag">岩洞湾岩场</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3200817606" data-nid="3200817606" data-subtype="area">襄阳</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3202279752" data-nid="3202279752" data-subtype="area">谷城南河</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/3202287702" data-nid="3202287702" data-subtype="crag">龙兴岩场</a></li><li><a href="/zh_hans/climbing/china/area/6183201834" data-nid="6183201834" data-subtype="crag">龙兴岩场B区</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/3202593075" data-nid="3202593075" data-subtype="area">南漳小三峡</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/8762585667" data-nid="8762585667" data-subtype="area">宜昌</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/3681329334" data-nid="3681329334" data-subtype="crag">宜昌蜘蛛洞</a></li><li><a href="/zh_hans/climbing/china/area/3944568192" data-nid="3944568192" data-subtype="crag">宜昌三峡崖刻</a></li><li><a href="/zh_hans/climbing/china/area/8762615064" data-nid="8762615064" data-subtype="crag">下牢溪</a></li><li><a href="/zh_hans/climbing/china/area/8762625252" data-nid="8762625252" data-subtype="crag">普溪河</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="1834892718" href="/zh_hans/climbing/china/area/1834892718" class=""><span class="primary-node-name">湖南 Hunan</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/1834903332" data-nid="1834903332" data-subtype="crag">张家界槟榔谷</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/1837914009" data-nid="1837914009" data-subtype="crag">东岸</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/1837938312" data-nid="1837938312" data-subtype="sector">水牛区</a></li><li><a href="/zh_hans/climbing/china/area/1837938378" data-nid="1837938378" data-subtype="sector">洞外左区</a></li><li><a href="/zh_hans/climbing/china/area/1837938444" data-nid="1837938444" data-subtype="sector">槟榔孔</a></li><li><a href="/zh_hans/climbing/china/area/1837938576" data-nid="1837938576" data-subtype="sector">洞外右区</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/1837914069" data-nid="1837914069" data-subtype="crag">西岸</a></li><li><a href="/zh_hans/climbing/china/area/1837914129" data-nid="1837914129" data-subtype="crag">教堂门</a></li><li><a href="/zh_hans/climbing/china/area/1837972773" data-nid="1837972773" data-subtype="crag">天使之城</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/1834903386" data-nid="1834903386" data-subtype="crag">慈利渔泉溪</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/1834913832" data-nid="1834913832" data-subtype="crag">娄底湄江</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/1877799474" data-nid="1877799474" data-subtype="crag">三道岩门</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/1877815620" data-nid="1877815620" data-subtype="cliff">A</a></li><li><a href="/zh_hans/climbing/china/area/1877815686" data-nid="1877815686" data-subtype="cliff">B</a></li><li><a href="/zh_hans/climbing/china/area/1877815752" data-nid="1877815752" data-subtype="cliff">C</a></li><li><a href="/zh_hans/climbing/china/area/1877815818" data-nid="1877815818" data-subtype="cliff">D</a></li><li><a href="/zh_hans/climbing/china/area/1877815884" data-nid="1877815884" data-subtype="cliff">E</a></li><li><a href="/zh_hans/climbing/china/area/1877815950" data-nid="1877815950" data-subtype="cliff">F</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/1877799534" data-nid="1877799534" data-subtype="crag">塞海湖</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/1877799594" data-nid="1877799594" data-subtype="crag">十里画壁</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/1877800791" data-nid="1877800791" data-subtype="cliff">A</a></li><li><a href="/zh_hans/climbing/china/area/1877800857" data-nid="1877800857" data-subtype="cliff">B</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2949882600" data-nid="2949882600" data-subtype="crag">郴州穿岩岭</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/12345280044" data-nid="12345280044" data-subtype="cliff">外墙一区</a></li><li><a href="/zh_hans/climbing/china/area/12345952653" data-nid="12345952653" data-subtype="cliff">外墙二区</a></li><li><a href="/zh_hans/climbing/china/area/12345968175" data-nid="12345968175" data-subtype="cliff">水洞一楼</a></li><li><a href="/zh_hans/climbing/china/area/12345969972" data-nid="12345969972" data-subtype="cliff">水洞二楼</a></li><li><a href="/zh_hans/climbing/china/area/12345972324" data-nid="12345972324" data-subtype="cliff">河对面</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/7286682096" data-nid="7286682096" data-subtype="crag">宁乡黄材岩场</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="2620411416" href="/zh_hans/climbing/china/area/2620411416" class=""><span class="primary-node-name">内蒙古 Inner Mongolia</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2620431309" data-nid="2620431309" data-subtype="crag">石条山</a></li><li><a href="/zh_hans/climbing/china/others/bo-long-ke" data-nid="156076527" data-subtype="crag">赤峰勃隆克</a></li><li><a href="/zh_hans/climbing/china/area/2349786924" data-nid="2349786924" data-subtype="crag">呼和浩特红召</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3964239393" data-nid="3964239393" data-subtype="area">大青山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/3964247127" data-nid="3964247127" data-subtype="crag">干沟</a></li><li><a href="/zh_hans/climbing/china/area/3964252404" data-nid="3964252404" data-subtype="crag">哈拉沁沟</a></li><li><a href="/zh_hans/climbing/china/area/9194964603" data-nid="9194964603" data-subtype="crag">陈梨窑水库</a></li><li><a href="/zh_hans/climbing/china/area/9194966883" data-nid="9194966883" data-subtype="crag">土右旗楼房沟</a></li><li><a href="/zh_hans/climbing/china/area/9194970636" data-nid="9194970636" data-subtype="crag">土右旗沙图沟</a></li><li><a href="/zh_hans/climbing/china/area/9194978154" data-nid="9194978154" data-subtype="crag">土左旗六道坝沟</a></li><li><a href="/zh_hans/climbing/china/area/9194995158" data-nid="9194995158" data-subtype="crag">豹榆沟</a></li><li><a href="/zh_hans/climbing/china/area/9195002055" data-nid="9195002055" data-subtype="crag">包头梅力更景区</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/3966456813" data-nid="3966456813" data-subtype="crag">土左旗楼房沟</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="2338915134" href="/zh_hans/climbing/china/area/2338915134" class=""><span class="primary-node-name">辽宁 Liaoning</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/6030935211" data-nid="6030935211" data-subtype="area">沈阳</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/6017486589" data-nid="6017486589" data-subtype="crag">棋盘山老虎口岩场</a></li><li><a href="/zh_hans/climbing/china/area/6033359487" data-nid="6033359487" data-subtype="crag">棋盘山4号岩场</a></li><li><a href="/zh_hans/climbing/china/area/6033388044" data-nid="6033388044" data-subtype="crag">棋盘山5号岩场</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2349776163" data-nid="2349776163" data-subtype="area">大连</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2349776718" data-nid="2349776718" data-subtype="crag">小黑山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2637507978" data-nid="2637507978" data-subtype="cliff">主峰</a></li><li><a href="/zh_hans/climbing/china/area/2637508044" data-nid="2637508044" data-subtype="cliff">侧峰</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/2349776784" data-nid="2349776784" data-subtype="crag">星海公园</a></li><li><a href="/zh_hans/climbing/china/area/2349776850" data-nid="2349776850" data-subtype="crag">燕窝岭</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/6209491590" data-nid="6209491590" data-subtype="area">鞍山</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/6209495028" data-nid="6209495028" data-subtype="crag">骆驼山岩场</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/6209499786" data-nid="6209499786" data-subtype="cliff">东峰后老伴</a></li><li><a href="/zh_hans/climbing/china/area/6209496198" data-nid="6209496198" data-subtype="cliff">西峰骑风口</a></li><li><a href="/zh_hans/climbing/china/area/6209496882" data-nid="6209496882" data-subtype="cliff">西峰西矿洞</a></li><li><a href="/zh_hans/climbing/china/area/6209498493" data-nid="6209498493" data-subtype="cliff">西峰中矿洞</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/2338915836" data-nid="2338915836" data-subtype="crag">与鹰共舞岩场</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/10594163277" data-nid="10594163277" data-subtype="crag">本溪榆树下</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3439706169" data-nid="3439706169" data-subtype="crag">辽阳</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/6206521671" data-nid="6206521671" data-subtype="crag">核伙沟</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/6187779999" data-nid="6187779999" data-subtype="crag">核伙沟1号岩场</a></li><li><a href="/zh_hans/climbing/china/area/6187782552" data-nid="6187782552" data-subtype="crag">核伙沟2号岩场</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/6136318323" data-nid="6136318323" data-subtype="crag">小屯岩场</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/6045716817" data-nid="6045716817" data-subtype="area">铁岭</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/6045717420" data-nid="6045717420" data-subtype="crag">驼峰岩场</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/4906598337" data-nid="4906598337" data-subtype="crag">义县碾盘沟圣旨峰岩场</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3914380821" data-nid="3914380821" data-subtype="crag">葫芦岛市建昌县</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/3972109554" data-nid="3972109554" data-subtype="crag">枣木杠户外探险公园</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/3963991929" data-nid="3963991929" data-subtype="crag">丹东响水寺冰瀑</a></li><li><a href="/zh_hans/climbing/china/area/3830749602" data-nid="3830749602" data-subtype="cliff">本溪滴水湖冰瀑</a></li><li><a href="/zh_hans/climbing/china/area/2338915896" data-nid="2338915896" data-subtype="crag">本溪南甸</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="831280560" href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill" class=""><span class="primary-node-name">江苏 Jiangsu</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/4754795733" data-nid="4754795733" data-subtype="area">徐州</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/1885191117" data-nid="1885191117" data-subtype="field">徐州云龙山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/2290122138" data-nid="2290122138" data-subtype="field">龙尾</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/2290122204" data-nid="2290122204" data-subtype="field">杏花村</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/2290122264" data-nid="2290122264" data-subtype="field">观音像</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/2290122324" data-nid="2290122324" data-subtype="field">羊左遗风</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/4755035757" data-nid="4755035757" data-subtype="area">南京</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7490761512" data-nid="7490761512" data-subtype="field">燕子矶</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7490825574" data-nid="7490825574" data-subtype="field">王笥洞</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/8745122169" data-nid="8745122169" data-subtype="area">王家湾</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/1885047144" data-nid="1885047144" data-subtype="crag">南京紫金山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/crazy-stone" data-nid="156178809" data-subtype="crag">疯狂的石头 Crazy Stone</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/1885115754" data-nid="1885115754" data-subtype="crag">百合</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/6806008350" data-nid="6806008350" data-subtype="field">天堡城</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7361543724" data-nid="7361543724" data-subtype="field">紫霞洞</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7361557062" data-nid="7361557062" data-subtype="boulder">紫霞洞</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7380002676" data-nid="7380002676" data-subtype="cliff">东壁</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5842980111" data-nid="5842980111" data-subtype="crag">青龙山劳动岩场</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5843113149" data-nid="5843113149" data-subtype="cliff">主岩壁</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5843113881" data-nid="5843113881" data-subtype="cliff">Crag-B</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5843114628" data-nid="5843114628" data-subtype="cliff">Crag-C</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5843115345" data-nid="5843115345" data-subtype="cliff">世外桃源</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5843116026" data-nid="5843116026" data-subtype="cliff">Crag-E</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5925116520" data-nid="5925116520" data-subtype="cliff">Crag-F</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5843125578" data-nid="5843125578" data-subtype="boulder">犬</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5843127768" data-nid="5843127768" data-subtype="boulder">Boulder-B</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5843128623" data-nid="5843128623" data-subtype="boulder">Boulder-C</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5843129274" data-nid="5843129274" data-subtype="boulder">Boulder-D</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5843129886" data-nid="5843129886" data-subtype="boulder">Boulder-E</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7210983315" data-nid="7210983315" data-subtype="boulder">小青龙</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/4491199443" data-nid="4491199443" data-subtype="gym">Blue Whale Climbing Gym 蓝鲸攀岩</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/8964727992" data-nid="8964727992" data-subtype="area">翠屏山</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/9350580972" data-nid="9350580972" data-subtype="area">江宁竹山陵园</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/4754996757" data-nid="4754996757" data-subtype="area">镇江</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/2300813988" data-nid="2300813988" data-subtype="crag">镇江南山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/2419334943" data-nid="2419334943" data-subtype="sector">A</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/2419336482" data-nid="2419336482" data-subtype="sector">B</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/2419336542" data-nid="2419336542" data-subtype="sector">C</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/2498775762" data-nid="2498775762" data-subtype="sector">D</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/2341943940" data-nid="2341943940" data-subtype="crag">镇江五峰山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/4784134893" data-nid="4784134893" data-subtype="cliff">A</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/4784135511" data-nid="4784135511" data-subtype="cliff">B</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/4755032187" data-nid="4755032187" data-subtype="area">苏州</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/1511041278" data-nid="1511041278" data-subtype="crag">苏州天池山 Tianchi Hill</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/1705861557" data-nid="1705861557" data-subtype="crag">苏州天平山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/1705863597" data-nid="1705863597" data-subtype="field">抱石一条街</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5270731152" data-nid="5270731152" data-subtype="boulder">阳山南 Yangshannan</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5987958324" data-nid="5987958324" data-subtype="area">树山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/6058691940" data-nid="6058691940" data-subtype="area">树山-山顶</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/6058694028" data-nid="6058694028" data-subtype="field">树山-洞 The Caves Area</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/6058694991" data-nid="6058694991" data-subtype="area">树山-湖 The Lake Area</a></li></ul></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/4654358511" data-nid="4654358511" data-subtype="gym">常州RED攀岩馆</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5270737071" data-nid="5270737071" data-subtype="area">常熟虞山 Changshu-Yushan</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5291025960" data-nid="5291025960" data-subtype="boulder">药瓶子</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5291026626" data-nid="5291026626" data-subtype="area">青龙岗（龙门） 黑洞</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7195827558" data-nid="7195827558" data-subtype="boulder">龙门</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7198130850" data-nid="7198130850" data-subtype="field">面馆</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7201903392" data-nid="7201903392" data-subtype="boulder">老人头</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7201904853" data-nid="7201904853" data-subtype="field">黑洞</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7201906524" data-nid="7201906524" data-subtype="field">欢乐谷（乱石区）</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7202164074" data-nid="7202164074" data-subtype="field">三件套（345号石）</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/9638401842" data-nid="9638401842" data-subtype="field">五件套</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7165881261" data-nid="7165881261" data-subtype="area">石屋涧 羊棚洞</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5270818134" data-nid="5270818134" data-subtype="boulder">石屋涧</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5529976869" data-nid="5529976869" data-subtype="boulder">脏脏宝Dirty</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5550682560" data-nid="5550682560" data-subtype="boulder">羊棚洞</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7204582980" data-nid="7204582980" data-subtype="boulder">一号石</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5291122533" data-nid="5291122533" data-subtype="area">帝师园~滚石~猴子头</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7201345677" data-nid="7201345677" data-subtype="boulder">滚石</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7201348212" data-nid="7201348212" data-subtype="boulder">猴子头</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/9354738846" data-nid="9354738846" data-subtype="field">猴子头东</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7230106080" data-nid="7230106080" data-subtype="field">猴子头西</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797163158" data-nid="10797163158" data-subtype="boulder">大猩猩</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10801552143" data-nid="10801552143" data-subtype="boulder">火炬</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/9354368376" data-nid="9354368376" data-subtype="field">帝师园</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797246540" data-nid="10797246540" data-subtype="boulder">砗磲</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797502674" data-nid="10797502674" data-subtype="boulder">大闸蟹</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797516441" data-nid="10797516441" data-subtype="boulder">鳐</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797525711" data-nid="10797525711" data-subtype="boulder">神仙鱼</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797533949" data-nid="10797533949" data-subtype="boulder">海鳗</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797539685" data-nid="10797539685" data-subtype="boulder">翻车鱼</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797549855" data-nid="10797549855" data-subtype="boulder">抹香鲸</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797563367" data-nid="10797563367" data-subtype="boulder">海马</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797567099" data-nid="10797567099" data-subtype="boulder">海螺</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797570024" data-nid="10797570024" data-subtype="boulder">美人鱼</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797579201" data-nid="10797579201" data-subtype="boulder">海浪</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797586926" data-nid="10797586926" data-subtype="boulder">大鲨鱼</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797605091" data-nid="10797605091" data-subtype="boulder">海豹</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797609888" data-nid="10797609888" data-subtype="boulder">海龟</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/5291123421" data-nid="5291123421" data-subtype="area">虞山印象~歌王~老虎洞</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7201463706" data-nid="7201463706" data-subtype="field">虞山印象</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7201512552" data-nid="7201512552" data-subtype="field">歌王歌后</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797636576" data-nid="10797636576" data-subtype="boulder">歌王</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797646734" data-nid="10797646734" data-subtype="boulder">歌后</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797655632" data-nid="10797655632" data-subtype="boulder">歌神</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797665877" data-nid="10797665877" data-subtype="boulder">歌迷</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7201854435" data-nid="7201854435" data-subtype="field">NR石</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/7201875441" data-nid="7201875441" data-subtype="field">老虎洞</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797682890" data-nid="10797682890" data-subtype="boulder">老虎洞</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/tian-chi-hill/area/10797693831" data-nid="10797693831" data-subtype="boulder">掌门石</a></li></ul></li></ul></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="2341229826" href="/zh_hans/climbing/china/area/2341229826" class=""><span class="primary-node-name">江西 Jiangxi</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2341232427" data-nid="2341232427" data-subtype="crag">九江石钟山</a></li><li><a href="/zh_hans/climbing/china/area/3978331710" data-nid="3978331710" data-subtype="crag">东浒寨飞拉达</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/9648697365" data-nid="9648697365" data-subtype="area">宜春洪塘</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/9648730485" data-nid="9648730485" data-subtype="crag">洪塘岩场</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/9648734445" data-nid="9648734445" data-subtype="area">A区</a></li><li><a href="/zh_hans/climbing/china/area/11494454610" data-nid="11494454610" data-subtype="sector">B区</a></li><li><a href="/zh_hans/climbing/china/area/11494482480" data-nid="11494482480" data-subtype="area">C区</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/9648765753" data-nid="9648765753" data-subtype="area">北坛天坑群</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/9648811023" data-nid="9648811023" data-subtype="area">石门村</a></li><li><a href="/zh_hans/climbing/china/area/9648819345" data-nid="9648819345" data-subtype="crag">石门村天坑</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/5487575403" data-nid="5487575403" data-subtype="crag">分宜洞村乡</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/5533783476" data-nid="5533783476" data-subtype="crag">蛇咀上 cave</a></li><li><a href="/zh_hans/climbing/china/area/5533803045" data-nid="5533803045" data-subtype="area">寒毛洞 cave</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/6066720996" data-nid="6066720996" data-subtype="area">红枫石城</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/6137125476" data-nid="6137125476" data-subtype="cliff">A区</a></li><li><a href="/zh_hans/climbing/china/area/6137135577" data-nid="6137135577" data-subtype="area">B区</a></li><li><a href="/zh_hans/climbing/china/area/6137151498" data-nid="6137151498" data-subtype="area">C区</a></li><li><a href="/zh_hans/climbing/china/area/6137170023" data-nid="6137170023" data-subtype="area">D区</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/6096644034" data-nid="6096644034" data-subtype="region">南昌梅岭</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/6096825789" data-nid="6096825789" data-subtype="boulder">A</a></li><li><a href="/zh_hans/climbing/china/area/6096861447" data-nid="6096861447" data-subtype="boulder">B</a></li><li><a href="/zh_hans/climbing/china/area/6096866817" data-nid="6096866817" data-subtype="field">抱石场A</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/9735368511" data-nid="9735368511" data-subtype="field">玉华山</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/9735374544" data-nid="9735374544" data-subtype="field">6号风机</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/9735464205" data-nid="9735464205" data-subtype="boulder">千层蛋糕</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/9735779847" data-nid="9735779847" data-subtype="boulder">No.1</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/9783959655" data-nid="9783959655" data-subtype="area">垂直面</a></li><li><a href="/zh_hans/climbing/china/area/9783962982" data-nid="9783962982" data-subtype="area">仰角面</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/9735779931" data-nid="9735779931" data-subtype="boulder">破壳</a></li><li><a href="/zh_hans/climbing/china/area/9735780015" data-nid="9735780015" data-subtype="boulder">No.3</a></li><li><a href="/zh_hans/climbing/china/area/9735780099" data-nid="9735780099" data-subtype="boulder">No.4</a></li><li><a href="/zh_hans/climbing/china/area/9735780183" data-nid="9735780183" data-subtype="boulder">No.5</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/9784066548" data-nid="9784066548" data-subtype="area">7号风机</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/11865807870" data-nid="11865807870" data-subtype="area">三江村深谭</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="3441799068" href="/zh_hans/climbing/china/area/3441799068" class=""><span class="primary-node-name">吉林 Jilin</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/3979630635" data-nid="3979630635" data-subtype="crag">临江七道沟</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="3341719653" href="/zh_hans/climbing/china/area/3341719653" class=""><span class="primary-node-name">宁夏 NingXia</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/3503898141" data-nid="3503898141" data-subtype="area">贺兰山滚钟口攀岩场</a></li><li><a href="/zh_hans/climbing/china/area/3979503882" data-nid="3979503882" data-subtype="crag">贺兰山大峰沟</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="3341720487" href="/zh_hans/climbing/china/area/3341720487" class=""><span class="primary-node-name">青海 QingHai</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/4895520702" data-nid="4895520702" data-subtype="area">年保玉则 Nianbaoyuze</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/4895530659" data-nid="4895530659" data-subtype="crag">Jedi Tower</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/3486109782" data-nid="3486109782" data-subtype="crag">西宁大通祁汉沟 阳光岩场</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/11507038500" data-nid="11507038500" data-subtype="area">岗什卡地区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/11507490111" data-nid="11507490111" data-subtype="crag">麒麟山</a></li><li><a href="/zh_hans/climbing/china/area/11507491173" data-nid="11507491173" data-subtype="area">岗什卡峰</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="2283193950" href="/zh_hans/climbing/china/area/2283193950" class=""><span class="primary-node-name">陕西 Shaanxi</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2283220269" data-nid="2283220269" data-subtype="area">大峪 Dayu</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2350188012" data-nid="2350188012" data-subtype="crag">老鹰岩</a></li><li><a href="/zh_hans/climbing/china/area/2284715016" data-nid="2284715016" data-subtype="crag">狮子茅棚</a></li><li><a href="/zh_hans/climbing/china/area/2657128875" data-nid="2657128875" data-subtype="crag">拴马桩</a></li><li><a href="/zh_hans/climbing/china/area/2657130495" data-nid="2657130495" data-subtype="field">西翠花</a></li><li><a href="/zh_hans/climbing/china/area/2283220839" data-nid="2283220839" data-subtype="crag">茄子山</a></li><li><a href="/zh_hans/climbing/china/area/2657128809" data-nid="2657128809" data-subtype="crag">九仙阁</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2350188072" data-nid="2350188072" data-subtype="crag">天水岩</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2922052518" data-nid="2922052518" data-subtype="crag">天水岩A区</a></li><li><a href="/zh_hans/climbing/china/area/2922053166" data-nid="2922053166" data-subtype="crag">天水岩C区</a></li><li><a href="/zh_hans/climbing/china/area/2922053775" data-nid="2922053775" data-subtype="area">天水岩D区</a></li><li><a href="/zh_hans/climbing/china/area/2922054330" data-nid="2922054330" data-subtype="crag">天水岩E区</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/4033292778" data-nid="4033292778" data-subtype="area">秘密花园</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/5561901228" data-nid="5561901228" data-subtype="field">龙潭A区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/5562199602" data-nid="5562199602" data-subtype="boulder">A1</a></li><li><a href="/zh_hans/climbing/china/area/5562344205" data-nid="5562344205" data-subtype="boulder">A2</a></li><li><a href="/zh_hans/climbing/china/area/5562626337" data-nid="5562626337" data-subtype="boulder">A3</a></li><li><a href="/zh_hans/climbing/china/area/5562631899" data-nid="5562631899" data-subtype="boulder">A4</a></li><li><a href="/zh_hans/climbing/china/area/5562631977" data-nid="5562631977" data-subtype="boulder">A5</a></li><li><a href="/zh_hans/climbing/china/area/5562632055" data-nid="5562632055" data-subtype="boulder">A6</a></li><li><a href="/zh_hans/climbing/china/area/5562613233" data-nid="5562613233" data-subtype="boulder">A7</a></li><li><a href="/zh_hans/climbing/china/area/5562610929" data-nid="5562610929" data-subtype="boulder">A8</a></li><li><a href="/zh_hans/climbing/china/area/5562622551" data-nid="5562622551" data-subtype="boulder">A9</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/5561902779" data-nid="5561902779" data-subtype="field">龙潭B区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/5562667911" data-nid="5562667911" data-subtype="boulder">B1</a></li><li><a href="/zh_hans/climbing/china/area/5562668922" data-nid="5562668922" data-subtype="boulder">B2</a></li><li><a href="/zh_hans/climbing/china/area/5562669006" data-nid="5562669006" data-subtype="boulder">B3</a></li><li><a href="/zh_hans/climbing/china/area/5562669084" data-nid="5562669084" data-subtype="boulder">B4</a></li><li><a href="/zh_hans/climbing/china/area/5562669162" data-nid="5562669162" data-subtype="boulder">B5</a></li><li><a href="/zh_hans/climbing/china/area/5562669240" data-nid="5562669240" data-subtype="boulder">B6</a></li><li><a href="/zh_hans/climbing/china/area/5562669318" data-nid="5562669318" data-subtype="boulder">B7</a></li><li><a href="/zh_hans/climbing/china/area/5562669396" data-nid="5562669396" data-subtype="boulder">B8</a></li><li><a href="/zh_hans/climbing/china/area/5562669474" data-nid="5562669474" data-subtype="boulder">B9</a></li><li><a href="/zh_hans/climbing/china/area/5562669552" data-nid="5562669552" data-subtype="boulder">B10</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/5561902845" data-nid="5561902845" data-subtype="field">龙潭C区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/5562762603" data-nid="5562762603" data-subtype="boulder">C1</a></li><li><a href="/zh_hans/climbing/china/area/5562763185" data-nid="5562763185" data-subtype="boulder">C2</a></li><li><a href="/zh_hans/climbing/china/area/5562856980" data-nid="5562856980" data-subtype="field">C3+</a></li><li><a href="/zh_hans/climbing/china/area/5562764433" data-nid="5562764433" data-subtype="boulder">C3</a></li><li><a href="/zh_hans/climbing/china/area/5562764511" data-nid="5562764511" data-subtype="boulder">C4</a></li><li><a href="/zh_hans/climbing/china/area/5562764589" data-nid="5562764589" data-subtype="boulder">C5</a></li><li><a href="/zh_hans/climbing/china/area/5562764667" data-nid="5562764667" data-subtype="boulder">C6</a></li><li><a href="/zh_hans/climbing/china/area/5562764745" data-nid="5562764745" data-subtype="boulder">C7</a></li><li><a href="/zh_hans/climbing/china/area/5562764823" data-nid="5562764823" data-subtype="boulder">C8</a></li><li><a href="/zh_hans/climbing/china/area/5562764907" data-nid="5562764907" data-subtype="boulder">C9</a></li><li><a href="/zh_hans/climbing/china/area/5562764985" data-nid="5562764985" data-subtype="boulder">C10</a></li><li><a href="/zh_hans/climbing/china/area/5562765063" data-nid="5562765063" data-subtype="boulder">C11</a></li><li><a href="/zh_hans/climbing/china/area/5562765141" data-nid="5562765141" data-subtype="boulder">C12</a></li><li><a href="/zh_hans/climbing/china/area/5562765219" data-nid="5562765219" data-subtype="boulder">C13</a></li><li><a href="/zh_hans/climbing/china/area/5562765297" data-nid="5562765297" data-subtype="boulder">C14</a></li><li><a href="/zh_hans/climbing/china/area/5562765375" data-nid="5562765375" data-subtype="boulder">C15</a></li><li><a href="/zh_hans/climbing/china/area/5562765453" data-nid="5562765453" data-subtype="boulder">C16</a></li><li><a href="/zh_hans/climbing/china/area/5562765531" data-nid="5562765531" data-subtype="boulder">C17</a></li><li><a href="/zh_hans/climbing/china/area/5562765609" data-nid="5562765609" data-subtype="boulder">C18</a></li><li><a href="/zh_hans/climbing/china/area/5562765693" data-nid="5562765693" data-subtype="boulder">C19</a></li><li><a href="/zh_hans/climbing/china/area/5562916809" data-nid="5562916809" data-subtype="boulder">C19右边</a></li><li><a href="/zh_hans/climbing/china/area/5562765771" data-nid="5562765771" data-subtype="boulder">C20</a></li><li><a href="/zh_hans/climbing/china/area/5562765849" data-nid="5562765849" data-subtype="boulder">C21</a></li><li><a href="/zh_hans/climbing/china/area/8251961262" data-nid="8251961262" data-subtype="boulder">C22</a></li><li><a href="/zh_hans/climbing/china/area/8251961334" data-nid="8251961334" data-subtype="boulder">C23</a></li><li><a href="/zh_hans/climbing/china/area/8251961406" data-nid="8251961406" data-subtype="area">C24</a></li><li><a href="/zh_hans/climbing/china/area/8251961478" data-nid="8251961478" data-subtype="area">C25</a></li><li><a href="/zh_hans/climbing/china/area/8251961550" data-nid="8251961550" data-subtype="area">C26</a></li><li><a href="/zh_hans/climbing/china/area/8251961622" data-nid="8251961622" data-subtype="area">C27</a></li><li><a href="/zh_hans/climbing/china/area/8251961694" data-nid="8251961694" data-subtype="area">C28</a></li><li><a href="/zh_hans/climbing/china/area/8251961766" data-nid="8251961766" data-subtype="area">C29</a></li><li><a href="/zh_hans/climbing/china/area/8251961838" data-nid="8251961838" data-subtype="area">C30</a></li><li><a href="/zh_hans/climbing/china/area/8251961910" data-nid="8251961910" data-subtype="area">C31</a></li><li><a href="/zh_hans/climbing/china/area/8252183856" data-nid="8252183856" data-subtype="boulder">C32</a></li><li><a href="/zh_hans/climbing/china/area/8252183928" data-nid="8252183928" data-subtype="boulder">C33</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/5561902911" data-nid="5561902911" data-subtype="field">龙潭D区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/5562966708" data-nid="5562966708" data-subtype="boulder">D1</a></li><li><a href="/zh_hans/climbing/china/area/5562973389" data-nid="5562973389" data-subtype="boulder">D2</a></li><li><a href="/zh_hans/climbing/china/area/5562973467" data-nid="5562973467" data-subtype="boulder">D3</a></li><li><a href="/zh_hans/climbing/china/area/8252242161" data-nid="8252242161" data-subtype="boulder">D5</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/5562190500" data-nid="5562190500" data-subtype="field">虎穴区</a></li><li><a href="/zh_hans/climbing/china/area/5562021516" data-nid="5562021516" data-subtype="field">狼窝区</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/4033306164" data-nid="4033306164" data-subtype="crag">翠华山</a></li><li><a href="/zh_hans/climbing/china/area/4036583598" data-nid="4036583598" data-subtype="field">河道边</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/2338816647" data-nid="2338816647" data-subtype="crag">沣峪口</a></li><li><a href="/zh_hans/climbing/china/area/2350186683" data-nid="2350186683" data-subtype="crag">大夫峪</a></li><li><a href="/zh_hans/climbing/china/area/2423210724" data-nid="2423210724" data-subtype="crag">天子峪</a></li><li><a href="/zh_hans/climbing/china/area/3137529039" data-nid="3137529039" data-subtype="crag">华山 Mount Hua</a></li><li><a href="/zh_hans/climbing/china/area/3681567099" data-nid="3681567099" data-subtype="crag">小峪</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/9543081129" data-nid="9543081129" data-subtype="area">洋峪</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/9543081966" data-nid="9543081966" data-subtype="crag">森宝乐园/瞻星岩</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/3962863773" data-nid="3962863773" data-subtype="crag">流峪飞峡</a></li><li><a href="/zh_hans/climbing/china/area/3962946189" data-nid="3962946189" data-subtype="crag">涝峪黑山岔</a></li><li><a href="/zh_hans/climbing/china/area/3977587173" data-nid="3977587173" data-subtype="crag">南宫山飞拉达</a></li><li><a href="/zh_hans/climbing/china/area/3307108638" data-nid="3307108638" data-subtype="gym">攀岩梦工厂</a></li><li><a href="/zh_hans/climbing/china/area/7627803783" data-nid="7627803783" data-subtype="gym">Redpoint Climbing Gym红点攀岩</a></li><li><a href="/zh_hans/climbing/china/area/9255624135" data-nid="9255624135" data-subtype="gym">大仁攀岩</a></li><li><a href="/zh_hans/climbing/china/area/9543079563" data-nid="9543079563" data-subtype="gym">岩十三攀岩</a></li><li><a href="/zh_hans/climbing/china/area/11649108411" data-nid="11649108411" data-subtype="gym">西柚攀岩SeeYou Climbing Gym</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/12722238447" data-nid="12722238447" data-subtype="area">商洛</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/12722247963" data-nid="12722247963" data-subtype="crag">刘秀潭</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="154039968" href="/zh_hans/climbing/china/shandong" class=""><span class="primary-node-name">山东 Shandong</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/2292896865" data-nid="2292896865" data-subtype="area">烟台 Yan Tai</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/2349960156" data-nid="2349960156" data-subtype="crag">崮山白水峡谷</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/4706592273" data-nid="4706592273" data-subtype="crag">A区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/10038184095" data-nid="10038184095" data-subtype="area">A区南侧</a></li><li><a href="/zh_hans/climbing/china/shandong/area/4706592339" data-nid="4706592339" data-subtype="crag">A区上层</a></li><li><a href="/zh_hans/climbing/china/shandong/area/4706592405" data-nid="4706592405" data-subtype="crag">B区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/4706592471" data-nid="4706592471" data-subtype="crag">C区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/4706592537" data-nid="4706592537" data-subtype="crag">D区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/4706592609" data-nid="4706592609" data-subtype="crag">南区</a></li></ul></li><li><a href="/zh_hans/climbing/china/shandong/area/3681554346" data-nid="3681554346" data-subtype="crag">福山国路夼</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/818186967" data-nid="818186967" data-subtype="area">淄博 Zi Bo</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/818187861" data-nid="818187861" data-subtype="crag">石鳖湾 Stone Turtle Bay</a></li><li><a href="/zh_hans/climbing/china/shandong/area/818195217" data-nid="818195217" data-subtype="crag">刁花峪洞 Diao Hua Yu Cave</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/818204991" data-nid="818204991" data-subtype="crag">石马岩场 Stone Horse</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/818206842" data-nid="818206842" data-subtype="cliff">1A</a></li><li><a href="/zh_hans/climbing/china/shandong/area/818224788" data-nid="818224788" data-subtype="cliff">1B</a></li><li><a href="/zh_hans/climbing/china/shandong/area/818230521" data-nid="818230521" data-subtype="cliff">2A&amp;B</a></li><li><a href="/zh_hans/climbing/china/shandong/area/818260875" data-nid="818260875" data-subtype="cliff">3A</a></li><li><a href="/zh_hans/climbing/china/shandong/area/818260941" data-nid="818260941" data-subtype="cliff">3B</a></li><li><a href="/zh_hans/climbing/china/shandong/area/818261007" data-nid="818261007" data-subtype="cliff">3C</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/2292859113" data-nid="2292859113" data-subtype="crag">北峪岩场</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/2338777005" data-nid="2338777005" data-subtype="sector">一区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/2338778022" data-nid="2338778022" data-subtype="sector">四区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/2338778088" data-nid="2338778088" data-subtype="sector">五区</a></li></ul></li><li><a href="/zh_hans/climbing/china/shandong/area/10061770239" data-nid="10061770239" data-subtype="crag">新生岩场</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/4427148771" data-nid="4427148771" data-subtype="area">邹城 Zou Cheng</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/4425569118" data-nid="4425569118" data-subtype="field">鸿山</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/5153786247" data-nid="5153786247" data-subtype="crag">昌平山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/2292871434" data-nid="2292871434" data-subtype="crag">昌平山南桑岩场</a></li><li><a href="/zh_hans/climbing/china/shandong/area/5153791521" data-nid="5153791521" data-subtype="area">昌平山老岩场</a></li></ul></li><li><a href="/zh_hans/climbing/china/shandong/area/6704681415" data-nid="6704681415" data-subtype="crag">护驾山</a></li><li><a href="/zh_hans/climbing/china/shandong/area/9021046557" data-nid="9021046557" data-subtype="field">香城镇/瓦峪</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/1804153785" data-nid="1804153785" data-subtype="area">枣庄 Zao Zhuang</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/1821114594" data-nid="1821114594" data-subtype="crag">夹谷山 Jia Gu Mountain</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/1826399157" data-nid="1826399157" data-subtype="sector">水池亭子区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/1826399067" data-nid="1826399067" data-subtype="sector">主岩壁 Main Cliff</a></li><li><a href="/zh_hans/climbing/china/shandong/area/5176200066" data-nid="5176200066" data-subtype="sector">东北区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/1826399001" data-nid="1826399001" data-subtype="sector">滴水洞 Drip Cave</a></li><li><a href="/zh_hans/climbing/china/shandong/area/2548400838" data-nid="2548400838" data-subtype="sector">西区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/2548400904" data-nid="2548400904" data-subtype="sector">北区</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/6030301896" data-nid="6030301896" data-subtype="area">庙南峪</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/5117342298" data-nid="5117342298" data-subtype="crag">平顶山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/4670953056" data-nid="4670953056" data-subtype="crag">一区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/5117326329" data-nid="5117326329" data-subtype="crag">二区</a></li></ul></li><li><a href="/zh_hans/climbing/china/shandong/area/1821115320" data-nid="1821115320" data-subtype="crag">云谷山</a></li><li><a href="/zh_hans/climbing/china/shandong/area/5612366661" data-nid="5612366661" data-subtype="crag">定盘山口西岩场</a></li></ul></li><li><a href="/zh_hans/climbing/china/shandong/area/9583252596" data-nid="9583252596" data-subtype="area">十道峪</a></li><li><a href="/zh_hans/climbing/china/shandong/area/3779723571" data-nid="3779723571" data-subtype="crag">焦山空</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/qingdao" data-nid="2637536664" data-subtype="area">青岛 Qingdao</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5545388802" data-nid="5545388802" data-subtype="crag">黄山崮</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/fu-hill" data-nid="156265455" data-subtype="area">浮山 Fu Hill</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/fu-hill/area/215144454" data-nid="215144454" data-subtype="cliff">Monster Cliff</a></li><li><a href="/zh_hans/climbing/china/shandong/fu-hill/area/277972248" data-nid="277972248" data-subtype="crag">201</a></li><li><a href="/zh_hans/climbing/china/shandong/fu-hill/area/2198132136" data-nid="2198132136" data-subtype="unknown">Lost World</a></li><li><a href="/zh_hans/climbing/china/shandong/fu-hill/area/2198132730" data-nid="2198132730" data-subtype="unknown">半坡起步</a></li><li><a href="/zh_hans/climbing/china/shandong/fu-hill/area/2198133333" data-nid="2198133333" data-subtype="unknown">大屁股</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/yang-kou" data-nid="156265479" data-subtype="crag">仰口岩场 Yang Kou</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/yang-kou/area/5545662234" data-nid="5545662234" data-subtype="cliff">情人峰</a></li><li><a href="/zh_hans/climbing/china/shandong/yang-kou/area/5545671033" data-nid="5545671033" data-subtype="cliff">平顶崮</a></li><li><a href="/zh_hans/climbing/china/shandong/yang-kou/area/5545683078" data-nid="5545683078" data-subtype="cliff">平顶崮西南峰</a></li><li><a href="/zh_hans/climbing/china/shandong/yang-kou/area/5545698336" data-nid="5545698336" data-subtype="cliff">擎天柱</a></li><li><a href="/zh_hans/climbing/china/shandong/yang-kou/area/5545723638" data-nid="5545723638" data-subtype="cliff">擎天柱西南峰</a></li><li><a href="/zh_hans/climbing/china/shandong/yang-kou/area/5545737669" data-nid="5545737669" data-subtype="cliff">觅天洞</a></li></ul></li><li><a href="/zh_hans/climbing/china/shandong/ba-xian-dun" data-nid="156265503" data-subtype="crag">八仙墩 Ba Xian Dun</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/qingdao/area/1712206911" data-nid="1712206911" data-subtype="crag">金家岭山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5548948041" data-nid="5548948041" data-subtype="boulder">Big One</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549216430" data-nid="5549216430" data-subtype="boulder">进化</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549216502" data-nid="5549216502" data-subtype="boulder">望妻</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549216574" data-nid="5549216574" data-subtype="boulder">联合国</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549216646" data-nid="5549216646" data-subtype="boulder">高度</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549216718" data-nid="5549216718" data-subtype="boulder">大晴天</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549216793" data-nid="5549216793" data-subtype="boulder">秋香</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549159694" data-nid="5549159694" data-subtype="boulder">向上</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549216868" data-nid="5549216868" data-subtype="boulder">9-3</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549216934" data-nid="5549216934" data-subtype="boulder">象脊</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549166033" data-nid="5549166033" data-subtype="boulder">开天辟地</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217006" data-nid="5549217006" data-subtype="boulder">马首</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217078" data-nid="5549217078" data-subtype="boulder">左右派</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217150" data-nid="5549217150" data-subtype="boulder">Cave</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217222" data-nid="5549217222" data-subtype="boulder">狼群</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217294" data-nid="5549217294" data-subtype="boulder">向阳</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217366" data-nid="5549217366" data-subtype="boulder">别扭</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217438" data-nid="5549217438" data-subtype="boulder">18-4</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217504" data-nid="5549217504" data-subtype="boulder">青苔</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217576" data-nid="5549217576" data-subtype="boulder">十三</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217648" data-nid="5549217648" data-subtype="boulder">软柿子</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217720" data-nid="5549217720" data-subtype="boulder">22-1</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549217786" data-nid="5549217786" data-subtype="boulder">23-1</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549225367" data-nid="5549225367" data-subtype="boulder">24-1</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549166105" data-nid="5549166105" data-subtype="boulder">25-2</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5549405817" data-nid="5549405817" data-subtype="boulder">喜鹊</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5552671677" data-nid="5552671677" data-subtype="boulder">223总站</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5552686512" data-nid="5552686512" data-subtype="boulder">金手指</a></li></ul></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/2292738351" data-nid="2292738351" data-subtype="crag">甲角石</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/guang-guang-gu" data-nid="2338152480" data-subtype="crag">二龙山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/xiao-wang-cliff" data-nid="156265431" data-subtype="crag">晓望岩场 Xiao Wang Cliff</a></li><li><a href="/zh_hans/climbing/china/shandong/guang-guang-gu/area/2960791977" data-nid="2960791977" data-subtype="area">A面</a></li><li><a href="/zh_hans/climbing/china/shandong/guang-guang-gu/area/8555889876" data-nid="8555889876" data-subtype="crag">Madrock 岩场</a></li></ul></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/11919530379" data-nid="11919530379" data-subtype="crag">桃花源东</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/qingdao/area/2338152540" data-nid="2338152540" data-subtype="crag">安子崮</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/12147918501" data-nid="12147918501" data-subtype="cliff">安子崮东区</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/12147933942" data-nid="12147933942" data-subtype="cliff">安子崮东北角</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/qingdao/area/5546380854" data-nid="5546380854" data-subtype="field">张家河</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547022554" data-nid="5547022554" data-subtype="boulder">1-6</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547022620" data-nid="5547022620" data-subtype="boulder">2-3</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547022686" data-nid="5547022686" data-subtype="boulder">3-1</a></li></ul></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/3681539352" data-nid="3681539352" data-subtype="crag">巉山</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/qingdao/area/3681460572" data-nid="3681460572" data-subtype="field">长岭</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547081234" data-nid="5547081234" data-subtype="boulder">Egg</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547083244" data-nid="5547083244" data-subtype="boulder">恐龙</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547083316" data-nid="5547083316" data-subtype="boulder">8-1</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547083388" data-nid="5547083388" data-subtype="boulder">10-3</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547083454" data-nid="5547083454" data-subtype="boulder">1-1</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547083520" data-nid="5547083520" data-subtype="boulder">2-1</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547083592" data-nid="5547083592" data-subtype="boulder">3-1</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547083658" data-nid="5547083658" data-subtype="boulder">4-1</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547083724" data-nid="5547083724" data-subtype="boulder">5-1</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547083790" data-nid="5547083790" data-subtype="boulder">6-2</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547083856" data-nid="5547083856" data-subtype="boulder">7-1</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547104358" data-nid="5547104358" data-subtype="field">泉心河</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547110895" data-nid="5547110895" data-subtype="boulder">6-4</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547110961" data-nid="5547110961" data-subtype="boulder">6-4/5-3</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547111027" data-nid="5547111027" data-subtype="boulder">3-2</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547111093" data-nid="5547111093" data-subtype="boulder">4-1</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547111159" data-nid="5547111159" data-subtype="boulder">2-2</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547111225" data-nid="5547111225" data-subtype="boulder">1-4</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/qingdao/area/3681492102" data-nid="3681492102" data-subtype="field">蜂巢</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547135027" data-nid="5547135027" data-subtype="boulder">1-4</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547140013" data-nid="5547140013" data-subtype="boulder">2-7</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547140079" data-nid="5547140079" data-subtype="boulder">3-3</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547140145" data-nid="5547140145" data-subtype="boulder">4-2</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5547140211" data-nid="5547140211" data-subtype="boulder">5-3</a></li></ul></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/4843839831" data-nid="4843839831" data-subtype="field">二浴西</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/4843839891" data-nid="4843839891" data-subtype="field">三浴西</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5552615034" data-nid="5552615034" data-subtype="field">燕岛秋潮</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/4843839771" data-nid="4843839771" data-subtype="field">燕儿岛山公园</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5552560650" data-nid="5552560650" data-subtype="field">海景花园</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/4843807905" data-nid="4843807905" data-subtype="boulder">银海大世界</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5552518827" data-nid="5552518827" data-subtype="field">小麦岛公园</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/3476837325" data-nid="3476837325" data-subtype="field">海洋大学沙滩</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/5552597184" data-nid="5552597184" data-subtype="field">灯塔南</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/3681499245" data-nid="3681499245" data-subtype="field">极地海洋世界</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/4843839951" data-nid="4843839951" data-subtype="field">石老人</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/4843840011" data-nid="4843840011" data-subtype="field">海曙云霞</a></li><li><a href="/zh_hans/climbing/china/shandong/qingdao/area/3365086374" data-nid="3365086374" data-subtype="gym">变色龙攀岩</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/5109045816" data-nid="5109045816" data-subtype="area">济南 Ji Nan</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/5109078477" data-nid="5109078477" data-subtype="crag">大佛头</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/5109208458" data-nid="5109208458" data-subtype="sector">一区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/5109233043" data-nid="5109233043" data-subtype="sector">二区</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/6496355757" data-nid="6496355757" data-subtype="crag">柏石峪</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/6496366776" data-nid="6496366776" data-subtype="cliff">大石棚区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/6497443944" data-nid="6497443944" data-subtype="cliff">二区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/6497494515" data-nid="6497494515" data-subtype="cliff">三区</a></li><li><a href="/zh_hans/climbing/china/shandong/area/6541810011" data-nid="6541810011" data-subtype="cliff">四区</a></li></ul></li><li><a href="/zh_hans/climbing/china/shandong/area/5109131214" data-nid="5109131214" data-subtype="crag">张夏义净寺</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/7334087499" data-nid="7334087499" data-subtype="area">莱芜</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/7334109432" data-nid="7334109432" data-subtype="field">万福山</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/shandong/area/10040554494" data-nid="10040554494" data-subtype="area">威海 Wei Hai</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/shandong/area/10040572581" data-nid="10040572581" data-subtype="gym">常春藤攀岩馆</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="2312001381" href="/zh_hans/climbing/china/area/2312001381" class=""><span class="primary-node-name">上海 Shanghai</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2320918137" data-nid="2320918137" data-subtype="gym">High Five Climbing Gym</a></li><li><a href="/zh_hans/climbing/china/area/2320917813" data-nid="2320917813" data-subtype="gym">Park Climbing Gym 爬客攀岩馆</a></li><li><a href="/zh_hans/climbing/china/area/2317345350" data-nid="2317345350" data-subtype="gym">PONGO Climbing Gym</a></li><li><a href="/zh_hans/climbing/china/area/2320918029" data-nid="2320918029" data-subtype="gym">Red Gym Climbing 红攀攀岩体验中心</a></li><li><a href="/zh_hans/climbing/china/area/2320917759" data-nid="2320917759" data-subtype="gym">Ribbon Climbing Gym 叶岩攀岩馆</a></li><li><a href="/zh_hans/climbing/china/area/2320918083" data-nid="2320918083" data-subtype="gym">Roaring Climbing Gym 啸岩馆</a></li><li><a href="/zh_hans/climbing/china/area/2317347636" data-nid="2317347636" data-subtype="gym">Shanghai Indoor Stadium</a></li><li><a href="/zh_hans/climbing/china/area/2320917705" data-nid="2320917705" data-subtype="gym">魔岩攀登</a></li><li><a href="/zh_hans/climbing/china/area/2320917867" data-nid="2320917867" data-subtype="gym">岩舞空间攀岩(梅赛德斯奔驰文化中心)</a></li><li><a href="/zh_hans/climbing/china/area/2320917921" data-nid="2320917921" data-subtype="gym">蜘蛛侠攀岩馆</a></li><li><a href="/zh_hans/climbing/china/area/2320917975" data-nid="2320917975" data-subtype="gym">尽峰攀岩</a></li><li><a href="/zh_hans/climbing/china/area/2320918191" data-nid="2320918191" data-subtype="gym">攀王室内攀岩</a></li><li><a href="/zh_hans/climbing/china/area/2320925724" data-nid="2320925724" data-subtype="gym">攀岩主义(金高路店)</a></li><li><a href="/zh_hans/climbing/china/area/2320925778" data-nid="2320925778" data-subtype="gym">滨江攀岩</a></li><li><a href="/zh_hans/climbing/china/area/2320925886" data-nid="2320925886" data-subtype="gym">家家乐国际攀岩中心</a></li><li><a href="/zh_hans/climbing/china/area/2320925832" data-nid="2320925832" data-subtype="gym">9A攀岩(七宝万科广场店)</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="831296673" href="/zh_hans/climbing/china/area/831296673" class=""><span class="primary-node-name">山西 Shanxi</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2282946159" data-nid="2282946159" data-subtype="crag">黎城洗耳河</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="154040016" href="/zh_hans/climbing/china/sichuan-chongqing" class=""><span class="primary-node-name">四川 Sichuan</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/2237335068" data-nid="2237335068" data-subtype="crag">江油腰悬岩</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3351120294" data-nid="3351120294" data-subtype="cliff">岩花岩 Stone Flower</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3351125793" data-nid="3351125793" data-subtype="cliff">枯枝岩 Deadwood</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3088426020" data-nid="3088426020" data-subtype="cliff">柏树林 Cypress Forest</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3088426080" data-nid="3088426080" data-subtype="cliff">大麦地 Barley Field</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3088426140" data-nid="3088426140" data-subtype="cliff">红崖湾 Red Cliff</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3088426200" data-nid="3088426200" data-subtype="cliff">羊圈湾 Sheep Pen</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8468526270" data-nid="8468526270" data-subtype="cliff">尺子崖</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3088426380" data-nid="3088426380" data-subtype="cliff">猴子洞 Monkey Cave</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5914840953" data-nid="5914840953" data-subtype="cliff">3B区</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3895633815" data-nid="3895633815" data-subtype="cliff">3A区</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3895551645" data-nid="3895551645" data-subtype="cliff">1区</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3895616025" data-nid="3895616025" data-subtype="cliff">2区</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3088426440" data-nid="3088426440" data-subtype="cliff">烟地坪 Smoky Land</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/1666266207" data-nid="1666266207" data-subtype="crag">德阳古店乡 Gudian Village</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/1745955612" data-nid="1745955612" data-subtype="crag">老岩场 Old Crag</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/1985240979" data-nid="1985240979" data-subtype="crag">新岩场 New Crag</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8514801993" data-nid="8514801993" data-subtype="field">新岩场抱石区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8514768483" data-nid="8514768483" data-subtype="field">A区</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8514771153" data-nid="8514771153" data-subtype="area">B区</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8514771219" data-nid="8514771219" data-subtype="area">C区</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8514771285" data-nid="8514771285" data-subtype="area">D区</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8514771351" data-nid="8514771351" data-subtype="area">E区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8571384429" data-nid="8571384429" data-subtype="boulder">E1</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8571394308" data-nid="8571394308" data-subtype="boulder">E2</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8571417381" data-nid="8571417381" data-subtype="boulder">E3</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8571417453" data-nid="8571417453" data-subtype="boulder">E4</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8571417525" data-nid="8571417525" data-subtype="boulder">E5</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8571422145" data-nid="8571422145" data-subtype="boulder">E6</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8514771417" data-nid="8514771417" data-subtype="area">F区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8571815790" data-nid="8571815790" data-subtype="boulder">F1</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/11826005562" data-nid="11826005562" data-subtype="area">G区</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/1745967843" data-nid="1745967843" data-subtype="area">葛仙山 Gexian Mountain</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5565806445" data-nid="5565806445" data-subtype="crag">飞来峰</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/2547945696" data-nid="2547945696" data-subtype="crag">鬼脸 Ghost Face</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5565833835" data-nid="5565833835" data-subtype="cliff">儿童乐园</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5565836580" data-nid="5565836580" data-subtype="cliff">尽头岩壁</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/1832192862" data-nid="1832192862" data-subtype="crag">月亮洞 Moon Cave</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/1745968335" data-nid="1745968335" data-subtype="crag">观音洞 Guanyin Cave</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/4906024440" data-nid="4906024440" data-subtype="cliff">训练墙</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6891489021" data-nid="6891489021" data-subtype="crag">理工岩场</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6944552730" data-nid="6944552730" data-subtype="crag">理工岩场</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6944250183" data-nid="6944250183" data-subtype="crag">bd岩场</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5565825342" data-nid="5565825342" data-subtype="cliff">老土匪洞</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6948670953" data-nid="6948670953" data-subtype="crag">鸡窝岩场</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6948689334" data-nid="6948689334" data-subtype="crag">硝洞岩场</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/918492141" data-nid="918492141" data-subtype="area">大邑鹤鸣山 He Ming Mountain</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/918494535" data-nid="918494535" data-subtype="crag">猴子岩 Monkey Rock</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/2615607903" data-nid="2615607903" data-subtype="crag">腾龙 Tenglong</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5568435798" data-nid="5568435798" data-subtype="cliff">一号岩区</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5568435864" data-nid="5568435864" data-subtype="cliff">二号岩区</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/9328366437" data-nid="9328366437" data-subtype="area">都江堰</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/9054573246" data-nid="9054573246" data-subtype="crag">龙池镇抱石</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/9054578631" data-nid="9054578631" data-subtype="boulder">1号</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/9316035600" data-nid="9316035600" data-subtype="boulder">2号</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/9316035660" data-nid="9316035660" data-subtype="boulder">3号</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/9316035720" data-nid="9316035720" data-subtype="boulder">4号</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/9316035780" data-nid="9316035780" data-subtype="boulder">5号</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/9328639599" data-nid="9328639599" data-subtype="field">虹口乡抱石</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/10831301763" data-nid="10831301763" data-subtype="region">乐山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/1640825760" data-nid="1640825760" data-subtype="crag">乐山龙岩 Dragon Crag</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/11314922817" data-nid="11314922817" data-subtype="area">乐山美女峰</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/10824674685" data-nid="10824674685" data-subtype="crag">大渡河一号桥头</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/10824715443" data-nid="10824715443" data-subtype="crag">白泥凼（前中后岩壁）</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/10824817842" data-nid="10824817842" data-subtype="crag">幺棚子</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/10824821625" data-nid="10824821625" data-subtype="crag">羊圈子</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/10824837957" data-nid="10824837957" data-subtype="crag">七公里</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/10825802973" data-nid="10825802973" data-subtype="area">乐山峨眉</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/10825810335" data-nid="10825810335" data-subtype="area">峨眉龙池</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/10825887117" data-nid="10825887117" data-subtype="cliff">溪流左</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/10825887183" data-nid="10825887183" data-subtype="area">溪流右</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/10825810443" data-nid="10825810443" data-subtype="area">白石沟</a></li></ul></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/2316681672" data-nid="2316681672" data-subtype="crag">宜宾-水富金沙江</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/9702959640" data-nid="9702959640" data-subtype="cliff">宜宾巡场岩</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/11294493894" data-nid="11294493894" data-subtype="area">右侧岩壁</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/11294607747" data-nid="11294607747" data-subtype="area">左侧岩壁</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/2350909947" data-nid="2350909947" data-subtype="crag">泸州叙永</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6025170000" data-nid="6025170000" data-subtype="area">内江市威远县永兴村</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6025167690" data-nid="6025167690" data-subtype="crag">运动攀岩场</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6025167750" data-nid="6025167750" data-subtype="crag">传统攀岩场</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6398025534" data-nid="6398025534" data-subtype="field">抱石区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6398026752" data-nid="6398026752" data-subtype="boulder">1号</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng" data-nid="156144837" data-subtype="crag">稻城 Dao Cheng</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/2756352600" data-nid="2756352600" data-subtype="field">茹布查卡 Ruba Chaka Village</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175108269" data-nid="3175108269" data-subtype="area">Area 1</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175112826" data-nid="3175112826" data-subtype="area">Area 1-1</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175112898" data-nid="3175112898" data-subtype="area">Area 1-2</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175112970" data-nid="3175112970" data-subtype="area">Area 1 Hill</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175113042" data-nid="3175113042" data-subtype="area">Area 1-3</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175108335" data-nid="3175108335" data-subtype="area">Area 2</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175226973" data-nid="3175226973" data-subtype="area">2-1</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175227045" data-nid="3175227045" data-subtype="area">2-2</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175108401" data-nid="3175108401" data-subtype="area">Area 3</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175241538" data-nid="3175241538" data-subtype="area">3-1</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175242150" data-nid="3175242150" data-subtype="area">3-2</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175242222" data-nid="3175242222" data-subtype="area">3-3</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175108467" data-nid="3175108467" data-subtype="area">Area 4</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175245798" data-nid="3175245798" data-subtype="area">4-1</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175245870" data-nid="3175245870" data-subtype="area">4-2</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175108533" data-nid="3175108533" data-subtype="area">Area 5</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175246980" data-nid="3175246980" data-subtype="area">5-1</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175247052" data-nid="3175247052" data-subtype="area">5-2</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/5723302176" data-nid="5723302176" data-subtype="field">圣.38岩场</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/5723303970" data-nid="5723303970" data-subtype="boulder">1 号石头</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/5723304036" data-nid="5723304036" data-subtype="boulder">2 号石头</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/5723304102" data-nid="5723304102" data-subtype="boulder">3 号石头</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/5723304168" data-nid="5723304168" data-subtype="boulder">4 号石头</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/5723304234" data-nid="5723304234" data-subtype="boulder">5 号石头</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/5723304300" data-nid="5723304300" data-subtype="boulder">6 号石头</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/5723304366" data-nid="5723304366" data-subtype="boulder">7 号石头</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/5723304432" data-nid="5723304432" data-subtype="boulder">8、9 号石头</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/5723304498" data-nid="5723304498" data-subtype="boulder">10-12 号石头</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/5723304564" data-nid="5723304564" data-subtype="boulder">13-16 号石头</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/2756352660" data-nid="2756352660" data-subtype="field">海子山 HaiziShan</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175243179" data-nid="3175243179" data-subtype="area">Area 1</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175271538" data-nid="3175271538" data-subtype="boulder">Potential Boulder 1</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175271610" data-nid="3175271610" data-subtype="boulder">Potential Boulder 2</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175271682" data-nid="3175271682" data-subtype="boulder">Potential Boulder 3</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175271754" data-nid="3175271754" data-subtype="boulder">Potential Boulder 4</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175271826" data-nid="3175271826" data-subtype="boulder">Potential Boulder 5</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175271898" data-nid="3175271898" data-subtype="boulder">Potential Boulder 6</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175271970" data-nid="3175271970" data-subtype="boulder">Potential Boulder 7</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175272042" data-nid="3175272042" data-subtype="boulder">Potential Boulder 8</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175243245" data-nid="3175243245" data-subtype="area">Area 2</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175275453" data-nid="3175275453" data-subtype="boulder">Potential Boulder 1</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175275525" data-nid="3175275525" data-subtype="boulder">Potential Boulder 2</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175275603" data-nid="3175275603" data-subtype="boulder">Potential Boulder 3</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175275675" data-nid="3175275675" data-subtype="boulder">Potential Boulder 4</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175275747" data-nid="3175275747" data-subtype="boulder">Potential Boulder 5</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175275819" data-nid="3175275819" data-subtype="boulder">Potential Boulder 6</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175275891" data-nid="3175275891" data-subtype="boulder">Potential Boulder 7</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175275963" data-nid="3175275963" data-subtype="boulder">Potential Boulder 8</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175276035" data-nid="3175276035" data-subtype="boulder">Potential Boulder 9</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175276107" data-nid="3175276107" data-subtype="boulder">Potential Boulder 10</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175276179" data-nid="3175276179" data-subtype="boulder">Potential Boulder 11</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175243311" data-nid="3175243311" data-subtype="area">Area 3</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175281069" data-nid="3175281069" data-subtype="boulder">Boulder 0</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175281141" data-nid="3175281141" data-subtype="boulder">Sour Cheese Boulder</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175281213" data-nid="3175281213" data-subtype="boulder">Stinky Cheese Boulder</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175281285" data-nid="3175281285" data-subtype="boulder">Anvil Boulder</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175281357" data-nid="3175281357" data-subtype="boulder">Boulder 1</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175243377" data-nid="3175243377" data-subtype="area">Area 4</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175290387" data-nid="3175290387" data-subtype="boulder">Potential Boulder 1</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175290459" data-nid="3175290459" data-subtype="boulder">Potential Boulder 2</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175290531" data-nid="3175290531" data-subtype="boulder">Potential Boulder 3</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175290603" data-nid="3175290603" data-subtype="boulder">Potential Boulder 4</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/6439570590" data-nid="6439570590" data-subtype="area">圣.45岩场</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/6439775262" data-nid="6439775262" data-subtype="boulder">Moby Dick 白鲸迪克</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/2756352720" data-nid="2756352720" data-subtype="area">兔儿山 TuerShan Alpine Area</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175438005" data-nid="3175438005" data-subtype="crag">Tu'er Wall</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/3175438077" data-nid="3175438077" data-subtype="crag">Playground Wall</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/6439570524" data-nid="6439570524" data-subtype="area">亚丁景区</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/6439610544" data-nid="6439610544" data-subtype="field">牛奶海</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/dao-cheng/area/6439657284" data-nid="6439657284" data-subtype="boulder">Moonrock 月亮石</a></li></ul></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3153970632" data-nid="3153970632" data-subtype="area">雪宝顶地区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3155904459" data-nid="3155904459" data-subtype="crag">小雪宝顶</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3155904531" data-nid="3155904531" data-subtype="crag">雪宝顶</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3155904603" data-nid="3155904603" data-subtype="crag">四根香峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3155904669" data-nid="3155904669" data-subtype="crag">红星岩</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3153970830" data-nid="3153970830" data-subtype="area">雪隆包地区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3154000071" data-nid="3154000071" data-subtype="crag">雪隆包</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3156016437" data-nid="3156016437" data-subtype="crag">奥太基</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3156156549" data-nid="3156156549" data-subtype="crag">奥太娜</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3156156615" data-nid="3156156615" data-subtype="crag">奥太美</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3130716396" data-nid="3130716396" data-subtype="area">四姑娘山地区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/2313232869" data-nid="2313232869" data-subtype="crag">双桥沟冰瀑 Shuangqiao Valley Ice Falls</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3982040412" data-nid="3982040412" data-subtype="crag">凉台沟冰瀑</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/4426130421" data-nid="4426130421" data-subtype="area">梯子沟 Tizi Valley</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/4426133292" data-nid="4426133292" data-subtype="cliff">朝阳</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/4426162464" data-nid="4426162464" data-subtype="area">卧龙关沟 Wolongguan Valley</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/4426198272" data-nid="4426198272" data-subtype="cliff">周末剧场 Weekend theater</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5899143777" data-nid="5899143777" data-subtype="crag">大沟底小岩壁</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3131047125" data-nid="3131047125" data-subtype="crag">大峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3131047197" data-nid="3131047197" data-subtype="crag">二峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3131047269" data-nid="3131047269" data-subtype="crag">三峰</a></li><li><a href="/zh_hans/climbing/china-mainland/sichuan-chongqing/4096-peak-4096" data-nid="3131047341" data-subtype="crag">幺妹峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8087055717" data-nid="8087055717" data-subtype="area">婆缪峰</a></li><li><a href="/zh_hans/climbing/china-mainland/sichuan-chongqing/cows-heart" data-nid="156268713" data-subtype="crag">牛心山</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8087291187" data-nid="8087291187" data-subtype="area">野人峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8087379321" data-nid="8087379321" data-subtype="area">女王峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8087381775" data-nid="8087381775" data-subtype="area">布达拉峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8090914251" data-nid="8090914251" data-subtype="area">鹰嘴岩</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/8100946512" data-nid="8100946512" data-subtype="crag">鲨鱼鳍</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3156056817" data-nid="3156056817" data-subtype="crag">羊满台</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3151404573" data-nid="3151404573" data-subtype="crag">半脊峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3153440271" data-nid="3153440271" data-subtype="crag">龙脊峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5902028247" data-nid="5902028247" data-subtype="cliff">瓦尔登瀑</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5902028319" data-nid="5902028319" data-subtype="cliff">乐园冰瀑</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5902028391" data-nid="5902028391" data-subtype="cliff">结斯沟1号冰壁</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3998477208" data-nid="3998477208" data-subtype="area">西岭雪山地区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3156086532" data-nid="3156086532" data-subtype="crag">大雪塘</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/4001106507" data-nid="4001106507" data-subtype="area">夹金山地区</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/4001265675" data-nid="4001265675" data-subtype="area">夏羌拉地区</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/4001243610" data-nid="4001243610" data-subtype="area">雅拉-莲花雪山地区</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3152067435" data-nid="3152067435" data-subtype="area">贡嘎山地区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3156106260" data-nid="3156106260" data-subtype="crag">木雅贡嘎</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3156106128" data-nid="3156106128" data-subtype="crag">中山峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3152080368" data-nid="3152080368" data-subtype="crag">那玛峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3156105996" data-nid="3156105996" data-subtype="crag">达多曼因</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3156105930" data-nid="3156105930" data-subtype="crag">勒多曼因</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3156105732" data-nid="3156105732" data-subtype="crag">嘉子峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3998468412" data-nid="3998468412" data-subtype="crag">下日乌且</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3152067501" data-nid="3152067501" data-subtype="area">仁宗雪山地区</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/4001261886" data-nid="4001261886" data-subtype="area">卡瓦洛日地区</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3149993385" data-nid="3149993385" data-subtype="area">雀儿山地区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/5366328915" data-nid="5366328915" data-subtype="crag">依寺夹塞峰</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3149994009" data-nid="3149994009" data-subtype="area">夏塞峰-扎金甲博地区</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6719306577" data-nid="6719306577" data-subtype="area">姊妹湖 Sister Lakes</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6722135088" data-nid="6722135088" data-subtype="area">20千之峰</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6722132313" data-nid="6722132313" data-subtype="cliff">到处跑的灵魂墙 Free Spirit Wall</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/sichuan-chongqing/shuang-qiao-valley" data-nid="156144072" data-subtype="crag">夏塞峰</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/sichuan-chongqing/shuang-qiao-valley/area/3175522524" data-nid="3175522524" data-subtype="crag">Contradition Spire Group</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/jarjinjabo" data-nid="156144120" data-subtype="crag">扎金甲博</a></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/chang-ping-valley" data-nid="156144096" data-subtype="crag">扎金甲姆</a></li></ul></li><li><a href="/zh_hans/climbing/china/sichuan-chongqing/area/3998498856" data-nid="3998498856" data-subtype="area">格聂山地区</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="3441786525" href="/zh_hans/climbing/china/area/3441786525" class=""><span class="primary-node-name">天津 Tianjin</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/9671770191" data-nid="9671770191" data-subtype="area">盘山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/9671776203" data-nid="9671776203" data-subtype="field">杨家后院</a></li><li><a href="/zh_hans/climbing/china/area/9671776752" data-nid="9671776752" data-subtype="field">鱼塘</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="831289587" href="/zh_hans/climbing/china/area/831289587" class=""><span class="primary-node-name">西藏 Tibet</span></a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/11666252949" data-nid="11666252949" data-subtype="area">林芝</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/831290721" data-nid="831290721" data-subtype="crag">夺底岩场 Lhasa Serra Cliff</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/2292736884" data-nid="2292736884" data-subtype="cliff">主岩壁</a></li><li><a href="/zh_hans/climbing/china/area/2292736944" data-nid="2292736944" data-subtype="cliff">独立石岩壁</a></li><li><a href="/zh_hans/climbing/china/area/2292737004" data-nid="2292737004" data-subtype="cliff">无名岩壁</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/3914393445" data-nid="3914393445" data-subtype="area">巴次普峰 Bartse Ri</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="1782016506" href="/zh_hans/climbing/china/area/1782016506" class=""><span class="primary-node-name">新疆 Xinjiang</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/3680584899" data-nid="3680584899" data-subtype="area">乌鲁木齐 Urumchi</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/2319809178" data-nid="2319809178" data-subtype="crag">达坂城攀岩公园</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/4706517135" data-nid="4706517135" data-subtype="crag">变色龙岩场</a></li><li><a href="/zh_hans/climbing/china/area/3680682609" data-nid="3680682609" data-subtype="crag">伤痕累累岩壁</a></li><li><a href="/zh_hans/climbing/china/area/3680682675" data-nid="3680682675" data-subtype="crag">姑娘追岩壁</a></li><li><a href="/zh_hans/climbing/china/area/3680682741" data-nid="3680682741" data-subtype="crag">可乐岩壁</a></li><li><a href="/zh_hans/climbing/china/area/3680682807" data-nid="3680682807" data-subtype="crag">旋转岩壁</a></li><li><a href="/zh_hans/climbing/china/area/3680682873" data-nid="3680682873" data-subtype="crag">茉莉岩壁</a></li><li><a href="/zh_hans/climbing/china/area/4706525040" data-nid="4706525040" data-subtype="crag">回龙岩壁</a></li><li><a href="/zh_hans/climbing/china/area/4706525880" data-nid="4706525880" data-subtype="crag">垂直降落岩壁</a></li><li><a href="/zh_hans/climbing/china/area/3680682939" data-nid="3680682939" data-subtype="crag">老狼崖</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/3680618481" data-nid="3680618481" data-subtype="crag">红岩冰壁</a></li><li><a href="/zh_hans/climbing/china/area/3680620515" data-nid="3680620515" data-subtype="crag">水西沟冰壁</a></li><li><a href="/zh_hans/climbing/china/area/3680621412" data-nid="3680621412" data-subtype="crag">白杨沟冰瀑</a></li><li><a href="/zh_hans/climbing/china/area/3680621955" data-nid="3680621955" data-subtype="crag">后峡冰壁</a></li><li><a href="/zh_hans/climbing/china/area/3680661360" data-nid="3680661360" data-subtype="crag">黑沟冰塔林冰壁</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/area/1782017340" data-nid="1782017340" data-subtype="crag">可可托海 Keketuohai</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/area/1782018999" data-nid="1782018999" data-subtype="cliff">Nipple Hill</a></li><li><a href="/zh_hans/climbing/china/area/2207821437" data-nid="2207821437" data-subtype="cliff">Crocodile Hill</a></li><li><a href="/zh_hans/climbing/china/area/2207832156" data-nid="2207832156" data-subtype="sector">Little Turtle</a></li><li><a href="/zh_hans/climbing/china/area/2207832762" data-nid="2207832762" data-subtype="area">Bridge Crags</a></li><li><a href="/zh_hans/climbing/china/area/2498442411" data-nid="2498442411" data-subtype="sector">The Fortress</a></li><li><a href="/zh_hans/climbing/china/area/2498445588" data-nid="2498445588" data-subtype="sector">Turtle Hill</a></li><li><a href="/zh_hans/climbing/china/area/2498454006" data-nid="2498454006" data-subtype="sector">Snowy Day Slab</a></li><li><a href="/zh_hans/climbing/china/area/2498456853" data-nid="2498456853" data-subtype="sector">The Knife Buttress</a></li><li><a href="/zh_hans/climbing/china/area/2498460762" data-nid="2498460762" data-subtype="sector">Divine Bell</a></li><li><a href="/zh_hans/climbing/china/area/2498465040" data-nid="2498465040" data-subtype="sector">The Flock</a></li><li><a href="/zh_hans/climbing/china/area/2498497305" data-nid="2498497305" data-subtype="sector">Shepherd Rock</a></li><li><a href="/zh_hans/climbing/china/area/2498497365" data-nid="2498497365" data-subtype="sector">Waterfall Fossil</a></li><li><a href="/zh_hans/climbing/china/area/2498490627" data-nid="2498490627" data-subtype="sector">Waterfall Rock</a></li><li><a href="/zh_hans/climbing/china/area/2498488782" data-nid="2498488782" data-subtype="sector">Tower of Tears</a></li><li><a href="/zh_hans/climbing/china/area/2498483601" data-nid="2498483601" data-subtype="sector">Small Bell</a></li><li><a href="/zh_hans/climbing/china/area/2498477595" data-nid="2498477595" data-subtype="sector">Elephant Hill</a></li><li><a href="/zh_hans/climbing/china/area/2498470887" data-nid="2498470887" data-subtype="sector">Hammer Rock</a></li><li><a href="/zh_hans/climbing/china/area/5514708423" data-nid="5514708423" data-subtype="cliff">五毒岩壁</a></li><li><a href="/zh_hans/climbing/china/area/8583351192" data-nid="8583351192" data-subtype="cliff">宝石塔</a></li></ul></li><li><a href="/zh_hans/climbing/china/area/7735529781" data-nid="7735529781" data-subtype="crag">阔克苏峡谷</a></li><li><a href="/zh_hans/climbing/china/area/3680668074" data-nid="3680668074" data-subtype="crag">玛纳斯河冰壁</a></li><li><a href="/zh_hans/climbing/china/area/3680668749" data-nid="3680668749" data-subtype="crag">乌苏巴音沟冰壁</a></li><li><a href="/zh_hans/climbing/china/area/3680669829" data-nid="3680669829" data-subtype="crag">库尔勒阿诗玛冰壁</a></li><li><a href="/zh_hans/climbing/china/area/3680670333" data-nid="3680670333" data-subtype="crag">哈密红山冰壁</a></li><li><a href="/zh_hans/climbing/china/area/4003528521" data-nid="4003528521" data-subtype="area">友谊峰地区</a></li><li><a href="/zh_hans/climbing/china/area/10250454447" data-nid="10250454447" data-subtype="area">天堂湖地区</a></li><li><a href="/zh_hans/climbing/china/area/12790453953" data-nid="12790453953" data-subtype="area">阿勒泰地区吉木乃县</a></li></ul></li><li class=" dropdown-submenu"><a data-nid="11877217" href="/zh_hans/climbing/china/yunnan" class=""><span class="primary-node-name">云南 Yunnan</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/area/10434727494" data-nid="10434727494" data-subtype="region">滇西地区</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan" data-nid="157767195" data-subtype="area">黎明 Liming</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/1512333114" data-nid="1512333114" data-subtype="crag">傈僳区 Lisu</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/790080789" data-nid="790080789" data-subtype="crag">立柱区 Pillars Area</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831401478" data-nid="831401478" data-subtype="crag">松顶拱壁区 Pinecrest Buttress</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831401838" data-nid="831401838" data-subtype="crag">原始北区 Primitive Area North</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831406689" data-nid="831406689" data-subtype="crag">五彩岩 Painted Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/3977525031" data-nid="3977525031" data-subtype="crag">安七尼飞拉达 Anqini Via Ferrata</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831401538" data-nid="831401538" data-subtype="crag">晚餐岩 Dinner Wall</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/790080849" data-nid="790080849" data-subtype="cliff">白垩纪区 Cretaceous Area</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831401358" data-nid="831401358" data-subtype="crag">洞区 Cave Area</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831401418" data-nid="831401418" data-subtype="crag">橙色天空区 Orange Sky Area</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831406569" data-nid="831406569" data-subtype="crag">假日区 The Holidays</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831401598" data-nid="831401598" data-subtype="crag">太空山区 Space Mountain</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831401778" data-nid="831401778" data-subtype="crag">四季区 Four Seasons Area</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/790080969" data-nid="790080969" data-subtype="crag">潘多拉区 Pandora</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/10380782880" data-nid="10380782880" data-subtype="area">Pandora Left</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/10380781224" data-nid="10380781224" data-subtype="area">Pandora Middle</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/7204447518" data-nid="7204447518" data-subtype="area">潘多拉 Pandora Right</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831401898" data-nid="831401898" data-subtype="crag">南方寓言区 The Southern Oracle</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/1512777699" data-nid="1512777699" data-subtype="crag">一条龙区 One Dragon</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831406749" data-nid="831406749" data-subtype="cliff">古龙壁 Old Dragon Buttress</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/1512395526" data-nid="1512395526" data-subtype="crag">The Watchtower</a></li></ul></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/7212653283" data-nid="7212653283" data-subtype="crag">Secret Garden</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/2462245107" data-nid="2462245107" data-subtype="crag">阳朔运动攀岩区 Yangshuo Sports Climbers' Crag</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/2462246856" data-nid="2462246856" data-subtype="cliff">Wifi Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/2462246922" data-nid="2462246922" data-subtype="cliff">Scifi Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/7772687769" data-nid="7772687769" data-subtype="cliff">Turtle Buttress</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/1512781383" data-nid="1512781383" data-subtype="cliff">Censored Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/1512781443" data-nid="1512781443" data-subtype="cliff">Uncensored Wall</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/7204111134" data-nid="7204111134" data-subtype="crag">加波底区 Jiabodi crags</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/7204195140" data-nid="7204195140" data-subtype="area">Space Force Buttress</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/7204193037" data-nid="7204193037" data-subtype="crag">Rainbow Cove</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/2462235087" data-nid="2462235087" data-subtype="crag">El Dorado</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/3223855188" data-nid="3223855188" data-subtype="sector">Animal House</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/3223884588" data-nid="3223884588" data-subtype="sector">Vertical</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/3918996903" data-nid="3918996903" data-subtype="sector">Far Right Side</a></li></ul></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/2462235021" data-nid="2462235021" data-subtype="crag">Goat Rodeo</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/3919058706" data-nid="3919058706" data-subtype="sector">黑怕哈米 Heibahami</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/1512763089" data-nid="1512763089" data-subtype="cliff">The Diamond</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831406629" data-nid="831406629" data-subtype="crag">守护者山谷 The Guardian Valley</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/7204681818" data-nid="7204681818" data-subtype="cliff">守护者 The Guardian</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831409398" data-nid="831409398" data-subtype="cliff">死亡天文台 Die Sternwarte</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831401718" data-nid="831401718" data-subtype="crag">Gorilla Face Crags</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/10492409415" data-nid="10492409415" data-subtype="area">Gorilla Cave</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/10492413465" data-nid="10492413465" data-subtype="crag">Gully Crag</a></li></ul></li></ul></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/790080909" data-nid="790080909" data-subtype="cliff">公牛峭壁 Bull Crag</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831401658" data-nid="831401658" data-subtype="crag">天使岩 Angel Crag</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/831406809" data-nid="831406809" data-subtype="crag">印第岩 Indy Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/liming-laojunshan/area/790080729" data-nid="790080729" data-subtype="cliff">远方区拱璧 Faraway Buttress</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/area/829141857" data-nid="829141857" data-subtype="area">石鼓 Shigu</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/area/3112242537" data-nid="3112242537" data-subtype="crag">Bai Yan Si 白岩寺</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/2438518491" data-nid="2438518491" data-subtype="field">Secret Garden 秘密花园</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/area/4494202812" data-nid="4494202812" data-subtype="crag">云塔山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/area/5517908829" data-nid="5517908829" data-subtype="cliff">第九区</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/area/829143543" data-nid="829143543" data-subtype="crag">Diamond Wall 钻石墙</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/area/831369333" data-nid="831369333" data-subtype="cliff">Left Wall 左墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/2772814212" data-nid="2772814212" data-subtype="cliff">Middle Wall 中墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/831369267" data-nid="831369267" data-subtype="cliff">Right Wall 右墙</a></li></ul></li><li><a href="/zh_hans/climbing/china/yunnan/area/829143603" data-nid="829143603" data-subtype="cliff">Water Rock 水岩</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/1513851039" data-nid="1513851039" data-subtype="cliff">The Courtyard 院子墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/2530175982" data-nid="2530175982" data-subtype="cliff">Stephen Wall 史帝芬墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/1513906227" data-nid="1513906227" data-subtype="cliff">Ritan Wall 日坛墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/1513906161" data-nid="1513906161" data-subtype="cliff">Morning Light 晨光墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/829143783" data-nid="829143783" data-subtype="cliff">The Pyramids 金字塔</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/area/2438460987" data-nid="2438460987" data-subtype="field">大洞抱石区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/area/2438464659" data-nid="2438464659" data-subtype="field">B</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/2438464770" data-nid="2438464770" data-subtype="field">C</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/2438464878" data-nid="2438464878" data-subtype="field">D</a></li></ul></li><li><a href="/zh_hans/climbing/china/yunnan/area/2190609798" data-nid="2190609798" data-subtype="cliff">Cave Right Side</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/829143303" data-nid="829143303" data-subtype="cliff">The Cave 大洞</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/1779664401" data-nid="1779664401" data-subtype="cliff">Rainbow Wall 彩虹墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/829143423" data-nid="829143423" data-subtype="cliff">Socks Wall 袜子墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/2797364481" data-nid="2797364481" data-subtype="cliff">The Long March Crag 长征墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/829143363" data-nid="829143363" data-subtype="cliff">Flying Squirrel 飞鼠岩</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/2190601365" data-nid="2190601365" data-subtype="cliff">Little Drip Cave 滴水洞</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/829143723" data-nid="829143723" data-subtype="cliff">Deception Wall 骗子墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/829143483" data-nid="829143483" data-subtype="cliff">Sunny Hill 朝阳坡</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/3383699358" data-nid="3383699358" data-subtype="cliff">Sky Burial Wall 天葬墙</a></li></ul></li><li><a href="/zh_hans/climbing/china/yunnan/area/3501782265" data-nid="3501782265" data-subtype="crag">丽江第五区岩场</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/da-li" data-nid="156148551" data-subtype="area">大理 Dali</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china-mainland/yunnan/shuanglang" data-nid="12486619" data-subtype="area">双廊 Shuang Lang</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china-mainland/yunnan/shuanglang/area/2113432782" data-nid="2113432782" data-subtype="crag">软 Softcore</a></li><li><a href="/zh_hans/climbing/china-mainland/yunnan/shuanglang/area/2113433412" data-nid="2113433412" data-subtype="crag">硬 Hardcore</a></li></ul></li><li><a href="/zh_hans/climbing/china-mainland/yunnan/binchuan" data-nid="12486643" data-subtype="crag">宾川观音箐 Binchuan Guanyinqing</a></li><li><a href="/zh_hans/climbing/china-mainland/yunnan/shimenguan" data-nid="125428908" data-subtype="crag">石门关 Shi Men Guan</a></li><li><a href="/zh_hans/climbing/china/yunnan/da-li/area/8071322481" data-nid="8071322481" data-subtype="field">大理坞抱石 Daliwood Bouldering</a></li><li><a href="/zh_hans/climbing/china/yunnan/da-li/area/3189247506" data-nid="3189247506" data-subtype="field">沙溪</a></li></ul></li><li><a href="/zh_hans/climbing/china/yunnan/area/3202754364" data-nid="3202754364" data-subtype="area">香格里拉 Shangri-La</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/4002877059" data-nid="4002877059" data-subtype="area">玉龙-哈巴雪山地区</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/4002881529" data-nid="4002881529" data-subtype="area">梅里-白马雪山地区</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/4002886374" data-nid="4002886374" data-subtype="area">巴拉格宗地区</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/kunming" data-nid="155762055" data-subtype="region">昆明 Kunming</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/western-hills" data-nid="2286142746" data-subtype="area">Western Hill 西山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/western-hills/area/7187001987" data-nid="7187001987" data-subtype="crag">鸽子岩 Dove Rock</a></li><li><a href="/zh_hans/climbing/china/yunnan/western-hills/area/2231403663" data-nid="2231403663" data-subtype="crag">猫头鹰岩 Low Area</a></li><li><a href="/zh_hans/climbing/china/yunnan/western-hills/area/2231403729" data-nid="2231403729" data-subtype="crag">观海阁岩 High Area</a></li><li><a href="/zh_hans/climbing/china/yunnan/western-hills/area/7373468487" data-nid="7373468487" data-subtype="cliff">大岩壁</a></li><li><a href="/zh_hans/climbing/china/yunnan/western-hills/area/2262961722" data-nid="2262961722" data-subtype="crag">黑墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/western-hills/area/2262432363" data-nid="2262432363" data-subtype="crag">红石墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/western-hills/area/7012789011" data-nid="7012789011" data-subtype="crag">大青山</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/kunming/area/2262916872" data-nid="2262916872" data-subtype="area">团结街道</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/xiao-mo-yu-cave" data-nid="153529431" data-subtype="crag">小墨雨洞 Xiao Mo Yu Cave</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/3126493020" data-nid="3126493020" data-subtype="area">奶爸墙 Daddy's Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/545742717" data-nid="545742717" data-subtype="crag">甜蜜墙 Honey Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/545742255" data-nid="545742255" data-subtype="crag">孕期墙 Pregnancy Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/543876516" data-nid="543876516" data-subtype="crag">墓地 The Graveyard</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/544415352" data-nid="544415352" data-subtype="crag">炸药墙 TNT Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/544436139" data-nid="544436139" data-subtype="crag">大墨雨 Wind Tunnel</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/kunming/area/544282092" data-nid="544282092" data-subtype="crag">Swallow Cave 燕子洞</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/3262758381" data-nid="3262758381" data-subtype="cliff">Shady Grove 林荫墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/3262886409" data-nid="3262886409" data-subtype="cliff">Cave 洞</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/3262895673" data-nid="3262895673" data-subtype="cliff">The Hot Spot 热点</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/3262896333" data-nid="3262896333" data-subtype="cliff">The Red Wall 红墙</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/4472253792" data-nid="4472253792" data-subtype="field">boulder 谷底攀石</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/fumin-canyon" data-nid="12486595" data-subtype="crag">富民谷 Fumin Canyon</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980811" data-nid="13980811" data-subtype="cliff">眼睛洞 Eye Cave</a></li><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980643" data-nid="13980643" data-subtype="cliff">落水墙 Splash Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980667" data-nid="13980667" data-subtype="cliff">桔子墙 Orange Face</a></li><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980691" data-nid="13980691" data-subtype="cliff">Cave Crag</a></li><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980715" data-nid="13980715" data-subtype="cliff">哭墙 Weeping Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980787" data-nid="13980787" data-subtype="cliff">阿迪达斯墙 Addidas Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980739" data-nid="13980739" data-subtype="cliff">阴影墙 Shadow Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980763" data-nid="13980763" data-subtype="cliff">走墙 Just Go Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980835" data-nid="13980835" data-subtype="cliff">下老红岩 Lower Old Red Rock</a></li><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980859" data-nid="13980859" data-subtype="cliff">彩虹墙 Rainbow Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980883" data-nid="13980883" data-subtype="cliff">道哥墙 Doug's Wall</a></li><li><a href="/zh_hans/climbing/china/yunnan/fumin-canyon/area/13980907" data-nid="13980907" data-subtype="cliff">上老红岩 Upper Old Red Rock</a></li></ul></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/545742783" data-nid="545742783" data-subtype="crag">大岩头 The Gash</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/kunming/area/2284583157" data-nid="2284583157" data-subtype="area">抚仙湖</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/2284585239" data-nid="2284585239" data-subtype="crag">海口玉皇阁</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/12216498849" data-nid="12216498849" data-subtype="crag">红石岩</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/2286140475" data-nid="2286140475" data-subtype="crag">大湾</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/kunming/area/8065813368" data-nid="8065813368" data-subtype="area">石林 Stone Forest</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/8065867398" data-nid="8065867398" data-subtype="crag">石林一号</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/8065870455" data-nid="8065870455" data-subtype="crag">石林二号</a></li><li><a href="/zh_hans/climbing/china/yunnan/kunming/area/8065870521" data-nid="8065870521" data-subtype="crag">石林火车站</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/area/7008859896" data-nid="7008859896" data-subtype="area">西双版纳</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/area/2282427849" data-nid="2282427849" data-subtype="crag">基诺山</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/area/7019868000" data-nid="7019868000" data-subtype="crag">达西利</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/area/7008860517" data-nid="7008860517" data-subtype="cliff">A</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/7019868702" data-nid="7019868702" data-subtype="cliff">B</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/area/10434727440" data-nid="10434727440" data-subtype="region">滇东南地区</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/area/1825754016" data-nid="1825754016" data-subtype="area">普者黑</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/yunnan/area/5674655568" data-nid="5674655568" data-subtype="area">蒙自市 Mengzi City</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/yunnan/area/5674808448" data-nid="5674808448" data-subtype="crag">西北勒乡撮莫底 Simodi Xibeile Township</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/3042642555" data-nid="3042642555" data-subtype="crag">芷村 Zhicun Village</a></li><li><a href="/zh_hans/climbing/china/yunnan/area/11462928075" data-nid="11462928075" data-subtype="crag">西北勒乡上呼土 Shanghutu Xibeile Township</a></li></ul></li><li><a href="/zh_hans/climbing/china/yunnan/area/7966016982" data-nid="7966016982" data-subtype="crag">罗平白石岩</a></li></ul></li></ul></li><li class=" dropdown-submenu"><a data-nid="154039896" href="/zh_hans/climbing/china/zhejiang-jiangsu" class=""><span class="primary-node-name">浙江 Zhejiang</span></a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1872875460" data-nid="1872875460" data-subtype="field">小洋山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2311619196" data-nid="2311619196" data-subtype="field">小洋山A&amp;B区</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2311627938" data-nid="2311627938" data-subtype="field">小洋山C区</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2311631724" data-nid="2311631724" data-subtype="field">小洋山D区</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2311798038" data-nid="2311798038" data-subtype="field">小洋山E区</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/6182438463" data-nid="6182438463" data-subtype="field">小洋山F区</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1825757517" data-nid="1825757517" data-subtype="region">杭州 Hangzhou</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/nan-gao-peak" data-nid="156178281" data-subtype="crag">南高峰 Nan Gao Peak</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/nan-gao-peak/area/1342228269" data-nid="1342228269" data-subtype="cliff">南高峰山顶 Nan Gao Cliff</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/nan-gao-peak/area/1342228335" data-nid="1342228335" data-subtype="cliff">千人洞 Qianren Cave</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/nan-gao-peak/area/3241237029" data-nid="3241237029" data-subtype="crag">荣幸岩场</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/nan-gao-peak/area/2311347003" data-nid="2311347003" data-subtype="unknown">停车场 Parking lot</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2704901400" data-nid="2704901400" data-subtype="area">灵山</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2621961267" data-nid="2621961267" data-subtype="crag">风水洞</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/ke-xiao" data-nid="156177507" data-subtype="crag">可笑 Ke Xiao</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2312603256" data-nid="2312603256" data-subtype="crag">回归岩壁 HuiGui Cliff</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/563680785" data-nid="563680785" data-subtype="crag">狮头岩 / Lion's Head</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1047553878" data-nid="1047553878" data-subtype="cliff">Crazy Corners</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/8730814233" data-nid="8730814233" data-subtype="cliff">Joe's Valley</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/9005456082" data-nid="9005456082" data-subtype="cliff">The Landing Zone</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1051890429" data-nid="1051890429" data-subtype="cliff">The Prow</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1051910385" data-nid="1051910385" data-subtype="cliff">Mika's Ledge</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/12579514029" data-nid="12579514029" data-subtype="sector">Gliddon's / 格里登墙</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1129832808" data-nid="1129832808" data-subtype="cliff">Midlands</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1132951335" data-nid="1132951335" data-subtype="cliff">Highlands</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/4781247423" data-nid="4781247423" data-subtype="sector">The People's Wall</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/9039189963" data-nid="9039189963" data-subtype="sector">The Lookout</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1132989330" data-nid="1132989330" data-subtype="sector">Lower 40</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1500896535" data-nid="1500896535" data-subtype="sector">The Come-Along Crag</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1132932843" data-nid="1132932843" data-subtype="sector">Mammut's Hump</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/8454133884" data-nid="8454133884" data-subtype="cliff">Big Rig</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1838474028" data-nid="1838474028" data-subtype="cliff">Trad</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/6553389564" data-nid="6553389564" data-subtype="field">Bouldering</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/big-stone-gate" data-nid="156177531" data-subtype="crag">大石门 Big Stone Gate</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/small-stone-gate" data-nid="156177555" data-subtype="crag">小石门 Small Stone Gate</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/3389125197" data-nid="3389125197" data-subtype="crag">梅家坞</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/4371016779" data-nid="4371016779" data-subtype="field">宝石山 Precious Stone Hill</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2907405858" data-nid="2907405858" data-subtype="field">保俶塔区</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/4371796719" data-nid="4371796719" data-subtype="boulder">屋后裂缝区</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/4371018237" data-nid="4371018237" data-subtype="boulder">45度墙</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/12229017732" data-nid="12229017732" data-subtype="area">临安山田深水抱</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/4545519930" data-nid="4545519930" data-subtype="field">临安天岩谷</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2286160098" data-nid="2286160098" data-subtype="region">绍兴 Shaoxing</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/7720210029" data-nid="7720210029" data-subtype="crag">百丈岩</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/3380995791" data-nid="3380995791" data-subtype="crag">百丈岩神雕崖</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/7695630051" data-nid="7695630051" data-subtype="cliff">百丈岩望雕崖</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xin-chang" data-nid="156177177" data-subtype="crag">新昌石狗洞 Shigoudong</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xin-chang/area/1431490071" data-nid="1431490071" data-subtype="cliff">大岩壁 Big Wall</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xin-chang/area/1845763683" data-nid="1845763683" data-subtype="cliff">传统攀 Trad</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xin-chang/area/1704828471" data-nid="1704828471" data-subtype="cliff">半山腰 Hillside</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xin-chang/area/1845750936" data-nid="1845750936" data-subtype="cliff">长坂坡区</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xin-chang/area/1705456089" data-nid="1705456089" data-subtype="cliff">主岩壁 Main Cliff</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xin-chang/area/1431489939" data-nid="1431489939" data-subtype="cliff">大屋檐 Big Roof</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xin-chang/area/3243118008" data-nid="3243118008" data-subtype="cliff">新岩壁</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xin-chang/area/1431490005" data-nid="1431490005" data-subtype="cliff">小屋檐 Small Roof</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/985610046" data-nid="985610046" data-subtype="crag">大石瀑 Dashipu</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/3178789992" data-nid="3178789992" data-subtype="crag">新昌韩妃江岩壁</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/3178792710" data-nid="3178792710" data-subtype="crag">新昌天烛湖岩壁</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/3380993514" data-nid="3380993514" data-subtype="crag">新昌沙溪镇天地岩</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/8423459613" data-nid="8423459613" data-subtype="area">Xihuayao village, Shangyu 上虞西华瑶村</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/9094365210" data-nid="9094365210" data-subtype="area">老鹰嘴 Eagle beak</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/9264669816" data-nid="9264669816" data-subtype="area">宛委山 Wanwei mountain</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1825768464" data-nid="1825768464" data-subtype="region">宁波 Ningbo</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/910869483" data-nid="910869483" data-subtype="field">鄞州攀岩公园 Yinjiangcun</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/882424491" data-nid="882424491" data-subtype="crag">宁波周公宅 Zhougongzhai</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2325981987" data-nid="2325981987" data-subtype="area">珠山尖 Zhu Shan</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2325985773" data-nid="2325985773" data-subtype="cliff">岩壁 Cliff</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2326002222" data-nid="2326002222" data-subtype="field">溪流抱石区 Stream-bed boulder field</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2326002321" data-nid="2326002321" data-subtype="field">竹林抱石区1</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2326002420" data-nid="2326002420" data-subtype="field">竹林抱石区2</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2325884859" data-nid="2325884859" data-subtype="crag">溪口商量岗 Shangliang Gang</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1477928979" data-nid="1477928979" data-subtype="crag">溪口三十六湾村 San Shi Liu Wan Cun</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1502157771" data-nid="1502157771" data-subtype="crag">小岩壁 East Cliff</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2325961770" data-nid="2325961770" data-subtype="cliff">大岩壁 West Cliff</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/8593239207" data-nid="8593239207" data-subtype="crag">奉化曰岭 Yueling</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1872856566" data-nid="1872856566" data-subtype="crag">奉化狮子山 Lion Cliff</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1015857468" data-nid="1015857468" data-subtype="crag">奉化西岙 Xi Ao Valley</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2325819948" data-nid="2325819948" data-subtype="cliff">A.</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1109877699" data-nid="1109877699" data-subtype="cliff">B. Big Red Cave</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1109858355" data-nid="1109858355" data-subtype="cliff">C. Bee House</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1109877765" data-nid="1109877765" data-subtype="cliff">D. The Bath House</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/926104308" data-nid="926104308" data-subtype="cliff">Chang An Jiao</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/880830861" data-nid="880830861" data-subtype="crag">象山 Xiangshan</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/3857674554" data-nid="3857674554" data-subtype="area">渔山岛</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1825764861" data-nid="1825764861" data-subtype="region">台州 Taizhou</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xian-ju" data-nid="156178305" data-subtype="crag">仙居 Xianju</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xian-ju/area/1038362169" data-nid="1038362169" data-subtype="crag">牛鼻洞 Niubidong</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xian-ju/area/1038371541" data-nid="1038371541" data-subtype="cliff">主岩场 Main Wall</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xian-ju/area/1038371685" data-nid="1038371685" data-subtype="cliff">上岩场 Upper Wall</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/xian-ju/area/10250579430" data-nid="10250579430" data-subtype="area">碧石洞</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/920666187" data-nid="920666187" data-subtype="crag">白岩下 Baiyanxia</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1856989515" data-nid="1856989515" data-subtype="region">衢州 Quzhou</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/920673297" data-nid="920673297" data-subtype="crag">两头洞 U Cave</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1822973511" data-nid="1822973511" data-subtype="sector">A</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1822973571" data-nid="1822973571" data-subtype="sector">B</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1822973631" data-nid="1822973631" data-subtype="sector">C</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1822973691" data-nid="1822973691" data-subtype="sector">D</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1822973751" data-nid="1822973751" data-subtype="sector">E</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2770070610" data-nid="2770070610" data-subtype="sector">F</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2770070676" data-nid="2770070676" data-subtype="sector">G</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2653876680" data-nid="2653876680" data-subtype="sector">H</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1824391986" data-nid="1824391986" data-subtype="crag">大唐村</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/1857101703" data-nid="1857101703" data-subtype="crag">上方镇芝溪山庄</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2713251894" data-nid="2713251894" data-subtype="region">金华</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/shou-xian-gorge" data-nid="156176802" data-subtype="crag">武义寿仙谷</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2713240524" data-nid="2713240524" data-subtype="crag">金华灶头</a></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/5099298765" data-nid="5099298765" data-subtype="crag">东阳市马宅镇梅谷</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/7771751586" data-nid="7771751586" data-subtype="cliff">东侧岩壁</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/7771747938" data-nid="7771747938" data-subtype="cliff">西侧岩壁</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/6042164526" data-nid="6042164526" data-subtype="crag">横店绕溪村</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/6043644429" data-nid="6043644429" data-subtype="crag">横店马二</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2842834128" data-nid="2842834128" data-subtype="region">温州 Wenzhou</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2842835598" data-nid="2842835598" data-subtype="area">泰顺 Taishun</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/2842896561" data-nid="2842896561" data-subtype="crag">红岩瀑布 Red Rock Fall</a></li></ul></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/3841615914" data-nid="3841615914" data-subtype="crag">黄龙攀岩场</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/10019711976" data-nid="10019711976" data-subtype="crag">乐清白石</a></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/5679187038" data-nid="5679187038" data-subtype="region">舟山 Zhoushan</a><ul class="dropdown-menu"><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/5679236730" data-nid="5679236730" data-subtype="field">朱家尖Zhujiajian</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/6556991328" data-nid="6556991328" data-subtype="field">Sector A</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/6557106210" data-nid="6557106210" data-subtype="field">Sector B</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/6557108745" data-nid="6557108745" data-subtype="field">Sector C</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/6557114115" data-nid="6557114115" data-subtype="field">Sector D</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/6557908329" data-nid="6557908329" data-subtype="field">Off-site</a></li></ul></li></ul></li><li class="dropdown-submenu"><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/6282883890" data-nid="6282883890" data-subtype="region">丽水</a><ul class="dropdown-menu"><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/3841607610" data-nid="3841607610" data-subtype="crag">丽水缙云鼎湖峰</a></li><li><a href="/zh_hans/climbing/china/zhejiang-jiangsu/area/6282898833" data-nid="6282898833" data-subtype="crag">佛星岩</a></li></ul></li></ul></li></ul>"""

# %% [markdown]
# 解析html

# %%
def _first_direct_child(tag: Tag, name: str):
    for ch in tag.children:
        if isinstance(ch, Tag) and ch.name == name:
            return ch
    return None


def _all_direct_children(tag: Tag, name: str):
    out = []
    for ch in tag.children:
        if isinstance(ch, Tag) and ch.name == name:
            out.append(ch)
    return out


def _extract_text_from_a(a: Tag) -> str:
    # 1) 优先 primary-node-name
    span = a.select_one("span.primary-node-name")
    if span and span.get_text(strip=True):
        return span.get_text(strip=True)

    # 2) 否则用 a 的可见文本（去掉多余空白）
    txt = " ".join(a.stripped_strings)
    return txt


def parse_li(li: Tag) -> dict:
    a = li.find("a", recursive=False)
    if not a:
        # 有些 li 可能没有直接 a
        return {"title": None, "href": None, "data_nid": None, "data_subtype": None, "children": []}

    node = {
        "title": _extract_text_from_a(a).replace("/ ", "") or None,
        "href": a.get("href"),
        "data_nid": a.get("data-nid"),
        "data_subtype": a.get("data-subtype"),
        "children": [],
    }

    # theCrag 这种结构里，子列表一般是 li 下面的直接 <ul>（dropdown-menu 或普通 ul）
    child_ul = _first_direct_child(li, "ul")
    if child_ul:
        node["children"] = parse_ul(child_ul)

    return node


def parse_ul(ul: Tag) -> list:
    items = []
    for li in _all_direct_children(ul, "li"):
        items.append(parse_li(li))
    return items


soup = BeautifulSoup(htmlstring, "lxml")
root_ul = soup.find("ul")
data = parse_ul(root_ul)
data.pop(0)  # 去掉第一个无用节点
# Out:
# {'title': 'China',
#  'href': '/zh_hans/climbing/china',
#  'data_nid': '11746747',
#  'data_subtype': None,
#  'children': []}

# %% [markdown]
# 删除无用字段

# %%
def recursive_delete(nodes: list, parent_type: str = None):
    to_be_removed = []
    for i, node in enumerate(nodes):
        recursive_delete(node["children"], parent_type=node.get("data_subtype"))
        node.pop("href", None)
        node.pop("data_nid", None)

        if len(node["children"]) == 0:
            continue

    for index in reversed(to_be_removed):
        nodes.pop(index)


# def recursive_print_type(nodes: list, depth: int = 0):
#     for node in nodes:
#         print(f'{" "*depth*2}{node.get("data_subtype")}')
#         recursive_print_type(node.get("children", []), depth + 1)


recursive_delete(data)
data
# Out:
# [{'title': '安徽 Anhui',
#   'data_subtype': None,
#   'children': [{'title': '萧县天门寺', 'data_subtype': 'crag', 'children': []},
#    {'title': '蚌埠梅花山', 'data_subtype': 'region', 'children': []},
#    {'title': '合肥茶壶山', 'data_subtype': 'cliff', 'children': []},
#    {'title': '芜湖',
#     'data_subtype': 'area',
#     'children': [{'title': '芜湖繁昌戴店',
#       'data_subtype': 'crag',
#       'children': [{'title': '南岩壁', 'data_subtype': 'cliff', 'children': []},
#        {'title': '大岩壁', 'data_subtype': 'sector', 'children': []},
#        {'title': '攀石区', 'data_subtype': 'sector', 'children': []},
#        {'title': '高台', 'data_subtype': 'sector', 'children': []},
#        {'title': '推广区', 'data_subtype': 'sector', 'children': []},
#        {'title': '中岩壁', 'data_subtype': 'sector', 'children': []},
#        {'title': '小岩壁', 'data_subtype': 'sector', 'children': []}]},
#      {'title': '南陵笔架山', 'data_subtype': 'crag', 'children': []}]},
#    {'title': '宣城市',
#     'data_subtype': 'area',
# ...

# %% [markdown]
# 深度优先，建立递归路径，在抵达最后一个节点时，对该路径上的节点进行处理。对于不同省份，需要分别处理

# %%
def get_all_paths_recursive(node, parent_path=[], all_branches=[]):
    current_path = parent_path.copy()
    current_path.append(node)

    if node["children"]:
        for child in node["children"]:
            get_all_paths_recursive(child, parent_path=current_path, all_branches=all_branches)
    else:
        all_branches.append(current_path)
        return


# 处理所有节点
for root_node in data:
    branches_from_root_node = []
    get_all_paths_recursive(root_node, all_branches=branches_from_root_node)

    for branch in branches_from_root_node:
        print([f'{b["title"]}({b["data_subtype"]})' for b in branch])
    print("\n\n")

    for branch in branches_from_root_node:
        first_crag_idx = next((i for i, n in enumerate(branch) if n.get("data_subtype") == "crag"), None)

        for idx, node in enumerate(branch):
            if any(keyword in (node["title"]) for keyword in ["天门山 Tianmen Mountain", "精灵谷 Jinglinggu"]):  # 北京白河
                first_crag_idx = idx + 1
                branch[first_crag_idx]["data_subtype"] = "crag"
            if any(keyword in (node["title"]) for keyword in ["乐业 Leye", "柳州 Liuzhou", "北流 BeiLiu"]):  # 广西
                first_crag_idx = idx + 1
                branch[first_crag_idx]["data_subtype"] = "crag"
            if any(keyword in (node["title"]) for keyword in ["张家界槟榔谷", "娄底湄江"]):  # 湖南
                first_crag_idx = idx + 1
                branch[first_crag_idx]["data_subtype"] = "crag"
            if any(keyword in (node["title"]) for keyword in ["辽阳", "葫芦岛市建昌县"]):  # 辽宁
                first_crag_idx = idx + 1
                branch[first_crag_idx]["data_subtype"] = "crag"
            if any(keyword == node["title"] for keyword in ["苏州", "常熟虞山 Changshu-Yushan"]):  # 江苏
                first_crag_idx = idx + 1
                branch[first_crag_idx]["data_subtype"] = "crag"
            if any(keyword == node["title"] for keyword in ["宜春洪塘"]):  # 江西
                first_crag_idx = idx + 1
                branch[first_crag_idx]["data_subtype"] = "crag"
            if any(keyword == node["title"] for keyword in ["大峪 Dayu"]):  # 陕西
                first_crag_idx = idx + 1
                branch[first_crag_idx]["data_subtype"] = "crag"
            if any(keyword == node["title"] for keyword in ["青岛 Qingdao"]):  # 山东
                first_crag_idx = idx + 1
                branch[first_crag_idx]["data_subtype"] = "crag"
            if any(keyword == node["title"] for keyword in ["江油腰悬岩", "德阳古店乡 Gudian Village", "乐山峨眉", "稻城 Dao Cheng"]):  # 四川
                first_crag_idx = idx + 1
                branch[first_crag_idx]["data_subtype"] = "crag"
            if any(keyword == node["title"] for keyword in ["可可托海 Keketuohai"]):  # 新疆
                first_crag_idx = idx + 1
                branch[first_crag_idx]["data_subtype"] = "crag"
            if any(keyword == node["title"] for keyword in ["南高峰 Nan Gao Peak", "宝石山 Precious Stone Hill(region)"]):  # 浙江
                first_crag_idx = idx + 1
                branch[first_crag_idx]["data_subtype"] = "crag"
        # set type to region for all nodes before first crag
        if first_crag_idx is not None:
            for i in range(first_crag_idx):
                branch[i]["data_subtype"] = "region"
            # for the node after the first crag, set the last node to wall, and the nodes in between to zone
            if first_crag_idx + 1 < len(branch):
                if branch[-1]["data_subtype"] == "cliff":
                    branch[-1]["data_subtype"] = "wall"
                elif branch[-1]["data_subtype"] == "boulder":
                    branch[-1]["data_subtype"] = "bloc"
                else:
                    branch[-1]["data_subtype"] = "wall"
                for i in range(first_crag_idx + 1, len(branch) - 1):
                    branch[i]["data_subtype"] = "zone"
        else:
            # no crag found, set all to region, set last node to crag
            if branch[-1]["data_subtype"] == "boulder":
                branch[-1]["data_subtype"] = "bloc"
                branch[-2]["data_subtype"] = "crag"
                for i in range(len(branch) - 2):
                    branch[i]["data_subtype"] = "region"
            else:
                branch[-1]["data_subtype"] = "crag"
                for i in range(len(branch) - 1):
                    branch[i]["data_subtype"] = "region"

        print([f'{b["title"]}({b["data_subtype"]})' for b in branch])
# Out:
# ['安徽 Anhui(None)', '萧县天门寺(crag)']
# ['安徽 Anhui(None)', '蚌埠梅花山(region)']
# ['安徽 Anhui(None)', '合肥茶壶山(cliff)']
# ['安徽 Anhui(None)', '芜湖(area)', '芜湖繁昌戴店(crag)', '南岩壁(cliff)']
# ['安徽 Anhui(None)', '芜湖(area)', '芜湖繁昌戴店(crag)', '大岩壁(sector)']
# ['安徽 Anhui(None)', '芜湖(area)', '芜湖繁昌戴店(crag)', '攀石区(sector)']
# ['安徽 Anhui(None)', '芜湖(area)', '芜湖繁昌戴店(crag)', '高台(sector)']
# ['安徽 Anhui(None)', '芜湖(area)', '芜湖繁昌戴店(crag)', '推广区(sector)']
# ['安徽 Anhui(None)', '芜湖(area)', '芜湖繁昌戴店(crag)', '中岩壁(sector)']
# ['安徽 Anhui(None)', '芜湖(area)', '芜湖繁昌戴店(crag)', '小岩壁(sector)']
# ['安徽 Anhui(None)', '芜湖(area)', '南陵笔架山(crag)']
# ['安徽 Anhui(None)', '宣城市(area)', '宣城泾县狮子山(crag)']
# ['安徽 Anhui(None)', '宣城市(area)', '宣城市溪口镇金狮洞(area)']
# ['安徽 Anhui(None)', '宣城市(area)', '板桥大石壁(crag)']
# ['安徽 Anhui(None)', '宣城市(area)', '绩溪饭甑尖(crag)']
# ['安徽 Anhui(None)', '宣城市(area)', '障山大峡谷(area)', '百丈岩(crag)']
# ['安徽 Anhui(None)', '宣城市(area)', '绩溪龙须山(field)']
# ['安徽 Anhui(None)', '安庆坦埠(crag)']
#
#
#
# ['安徽 Anhui(region)', '萧县天门寺(crag)']
# ...

# %%
output_file = "/Users/liao/myProjects/VSCode_workspace/rockbook/resources/crags.json"
with open(output_file, "w", encoding="utf-8") as f:
    f.write(json.dumps(data, ensure_ascii=False, indent=2))

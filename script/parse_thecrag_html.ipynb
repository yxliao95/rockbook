# %%
import os
import json
from bs4 import BeautifulSoup, Tag

with open("/Users/liao/myProjects/VSCode_workspace/rockbook/resources/thecrag1/thecrag.jsonl", "r") as f:
    data = [json.loads(line) for line in f]

data[0]
# Out:
# {'input': 'https://www.thecrag.com/zh_hans/climbing/china/sichuan-chongqing/area/6025170000',
#  'result': '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<!doctype html>\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="zh_hans" lang="zh_hans" xmlns:og="http://opengraphprotocol.org/schema/">\n<head>\n<link rel="preconnect" href="https://static.thecrag.com">\n<link rel="preconnect" href="https://image.thecrag.com">\n\n\n<meta http-equiv="Content-Security-Policy" content="upgrade-insecure-requests" />\n<meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n\n<link rel="alternate" hreflang="de" href="https://www.thecrag.com/de/klettern/china/sichuan-chongqing/area/6025170000" />\n<link rel="alternate" hreflang="en" href="https://www.thecrag.com/en/climbing/china/sichuan-chongqing/area/6025170000" />\n<link rel="alternate" hreflang="es" href="https://www.thecrag.com/es/escalar/china/sichuan-chongqing/area/6025170000" />\n<link rel="alternate" hreflang="fr" href="https://www.thecrag.com/fr/grimper/china/sichuan-chongqing/area/6025170000" />\n<link rel="alternate" hreflang="it" href="https://www.thecrag.com/it/arrampicata/china/sichuan-chongqing/area/6025170000" />\n<link rel="alternate" hreflang="ko" href="https://www.thecrag.com/ko/climbing/china/sichuan-chongqing/area/6025170000" />\n<link rel="alternate" hreflang="pt" href="https://www.thecrag.com/pt/escalando/china/sichuan-chongqing/area/6025170000" />\n<link rel="alternate" hreflang="zh-hans" href="https://www.thecrag.com/zh_hans/climbing/china/sichuan-chongqing/area/6025170000" />\n<link rel="canonical" href="https://www.thecrag.com/zh_hans/climbing/china/sichuan-chongqing/area/6025170000" />\n\n<title>内江市威远县永兴村, 攀登 | theCrag</title>\n\n<meta property="fb:app_id" content="141410435911098" />\n<meta property="og:url" content="https://www.thecrag.com/zh_hans/climbing/china/sichuan-chongqing/area/6025170000" />\n<meta property="og:site_name" content="theCrag" />\n<meta property="og:title" content="内江市威远县永兴村, 攀登 | theCrag" />\n<meta property="place:location:longitude" content="104.54794015182" />\n<meta property="place:location:latitude" content="29.73641832683" />\n<meta property="og:type" content="website" />\n\n\n<meta name="description"        content="[大魏的路书](https://mp.weixin.qq.com/s/7PHCkzRF-xT6CaBeBqA3CA) : 这里的地貌比较具有地方特色，属于穹隆地貌，官方说法“威远是目前世界上发现面积最大的穹隆地貌，面积约641.5平方公里。\n\n[大魏路书更新2022.7.11](https://mp.weixin.qq.com/s/6sJ4p6CVQHXzh8lo6QLyUA)" />\n<meta property="og:description" content="[大魏的路书](https://mp.weixin.qq.com/s/7PHCkzRF-xT6CaBeBqA3CA) : 这里的地貌比较具有地方特色，属于穹隆地貌，官方说法“威远是目前世界上发现面积最大的穹隆地貌，面积约641.5平方公里。\n\n[大魏路书更新2022.7.11](https://mp.weixin.qq.com/s/6sJ4p6CVQHXzh8lo6QLyUA)" />\n<link rel="shortcut icon" href="https://static.thecrag.com/cids/images/favicon-1.1.1.ico" type="image/x-icon" />\n<meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=3">\n<link rel="apple-touch-icon-precomposed" href="https://static.thecrag.com/cids/images/logo-114-1.1.1.png" sizes="114x114"/>\n\n<link rel="search" type="application/opensearchdescription+xml" href="/open-search.xml?v=2" title="Search theCrag" />\n\n\n\n\n\n<link rel="stylesheet" type="text/css" media="all" href="https://static.thecrag.com/cids/portal-1.1.115.css" />\n<link rel="stylesheet" type="text/css" media="all" href="https://static.thecrag.com/cids/bootstrap-forms-1.1.3.css" />\n<script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/1.8.3/jquery.js"></script>\n\n\n\n\n\n<!--[if lt IE 8]>\n<script src="https://cdnjs.cloudflare.com/ajax/libs/json2/20160511/json2.min.js"></script>\n<![endif]-->\n\n\n\n\n<script>\nvar staticBase = \'https://static.thecrag.com/\';\n</script>\n</head>\n<body id="default" class="  responsive" data-nid="6025170000" data-kudos="46">\n\n<!-- Global site tag (gtag.js) - Google Analytics -->\n<script async src="https://www.googletagmanager.com/gtag/js?id=G-E4F0QR29VH"></script>\n<script type="text/javascript">\n    window.dataLayer = window.dataLayer || [];\n    function gtag(){dataLayer.push(arguments);}\n    gtag(\'js\', new Date());\n \n    gt ...

# %%
soup = BeautifulSoup(data[0]["result"], "lxml")
data_nid = soup.find("body").get("data-nid")

main_contain = soup.select_one("#wrapper div.regions__content div.regions__read")

info_nodes = main_contain.select("div.regions__read div.node-info")
sub_info_tables = main_contain.select_one("div.regions__read form")
sub_info_nodes = sub_info_tables.select("div[data-nid]")

print(sub_info_nodes[0].get("class", []))

print(len(sub_info_nodes))  # 子 div 数量
sub_info_nodes[0]
# Out:
# ['area']
# 3
# <div class="area" data-nid="6025167690">
# <div class="loc"><a class="mappin located" href="/zh_hans/climbing/china/sichuan-chongqing/area/6025167690/locate" title="Located">1</a></div>
# <div class="name"><a href="/zh_hans/climbing/china/sichuan-chongqing/area/6025167690"><span class="primary-node-name">运动攀岩场</span></a>
# <span class="type">岩场</span>
# </div>
# <div class="style">
# <a href="/routes/at/6025167690/with-gear-style/sport/" title="过滤至10条运动攀岩线路"><b class="bullet sport"></b> 所有 运动攀岩</a></div>
# <div class="stats">
# <div class="routes">10</div>
# <div class="ticks">0</div>
# <div class="height">24m</div>
# <div class="grades"><div class="band grade-band"><b class="gb2" style="width: 9.1%" title="1 进阶攀岩者 线路"></b><b class="gb3" style="width: 63.64%" title="7 经验丰富的攀岩者 线路"></b><b class="gb4" style="width: 27.28%" title="3 攀岩专家 线路"></b></div>
# </div>
# <div class="topos"> </div>
# <div class="a-pop"><a class="iblock pop pop--0" href="/zh_hans/climbing/china/sichuan-chongqing/area/6025167690/ascents" title="Relative popularity (0) - No  攀登"><span class="va-m"></span></a></div>
# </div>
# </div>
